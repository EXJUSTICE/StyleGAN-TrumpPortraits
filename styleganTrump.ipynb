# %% [markdown]
# Clone the repo from github

# %%
# !git clone https://github.com/NVlabs/stylegan.git
# Out:
# Cloning into 'stylegan'...
# remote: Enumerating objects: 77, done.
# remote: Total 77 (delta 0), reused 0 (delta 0), pack-reused 77
# Unpacking objects: 100% (77/77), done.

# %% [markdown]
# cd into the directory

# %%
cd stylegan/
# Out:
# /content/stylegan

# %% [markdown]
# download dataset from google drive, (Trump photos dataset from kaggle)

# %%
# !gdown https://drive.google.com/uc?id=1EKTecu9E2t1j1ZyCRRbaA-ZVOjHCL15r
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1EKTecu9E2t1j1ZyCRRbaA-ZVOjHCL15r
# To: /content/stylegan/trump.zip
# 709MB [00:04, 174MB/s]

# %% [markdown]
# No Scrapper used

# %% [markdown]
# make directory for portraits

# %%
# !mkdir portraitbig

# %% [markdown]
# move portrait zip to directory

# %%
# !mv /content/stylegan/trump.zip /content/stylegan/portraitbig/

# %% [markdown]
# unzip portrait zip file (into portraitbig, under trump_photos folder)

# %%
cd portraitbig/
# Out:
# /content/stylegan/portraitbig

# %%
# !unzip trump.zip
# Out:
# Archive:  trump.zip
#    creating: trump_photos/
#   inflating: trump_photos/1001.jpg
#   inflating: trump_photos/1003.jpg
#   inflating: trump_photos/1004.jpg
#   inflating: trump_photos/1007.jpg
#   inflating: trump_photos/101.jpg
#   inflating: trump_photos/1010.jpg
#   inflating: trump_photos/1013.jpg
#   inflating: trump_photos/1015.jpg
#   inflating: trump_photos/1019.jpg
#   inflating: trump_photos/102.jpg
#   inflating: trump_photos/1022.jpg
#   inflating: trump_photos/1026.jpg
#   inflating: trump_photos/1029.jpg
#   inflating: trump_photos/1031.jpg
#   inflating: trump_photos/1032.jpg
#   inflating: trump_photos/1038.jpg
#   inflating: trump_photos/1040.jpg
#   inflating: trump_photos/1042.jpg
#   inflating: trump_photos/1045.jpg
#   inflating: trump_photos/1046.jpg
#   inflating: trump_photos/1047.jpg
#   inflating: trump_photos/1048.jpg
#   inflating: trump_photos/1051.jpg
#   inflating: trump_photos/1054.jpg
#   inflating: trump_photos/1059.jpg
#   inflating: trump_photos/106.jpg
#   inflating: trump_photos/1063.jpg
#   inflating: trump_photos/1066.jpg
#   inflating: trump_photos/1068.jpg
#   inflating: trump_photos/1069.jpg
#   inflating: trump_photos/1074.jpg
#   inflating: trump_photos/1075.jpg
#   inflating: trump_photos/108.jpg
#   inflating: trump_photos/1080.jpg
#   inflating: trump_photos/1082.jpg
#   inflating: trump_photos/1084.jpg
#   inflating: trump_photos/1088.jpg
#   inflating: trump_photos/1090.jpg
#   inflating: trump_photos/1092.jpg
#   inflating: trump_photos/1095.jpg
#   inflating: trump_photos/1096.jpg
#   inflating: trump_photos/1097.jpg
#   inflating: trump_photos/110.jpg
#   inflating: trump_photos/1100.jpg
#   inflating: trump_photos/1107.jpg
#   inflating: trump_photos/1110.jpg
#   inflating: trump_photos/1111.jpg
#   inflating: trump_photos/1114.jpg
#   inflating: trump_photos/1116.jpg
#   inflating: trump_photos/1118.jpg
#   inflating: trump_photos/112.jpg
#   inflating: trump_photos/1144.jpg
#   inflating: trump_photos/1145.jpg
#   inflating: trump_photos/1148.jpg
#   inflating: trump_photos/115.jpg
#   inflating: trump_photos/1150.jpg
#   inflating: trump_photos/1152.jpg
#   inflating: trump_photos/1156.jpg
#   inflating: trump_photos/1162.jpg
#   inflating: trump_photos/1168.jpg
#   inflating: trump_photos/117.jpg
#   inflating: trump_photos/1172.jpg
#   inflating: trump_photos/1177.jpg
#   inflating: trump_photos/118.jpg
#   inflating: trump_photos/1180.jpg
#   inflating: trump_photos/1182.jpg
#   inflating: trump_photos/1184.jpg
#   inflating: trump_photos/1185.jpg
#   inflating: trump_photos/1186.jpg
#   inflating: trump_photos/1195.jpg
#   inflating: trump_photos/12.jpg
#   inflating: trump_photos/1204.jpg
#   inflating: trump_photos/1208.jpg
#   inflating: trump_photos/121.jpg
#   inflating: trump_photos/1214.jpg
#   inflating: trump_photos/1215.jpg
#   inflating: trump_photos/1216.jpg
#   inflating: trump_photos/1217.jpg
#   inflating: trump_photos/1220.jpg
#   inflating: trump_photos/1221.jpg
#   inflating: trump_photos/1222.jpg
#   inflating: trump_photos/1228.jpg
#   inflating: trump_photos/1232.jpg
#   inflating: trump_photos/1236.jpg
#   inflating: trump_photos/1238.jpg
#   inflating: trump_photos/124.jpg
#   inflating: trump_photos/1240.jpg
#   inflating: trump_photos/1242.jpg
#   inflating: trump_photos/1244.jpg
#   inflating: trump_photos/1247.jpg
#   inflating: trump_photos/125.jpg
#   inflating: trump_photos/1251.jpg
#   inflating: trump_photos/1252.jpg
#   inflating: trump_photos/1258.jpg
#   inflating: trump_photos/1262.jpg
#   inflating: trump_photos/1265.jpg
#   inflating: trump_photos/127.jpg
#   inflating: trump_photos/1273.jpg
#   inflating: trump_photos/1275.jpg
#   inflating: trump_photos/1277.jpg
#   inflating: trump_photos/1279.jpg
#   inflating: trump_photos/1290.jpg
#   inflating: trump_photos/1291.jpg
#   inflating: trump_photos/1292.jpg
#   inflating: trump_photos/1294.jpg
#   inflating: trump_photos/1296.jpg
#   inflating: trump_photos/13.jpg
#   inflating: trump_photos/130.jpg
#   inflating: trump_photos/1303.jpg
#   inflating: trump_photos/1307.jpg
#   inflating: trump_photos/1308.jpg
#   inflating: trump_photos/1311.jpg
#   inflating: trump_photos/1312.jpg
#   inflating: trump_photos/1315.jpg
#   inflating: trump_photos/1318.jpg
#   inflating: trump_photos/1319.jpg
#   inflating: trump_photos/1322.jpg
#   inflating: trump_photos/1323.jpg
#   inflating: trump_photos/1324.jpg
#   inflating: trump_photos/1326.jpg
#   inflating: trump_photos/1328.jpg
#   inflating: trump_photos/1332.jpg
#   inflating: trump_photos/1336.jpg
#   inflating: trump_photos/1338.jpg
#   inflating: trump_photos/1339.jpg
#   inflating: trump_photos/1340.jpg
#   inflating: trump_photos/1341.jpg
#   inflating: trump_photos/1344.jpg
#   inflating: trump_photos/1352.jpg
#   inflating: trump_photos/136.jpg
#   inflating: trump_photos/1360.jpg
#   inflating: trump_photos/1363.jpg
#   inflating: trump_photos/1366.jpg
#   inflating: trump_photos/1367.jpg
#   inflating: trump_photos/1369.jpg
#   inflating: trump_photos/1370.jpg
#   inflating: trump_photos/1373.jpg
#   inflating: trump_photos/1375.jpg
#   inflating: trump_photos/1376.jpg
#   inflating: trump_photos/138.jpg
#   inflating: trump_photos/1389.jpg
#   inflating: trump_photos/1395.jpg
#   inflating: trump_photos/1397.jpg
#   inflating: trump_photos/1400.jpg
#   inflating: trump_photos/1409.jpg
#   inflating: trump_photos/1412.jpg
#   inflating: trump_photos/1414.jpg
#   inflating: trump_photos/1415.jpg
#   inflating: trump_photos/1417.jpg
#   inflating: trump_photos/1419.jpg
#   inflating: trump_photos/142.jpg
#   inflating: trump_photos/1420.jpg
#   inflating: trump_photos/1425.jpg
#   inflating: trump_photos/1429.jpg
#   inflating: trump_photos/1431.jpg
#   inflating: trump_photos/1433.jpg
#   inflating: trump_photos/1437.jpg
#   inflating: trump_photos/1438.jpg
#   inflating: trump_photos/1443.jpg
#   inflating: trump_photos/1445.jpg
#   inflating: trump_photos/1446.jpg
#   inflating: trump_photos/1447.jpg
#   inflating: trump_photos/1450.jpg
#   inflating: trump_photos/1456.jpg
#   inflating: trump_photos/1459.jpg
#   inflating: trump_photos/1460.jpg
#   inflating: trump_photos/1463.jpg
#   inflating: trump_photos/1465.jpg
#   inflating: trump_photos/1471.jpg
#   inflating: trump_photos/1473.jpg
#   inflating: trump_photos/1474.jpg
#   inflating: trump_photos/1475.jpg
#   inflating: trump_photos/1477.jpg
#   inflating: trump_photos/1478.jpg
#   inflating: trump_photos/148.jpg
#   inflating: trump_photos/1480.jpg
#   inflating: trump_photos/1484.jpg
#   inflating: trump_photos/1485.jpg
#   inflating: trump_photos/1486.jpg
#   inflating: trump_photos/1488.jpg
#   inflating: trump_photos/1491.jpg
#   inflating: trump_photos/1497.jpg
#   inflating: trump_photos/1499.jpg
#   inflating: trump_photos/1500.jpg
#   inflating: trump_photos/1502.jpg
#   inflating: trump_photos/1503.jpg
#   inflating: trump_photos/1506.jpg
#   inflating: trump_photos/1511.jpg
#   inflating: trump_photos/1514.jpg
#   inflating: trump_photos/1522.jpg
#   inflating: trump_photos/1523.jpg
#   inflating: trump_photos/1525.jpg
#   inflating: trump_photos/1527.jpg
#   inflating: trump_photos/1528.jpg
#   inflating: trump_photos/153.jpg
#   inflating: trump_photos/1532.jpg
#   inflating: trump_photos/1533.jpg
#   inflating: trump_photos/1538.jpg
#   inflating: trump_photos/1539.jpg
#   inflating: trump_photos/154.jpg
#   inflating: trump_photos/1544.jpg
#   inflating: trump_photos/155.jpg
#   inflating: trump_photos/1558.jpg
#   inflating: trump_photos/1565.jpg
#   inflating: trump_photos/1570.jpg
#   inflating: trump_photos/1574.jpg
#   inflating: trump_photos/1575.jpg
#   inflating: trump_photos/1576.jpg
#   inflating: trump_photos/1578.jpg
#   inflating: trump_photos/1581.jpg
#   inflating: trump_photos/1586.jpg
#   inflating: trump_photos/1588.jpg
#   inflating: trump_photos/1591.jpg
#   inflating: trump_photos/1595.jpg
#   inflating: trump_photos/1598.jpg
#   inflating: trump_photos/16.jpg
#   inflating: trump_photos/160.jpg
#   inflating: trump_photos/1600.jpg
#   inflating: trump_photos/161.jpg
#   inflating: trump_photos/1611.jpg
#   inflating: trump_photos/1613.jpg
#   inflating: trump_photos/1616.jpg
#   inflating: trump_photos/1617.jpg
#   inflating: trump_photos/1621.jpg
#   inflating: trump_photos/1632.jpg
#   inflating: trump_photos/1637.jpg
#   inflating: trump_photos/164.jpg
#   inflating: trump_photos/1642.jpg
#   inflating: trump_photos/1643.jpg
#   inflating: trump_photos/1646.jpg
#   inflating: trump_photos/1649.jpg
#   inflating: trump_photos/1651.jpg
#   inflating: trump_photos/1655.jpg
#   inflating: trump_photos/1658.jpg
#   inflating: trump_photos/1664.jpg
#   inflating: trump_photos/1665.jpg
#   inflating: trump_photos/1667.jpg
#   inflating: trump_photos/1668.jpg
#   inflating: trump_photos/1670.jpg
#   inflating: trump_photos/1673.jpg
#   inflating: trump_photos/1678.jpg
#   inflating: trump_photos/1680.jpg
#   inflating: trump_photos/1681.jpg
#   inflating: trump_photos/1684.jpg
#   inflating: trump_photos/1686.jpg
#   inflating: trump_photos/169.jpg
#   inflating: trump_photos/1692.jpg
#   inflating: trump_photos/1698.jpg
#   inflating: trump_photos/1702.jpg
#   inflating: trump_photos/1703.jpg
#   inflating: trump_photos/1704.jpg
#   inflating: trump_photos/1705.jpg
#   inflating: trump_photos/1707.jpg
#   inflating: trump_photos/1708.jpg
#   inflating: trump_photos/171.jpg
#   inflating: trump_photos/1710.jpg
#   inflating: trump_photos/1713.jpg
#   inflating: trump_photos/172.jpg
#   inflating: trump_photos/1721.jpg
#   inflating: trump_photos/1723.jpg
#   inflating: trump_photos/1724.jpg
#   inflating: trump_photos/1726.jpg
#   inflating: trump_photos/1728.jpg
#   inflating: trump_photos/173.jpg
#   inflating: trump_photos/1732.jpg
#   inflating: trump_photos/174.jpg
#   inflating: trump_photos/1740.jpg
#   inflating: trump_photos/1741.jpg
#   inflating: trump_photos/1746.jpg
#   inflating: trump_photos/1748.jpg
#   inflating: trump_photos/1749.jpg
#   inflating: trump_photos/1750.jpg
#   inflating: trump_photos/1751.jpg
#   inflating: trump_photos/1752.jpg
#   inflating: trump_photos/176.jpg
#   inflating: trump_photos/1760.jpg
#   inflating: trump_photos/1769.jpg
#   inflating: trump_photos/1770.jpg
#   inflating: trump_photos/1771.jpg
#   inflating: trump_photos/178.jpg
#   inflating: trump_photos/1780.jpg
#   inflating: trump_photos/1782.jpg
#   inflating: trump_photos/1783.jpg
#   inflating: trump_photos/1789.jpg
#   inflating: trump_photos/1792.jpg
#   inflating: trump_photos/1796.jpg
#   inflating: trump_photos/1797.jpg
#   inflating: trump_photos/1798.jpg
#   inflating: trump_photos/1801.jpg
#   inflating: trump_photos/1802.jpg
#   inflating: trump_photos/1803.jpg
#   inflating: trump_photos/1812.jpg
#   inflating: trump_photos/1815.jpg
#   inflating: trump_photos/1820.jpg
#   inflating: trump_photos/1829.jpg
#   inflating: trump_photos/1833.jpg
#   inflating: trump_photos/1840.jpg
#   inflating: trump_photos/1841.jpg
#   inflating: trump_photos/1843.jpg
#   inflating: trump_photos/1846.jpg
#   inflating: trump_photos/1847.jpg
#   inflating: trump_photos/1851.jpg
#   inflating: trump_photos/1853.jpg
#   inflating: trump_photos/1857.jpg
#   inflating: trump_photos/1859.jpg
#   inflating: trump_photos/1865.jpg
#   inflating: trump_photos/1867.jpg
#   inflating: trump_photos/1868.jpg
#   inflating: trump_photos/1869.jpg
#   inflating: trump_photos/1872.jpg
#   inflating: trump_photos/1878.jpg
#   inflating: trump_photos/1882.jpg
#   inflating: trump_photos/1884.jpg
#   inflating: trump_photos/1885.jpg
#   inflating: trump_photos/1888.jpg
#   inflating: trump_photos/1890.jpg
#   inflating: trump_photos/1892.jpg
#   inflating: trump_photos/1893.jpg
#   inflating: trump_photos/190.jpg
#   inflating: trump_photos/1900.jpg
#   inflating: trump_photos/1902.jpg
#   inflating: trump_photos/1903.jpg
#   inflating: trump_photos/191.jpg
#   inflating: trump_photos/170.jpg
#   inflating: trump_photos/1772.jpg
#   inflating: trump_photos/1808.jpg
#   inflating: trump_photos/1899.jpg
#   inflating: trump_photos/1911.jpg
#   inflating: trump_photos/1916.jpg
#   inflating: trump_photos/1919.jpg
#   inflating: trump_photos/1920.jpg
#   inflating: trump_photos/1926.jpg
#   inflating: trump_photos/1928.jpg
#   inflating: trump_photos/1930.jpg
#   inflating: trump_photos/1933.jpg
#   inflating: trump_photos/1935.jpg
#   inflating: trump_photos/1941.jpg
#   inflating: trump_photos/1942.jpg
#   inflating: trump_photos/1943.jpg
#   inflating: trump_photos/1947.jpg
#   inflating: trump_photos/1952.jpg
#   inflating: trump_photos/1960.jpg
#   inflating: trump_photos/1962.jpg
#   inflating: trump_photos/1964.jpg
#   inflating: trump_photos/1966.jpg
#   inflating: trump_photos/1967.jpg
#   inflating: trump_photos/1968.jpg
#   inflating: trump_photos/1970.jpg
#   inflating: trump_photos/1975.jpg
#   inflating: trump_photos/1977.jpg
#   inflating: trump_photos/1980.jpg
#   inflating: trump_photos/1983.jpg
#   inflating: trump_photos/1987.jpg
#   inflating: trump_photos/1993.jpg
#   inflating: trump_photos/1995.jpg
#   inflating: trump_photos/20.jpg
#   inflating: trump_photos/200.jpg
#   inflating: trump_photos/2001.jpg
#   inflating: trump_photos/2009.jpg
#   inflating: trump_photos/2010.jpg
#   inflating: trump_photos/2012.jpg
#   inflating: trump_photos/2015.jpg
#   inflating: trump_photos/2016.jpg
#   inflating: trump_photos/2018.jpg
#   inflating: trump_photos/2020.jpg
#   inflating: trump_photos/2023.jpg
#   inflating: trump_photos/2030.jpg
#   inflating: trump_photos/2031.jpg
#   inflating: trump_photos/2033.jpg
#   inflating: trump_photos/2038.jpg
#   inflating: trump_photos/2041.jpg
#   inflating: trump_photos/2042.jpg
#   inflating: trump_photos/2047.jpg
#   inflating: trump_photos/2054.jpg
#   inflating: trump_photos/2059.jpg
#   inflating: trump_photos/2061.jpg
#   inflating: trump_photos/2070.jpg
#   inflating: trump_photos/2078.jpg
#   inflating: trump_photos/2082.jpg
#   inflating: trump_photos/2083.jpg
#   inflating: trump_photos/2084.jpg
#   inflating: trump_photos/2085.jpg
#   inflating: trump_photos/2086.jpg
#   inflating: trump_photos/2087.jpg
#   inflating: trump_photos/2090.jpg
#   inflating: trump_photos/2091.jpg
#   inflating: trump_photos/2093.jpg
#   inflating: trump_photos/2095.jpg
#   inflating: trump_photos/2097.jpg
#   inflating: trump_photos/2101.jpg
#   inflating: trump_photos/2106.jpg
#   inflating: trump_photos/2113.jpg
#   inflating: trump_photos/2114.jpg
#   inflating: trump_photos/2115.jpg
#   inflating: trump_photos/2119.jpg
#   inflating: trump_photos/2121.jpg
#   inflating: trump_photos/2123.jpg
#   inflating: trump_photos/2130.jpg
#   inflating: trump_photos/2132.jpg
#   inflating: trump_photos/2135.jpg
#   inflating: trump_photos/214.jpg
#   inflating: trump_photos/2141.jpg
#   inflating: trump_photos/2142.jpg
#   inflating: trump_photos/2153.jpg
#   inflating: trump_photos/2155.jpg
#   inflating: trump_photos/2156.jpg
#   inflating: trump_photos/2159.jpg
#   inflating: trump_photos/216.jpg
#   inflating: trump_photos/2160.jpg
#   inflating: trump_photos/2165.jpg
#   inflating: trump_photos/2167.jpg
#   inflating: trump_photos/2171.jpg
#   inflating: trump_photos/2172.jpg
#   inflating: trump_photos/2173.jpg
#   inflating: trump_photos/2180.jpg
#   inflating: trump_photos/2188.jpg
#   inflating: trump_photos/2197.jpg
#   inflating: trump_photos/2199.jpg
#   inflating: trump_photos/22.jpg
#   inflating: trump_photos/2200.jpg
#   inflating: trump_photos/2212.jpg
#   inflating: trump_photos/2213.jpg
#   inflating: trump_photos/2214.jpg
#   inflating: trump_photos/2216.jpg
#   inflating: trump_photos/2217.jpg
#   inflating: trump_photos/2218.jpg
#   inflating: trump_photos/2221.jpg
#   inflating: trump_photos/2222.jpg
#   inflating: trump_photos/2223.jpg
#   inflating: trump_photos/2224.jpg
#   inflating: trump_photos/2227.jpg
#   inflating: trump_photos/2228.jpg
#   inflating: trump_photos/2229.jpg
#   inflating: trump_photos/2230.jpg
#   inflating: trump_photos/2233.jpg
#   inflating: trump_photos/2235.jpg
#   inflating: trump_photos/2248.jpg
#   inflating: trump_photos/2249.jpg
#   inflating: trump_photos/2250.jpg
#   inflating: trump_photos/2251.jpg
#   inflating: trump_photos/2258.jpg
#   inflating: trump_photos/226.jpg
#   inflating: trump_photos/2264.jpg
#   inflating: trump_photos/2268.jpg
#   inflating: trump_photos/2270.jpg
#   inflating: trump_photos/2273.jpg
#   inflating: trump_photos/2280.jpg
#   inflating: trump_photos/2281.jpg
#   inflating: trump_photos/2288.jpg
#   inflating: trump_photos/2289.jpg
#   inflating: trump_photos/2290.jpg
#   inflating: trump_photos/2291.jpg
#   inflating: trump_photos/2292.jpg
#   inflating: trump_photos/2293.jpg
#   inflating: trump_photos/2299.jpg
#   inflating: trump_photos/230.jpg
#   inflating: trump_photos/2301.jpg
#   inflating: trump_photos/2303.jpg
#   inflating: trump_photos/2304.jpg
#   inflating: trump_photos/2306.jpg
#   inflating: trump_photos/2307.jpg
#   inflating: trump_photos/2309.jpg
#   inflating: trump_photos/231.jpg
#   inflating: trump_photos/2311.jpg
#   inflating: trump_photos/2313.jpg
#   inflating: trump_photos/2314.jpg
#   inflating: trump_photos/2317.jpg
#   inflating: trump_photos/232.jpg
#   inflating: trump_photos/2324.jpg
#   inflating: trump_photos/2325.jpg
#   inflating: trump_photos/2326.jpg
#   inflating: trump_photos/2327.jpg
#   inflating: trump_photos/2329.jpg
#   inflating: trump_photos/2333.jpg
#   inflating: trump_photos/2335.jpg
#   inflating: trump_photos/2336.jpg
#   inflating: trump_photos/2338.jpg
#   inflating: trump_photos/234.jpg
#   inflating: trump_photos/2340.jpg
#   inflating: trump_photos/2342.jpg
#   inflating: trump_photos/2343.jpg
#   inflating: trump_photos/2345.jpg
#   inflating: trump_photos/2346.jpg
#   inflating: trump_photos/236.jpg
#   inflating: trump_photos/2362.jpg
#   inflating: trump_photos/2363.jpg
#   inflating: trump_photos/2364.jpg
#   inflating: trump_photos/2369.jpg
#   inflating: trump_photos/237.jpg
#   inflating: trump_photos/2371.jpg
#   inflating: trump_photos/2378.jpg
#   inflating: trump_photos/2380.jpg
#   inflating: trump_photos/2385.jpg
#   inflating: trump_photos/2388.jpg
#   inflating: trump_photos/2390.jpg
#   inflating: trump_photos/2393.jpg
#   inflating: trump_photos/2394.jpg
#   inflating: trump_photos/2402.jpg
#   inflating: trump_photos/2405.jpg
#   inflating: trump_photos/2414.jpg
#   inflating: trump_photos/2415.jpg
#   inflating: trump_photos/242.jpg
#   inflating: trump_photos/2422.jpg
#   inflating: trump_photos/2425.jpg
#   inflating: trump_photos/2432.jpg
#   inflating: trump_photos/2433.jpg
#   inflating: trump_photos/2435.jpg
#   inflating: trump_photos/2436.jpg
#   inflating: trump_photos/2443.jpg
#   inflating: trump_photos/2451.jpg
#   inflating: trump_photos/2452.jpg
#   inflating: trump_photos/2460.jpg
#   inflating: trump_photos/2462.jpg
#   inflating: trump_photos/2467.jpg
#   inflating: trump_photos/2469.jpg
#   inflating: trump_photos/247.jpg
#   inflating: trump_photos/2474.jpg
#   inflating: trump_photos/2485.jpg
#   inflating: trump_photos/2490.jpg
#   inflating: trump_photos/2493.jpg
#   inflating: trump_photos/2495.jpg
#   inflating: trump_photos/2497.jpg
#   inflating: trump_photos/2500.jpg
#   inflating: trump_photos/2501.jpg
#   inflating: trump_photos/2505.jpg
#   inflating: trump_photos/2510.jpg
#   inflating: trump_photos/2519.jpg
#   inflating: trump_photos/2521.jpg
#   inflating: trump_photos/2523.jpg
#   inflating: trump_photos/2527.jpg
#   inflating: trump_photos/2528.jpg
#   inflating: trump_photos/253.jpg
#   inflating: trump_photos/2531.jpg
#   inflating: trump_photos/2533.jpg
#   inflating: trump_photos/2539.jpg
#   inflating: trump_photos/2547.jpg
#   inflating: trump_photos/2557.jpg
#   inflating: trump_photos/2558.jpg
#   inflating: trump_photos/2561.jpg
#   inflating: trump_photos/2562.jpg
#   inflating: trump_photos/2563.jpg
#   inflating: trump_photos/2565.jpg
#   inflating: trump_photos/2567.jpg
#   inflating: trump_photos/2569.jpg
#   inflating: trump_photos/257.jpg
#   inflating: trump_photos/2571.jpg
#   inflating: trump_photos/2572.jpg
#   inflating: trump_photos/2573.jpg
#   inflating: trump_photos/2574.jpg
#   inflating: trump_photos/2579.jpg
#   inflating: trump_photos/2585.jpg
#   inflating: trump_photos/2592.jpg
#   inflating: trump_photos/2593.jpg
#   inflating: trump_photos/2595.jpg
#   inflating: trump_photos/2597.jpg
#   inflating: trump_photos/2598.jpg
#   inflating: trump_photos/26.jpg
#   inflating: trump_photos/2601.jpg
#   inflating: trump_photos/2602.jpg
#   inflating: trump_photos/2607.jpg
#   inflating: trump_photos/2608.jpg
#   inflating: trump_photos/261.jpg
#   inflating: trump_photos/2614.jpg
#   inflating: trump_photos/2615.jpg
#   inflating: trump_photos/2620.jpg
#   inflating: trump_photos/2623.jpg
#   inflating: trump_photos/2625.jpg
#   inflating: trump_photos/2627.jpg
#   inflating: trump_photos/2629.jpg
#   inflating: trump_photos/2631.jpg
#   inflating: trump_photos/2637.jpg
#   inflating: trump_photos/2639.jpg
#   inflating: trump_photos/264.jpg
#   inflating: trump_photos/2640.jpg
#   inflating: trump_photos/2641.jpg
#   inflating: trump_photos/2643.jpg
#   inflating: trump_photos/2646.jpg
#   inflating: trump_photos/2648.jpg
#   inflating: trump_photos/2650.jpg
#   inflating: trump_photos/2653.jpg
#   inflating: trump_photos/2654.jpg
#   inflating: trump_photos/2657.jpg
#   inflating: trump_photos/2659.jpg
#   inflating: trump_photos/2669.jpg
#   inflating: trump_photos/267.jpg
#   inflating: trump_photos/2670.jpg
#   inflating: trump_photos/2671.jpg
#   inflating: trump_photos/2672.jpg
#   inflating: trump_photos/2673.jpg
#   inflating: trump_photos/2677.jpg
#   inflating: trump_photos/2685.jpg
#   inflating: trump_photos/2686.jpg
#   inflating: trump_photos/2687.jpg
#   inflating: trump_photos/2694.jpg
#   inflating: trump_photos/2695.jpg
#   inflating: trump_photos/2702.jpg
#   inflating: trump_photos/2705.jpg
#   inflating: trump_photos/2706.jpg
#   inflating: trump_photos/2709.jpg
#   inflating: trump_photos/271.jpg
#   inflating: trump_photos/2714.jpg
#   inflating: trump_photos/2728.jpg
#   inflating: trump_photos/273.jpg
#   inflating: trump_photos/2735.jpg
#   inflating: trump_photos/2737.jpg
#   inflating: trump_photos/2738.jpg
#   inflating: trump_photos/274.jpg
#   inflating: trump_photos/2742.jpg
#   inflating: trump_photos/2743.jpg
#   inflating: trump_photos/2746.jpg
#   inflating: trump_photos/2748.jpg
#   inflating: trump_photos/275.jpg
#   inflating: trump_photos/2750.jpg
#   inflating: trump_photos/2752.jpg
#   inflating: trump_photos/2756.jpg
#   inflating: trump_photos/2759.jpg
#   inflating: trump_photos/2761.jpg
#   inflating: trump_photos/277.jpg
#   inflating: trump_photos/2773.jpg
#   inflating: trump_photos/2774.jpg
#   inflating: trump_photos/2778.jpg
#   inflating: trump_photos/2785.jpg
#   inflating: trump_photos/2788.jpg
#   inflating: trump_photos/2789.jpg
#   inflating: trump_photos/2790.jpg
#   inflating: trump_photos/2794.jpg
#   inflating: trump_photos/2798.jpg
#   inflating: trump_photos/2800.jpg
#   inflating: trump_photos/2803.jpg
#   inflating: trump_photos/2804.jpg
#   inflating: trump_photos/2805.jpg
#   inflating: trump_photos/2807.jpg
#   inflating: trump_photos/134.jpg
#   inflating: trump_photos/2348.jpg
#   inflating: trump_photos/2708.jpg
#   inflating: trump_photos/2726.jpg
#   inflating: trump_photos/2762.jpg
#   inflating: trump_photos/2780.jpg
#   inflating: trump_photos/2799.jpg
#   inflating: trump_photos/2809.jpg
#   inflating: trump_photos/2812.jpg
#   inflating: trump_photos/2815.jpg
#   inflating: trump_photos/2817.jpg
#   inflating: trump_photos/282.jpg
#   inflating: trump_photos/2820.jpg
#   inflating: trump_photos/2821.jpg
#   inflating: trump_photos/2823.jpg
#   inflating: trump_photos/2828.jpg
#   inflating: trump_photos/2830.jpg
#   inflating: trump_photos/2832.jpg
#   inflating: trump_photos/2834.jpg
#   inflating: trump_photos/2835.jpg
#   inflating: trump_photos/2839.jpg
#   inflating: trump_photos/284.jpg
#   inflating: trump_photos/2840.jpg
#   inflating: trump_photos/2841.jpg
#   inflating: trump_photos/2846.jpg
#   inflating: trump_photos/285.jpg
#   inflating: trump_photos/2852.jpg
#   inflating: trump_photos/2854.jpg
#   inflating: trump_photos/2857.jpg
#   inflating: trump_photos/2858.jpg
#   inflating: trump_photos/2859.jpg
#   inflating: trump_photos/286.jpg
#   inflating: trump_photos/2863.jpg
#   inflating: trump_photos/2864.jpg
#   inflating: trump_photos/2865.jpg
#   inflating: trump_photos/2869.jpg
#   inflating: trump_photos/2870.jpg
#   inflating: trump_photos/2872.jpg
#   inflating: trump_photos/2873.jpg
#   inflating: trump_photos/2879.jpg
#   inflating: trump_photos/288.jpg
#   inflating: trump_photos/2880.jpg
#   inflating: trump_photos/2885.jpg
#   inflating: trump_photos/2886.jpg
#   inflating: trump_photos/2887.jpg
#   inflating: trump_photos/2895.jpg
#   inflating: trump_photos/2896.jpg
#   inflating: trump_photos/2899.jpg
#   inflating: trump_photos/29.jpg
#   inflating: trump_photos/2900.jpg
#   inflating: trump_photos/2901.jpg
#   inflating: trump_photos/2902.jpg
#   inflating: trump_photos/2907.jpg
#   inflating: trump_photos/2909.jpg
#   inflating: trump_photos/2910.jpg
#   inflating: trump_photos/2916.jpg
#   inflating: trump_photos/2917.jpg
#   inflating: trump_photos/2920.jpg
#   inflating: trump_photos/2925.jpg
#   inflating: trump_photos/2931.jpg
#   inflating: trump_photos/2937.jpg
#   inflating: trump_photos/2938.jpg
#   inflating: trump_photos/2945.jpg
#   inflating: trump_photos/2946.jpg
#   inflating: trump_photos/295.jpg
#   inflating: trump_photos/2954.jpg
#   inflating: trump_photos/2955.jpg
#   inflating: trump_photos/2958.jpg
#   inflating: trump_photos/2961.jpg
#   inflating: trump_photos/2963.jpg
#   inflating: trump_photos/2964.jpg
#   inflating: trump_photos/2965.jpg
#   inflating: trump_photos/2966.jpg
#   inflating: trump_photos/2968.jpg
#   inflating: trump_photos/2969.jpg
#   inflating: trump_photos/297.jpg
#   inflating: trump_photos/2972.jpg
#   inflating: trump_photos/2973.jpg
#   inflating: trump_photos/2975.jpg
#   inflating: trump_photos/298.jpg
#   inflating: trump_photos/2982.jpg
#   inflating: trump_photos/2989.jpg
#   inflating: trump_photos/2990.jpg
#   inflating: trump_photos/2992.jpg
#   inflating: trump_photos/2995.jpg
#   inflating: trump_photos/2996.jpg
#   inflating: trump_photos/2997.jpg
#   inflating: trump_photos/2998.jpg
#   inflating: trump_photos/30.jpg
#   inflating: trump_photos/3001.jpg
#   inflating: trump_photos/3004.jpg
#   inflating: trump_photos/3009.jpg
#   inflating: trump_photos/301.jpg
#   inflating: trump_photos/3016.jpg
#   inflating: trump_photos/3019.jpg
#   inflating: trump_photos/309.jpg
#   inflating: trump_photos/313.jpg
#   inflating: trump_photos/317.jpg
#   inflating: trump_photos/319.jpg
#   inflating: trump_photos/32.jpg
#   inflating: trump_photos/321.jpg
#   inflating: trump_photos/324.jpg
#   inflating: trump_photos/326.jpg
#   inflating: trump_photos/327.jpg
#   inflating: trump_photos/330.jpg
#   inflating: trump_photos/331.jpg
#   inflating: trump_photos/333.jpg
#   inflating: trump_photos/338.jpg
#   inflating: trump_photos/34.jpg
#   inflating: trump_photos/341.jpg
#   inflating: trump_photos/344.jpg
#   inflating: trump_photos/347.jpg
#   inflating: trump_photos/348.jpg
#   inflating: trump_photos/35.jpg
#   inflating: trump_photos/350.jpg
#   inflating: trump_photos/352.jpg
#   inflating: trump_photos/355.jpg
#   inflating: trump_photos/357.jpg
#   inflating: trump_photos/358.jpg
#   inflating: trump_photos/36.jpg
#   inflating: trump_photos/360.jpg
#   inflating: trump_photos/362.jpg
#   inflating: trump_photos/366.jpg
#   inflating: trump_photos/368.jpg
#   inflating: trump_photos/372.jpg
#   inflating: trump_photos/375.jpg
#   inflating: trump_photos/377.jpg
#   inflating: trump_photos/38.jpg
#   inflating: trump_photos/380.jpg
#   inflating: trump_photos/381.jpg
#   inflating: trump_photos/382.jpg
#   inflating: trump_photos/383.jpg
#   inflating: trump_photos/390.jpg
#   inflating: trump_photos/393.jpg
#   inflating: trump_photos/394.jpg
#   inflating: trump_photos/395.jpg
#   inflating: trump_photos/397.jpg
#   inflating: trump_photos/40.jpg
#   inflating: trump_photos/401.jpg
#   inflating: trump_photos/402.jpg
#   inflating: trump_photos/404.jpg
#   inflating: trump_photos/406.jpg
#   inflating: trump_photos/41.jpg
#   inflating: trump_photos/410.jpg
#   inflating: trump_photos/411.jpg
#   inflating: trump_photos/419.jpg
#   inflating: trump_photos/42.jpg
#   inflating: trump_photos/421.jpg
#   inflating: trump_photos/423.jpg
#   inflating: trump_photos/430.jpg
#   inflating: trump_photos/433.jpg
#   inflating: trump_photos/435.jpg
#   inflating: trump_photos/436.jpg
#   inflating: trump_photos/438.jpg
#   inflating: trump_photos/44.jpg
#   inflating: trump_photos/443.jpg
#   inflating: trump_photos/444.jpg
#   inflating: trump_photos/445.jpg
#   inflating: trump_photos/447.jpg
#   inflating: trump_photos/448.jpg
#   inflating: trump_photos/449.jpg
#   inflating: trump_photos/453.jpg
#   inflating: trump_photos/463.jpg
#   inflating: trump_photos/466.jpg
#   inflating: trump_photos/468.jpg
#   inflating: trump_photos/470.jpg
#   inflating: trump_photos/475.jpg
#   inflating: trump_photos/478.jpg
#   inflating: trump_photos/479.jpg
#   inflating: trump_photos/480.jpg
#   inflating: trump_photos/482.jpg
#   inflating: trump_photos/484.jpg
#   inflating: trump_photos/491.jpg
#   inflating: trump_photos/494.jpg
#   inflating: trump_photos/495.jpg
#   inflating: trump_photos/499.jpg
#   inflating: trump_photos/50.jpg
#   inflating: trump_photos/500.jpg
#   inflating: trump_photos/509.jpg
#   inflating: trump_photos/51.jpg
#   inflating: trump_photos/52.jpg
#   inflating: trump_photos/523.jpg
#   inflating: trump_photos/53.jpg
#   inflating: trump_photos/538.jpg
#   inflating: trump_photos/539.jpg
#   inflating: trump_photos/543.jpg
#   inflating: trump_photos/544.jpg
#   inflating: trump_photos/545.jpg
#   inflating: trump_photos/546.jpg
#   inflating: trump_photos/556.jpg
#   inflating: trump_photos/56.jpg
#   inflating: trump_photos/560.jpg
#   inflating: trump_photos/561.jpg
#   inflating: trump_photos/562.jpg
#   inflating: trump_photos/565.jpg
#   inflating: trump_photos/57.jpg
#   inflating: trump_photos/575.jpg
#   inflating: trump_photos/579.jpg
#   inflating: trump_photos/58.jpg
#   inflating: trump_photos/582.jpg
#   inflating: trump_photos/585.jpg
#   inflating: trump_photos/587.jpg
#   inflating: trump_photos/588.jpg
#   inflating: trump_photos/593.jpg
#   inflating: trump_photos/595.jpg
#   inflating: trump_photos/598.jpg
#   inflating: trump_photos/599.jpg
#   inflating: trump_photos/6.jpg
#   inflating: trump_photos/600.jpg
#   inflating: trump_photos/605.jpg
#   inflating: trump_photos/610.jpg
#   inflating: trump_photos/614.jpg
#   inflating: trump_photos/616.jpg
#   inflating: trump_photos/617.jpg
#   inflating: trump_photos/619.jpg
#   inflating: trump_photos/621.jpg
#   inflating: trump_photos/622.jpg
#   inflating: trump_photos/624.jpg
#   inflating: trump_photos/627.jpg
#   inflating: trump_photos/633.jpg
#   inflating: trump_photos/634.jpg
#   inflating: trump_photos/635.jpg
#   inflating: trump_photos/636.jpg
#   inflating: trump_photos/639.jpg
#   inflating: trump_photos/64.jpg
#   inflating: trump_photos/643.jpg
#   inflating: trump_photos/646.jpg
#   inflating: trump_photos/65.jpg
#   inflating: trump_photos/66.jpg
#   inflating: trump_photos/660.jpg
#   inflating: trump_photos/662.jpg
#   inflating: trump_photos/663.jpg
#   inflating: trump_photos/666.jpg
#   inflating: trump_photos/669.jpg
#   inflating: trump_photos/673.jpg
#   inflating: trump_photos/676.jpg
#   inflating: trump_photos/679.jpg
#   inflating: trump_photos/683.jpg
#   inflating: trump_photos/684.jpg
#   inflating: trump_photos/688.jpg
#   inflating: trump_photos/689.jpg
#   inflating: trump_photos/69.jpg
#   inflating: trump_photos/690.jpg
#   inflating: trump_photos/691.jpg
#   inflating: trump_photos/692.jpg
#   inflating: trump_photos/693.jpg
#   inflating: trump_photos/696.jpg
#   inflating: trump_photos/7.jpg
#   inflating: trump_photos/702.jpg
#   inflating: trump_photos/703.jpg
#   inflating: trump_photos/707.jpg
#   inflating: trump_photos/709.jpg
#   inflating: trump_photos/71.jpg
#   inflating: trump_photos/712.jpg
#   inflating: trump_photos/713.jpg
#   inflating: trump_photos/716.jpg
#   inflating: trump_photos/719.jpg
#   inflating: trump_photos/720.jpg
#   inflating: trump_photos/724.jpg
#   inflating: trump_photos/725.jpg
#   inflating: trump_photos/728.jpg
#   inflating: trump_photos/730.jpg
#   inflating: trump_photos/731.jpg
#   inflating: trump_photos/732.jpg
#   inflating: trump_photos/737.jpg
#   inflating: trump_photos/74.jpg
#   inflating: trump_photos/745.jpg
#   inflating: trump_photos/752.jpg
#   inflating: trump_photos/753.jpg
#   inflating: trump_photos/754.jpg
#   inflating: trump_photos/755.jpg
#   inflating: trump_photos/758.jpg
#   inflating: trump_photos/759.jpg
#   inflating: trump_photos/764.jpg
#   inflating: trump_photos/769.jpg
#   inflating: trump_photos/772.jpg
#   inflating: trump_photos/775.jpg
#   inflating: trump_photos/777.jpg
#   inflating: trump_photos/778.jpg
#   inflating: trump_photos/78.jpg
#   inflating: trump_photos/782.jpg
#   inflating: trump_photos/797.jpg
#   inflating: trump_photos/798.jpg
#   inflating: trump_photos/799.jpg
#   inflating: trump_photos/803.jpg
#   inflating: trump_photos/805.jpg
#   inflating: trump_photos/810.jpg
#   inflating: trump_photos/813.jpg
#   inflating: trump_photos/816.jpg
#   inflating: trump_photos/819.jpg
#   inflating: trump_photos/822.jpg
#   inflating: trump_photos/825.jpg
#   inflating: trump_photos/831.jpg
#   inflating: trump_photos/833.jpg
#   inflating: trump_photos/834.jpg
#   inflating: trump_photos/835.jpg
#   inflating: trump_photos/838.jpg
#   inflating: trump_photos/839.jpg
#   inflating: trump_photos/84.jpg
#   inflating: trump_photos/841.jpg
#   inflating: trump_photos/846.jpg
#   inflating: trump_photos/851.jpg
#   inflating: trump_photos/855.jpg
#   inflating: trump_photos/857.jpg
#   inflating: trump_photos/860.jpg
#   inflating: trump_photos/862.jpg
#   inflating: trump_photos/865.jpg
#   inflating: trump_photos/867.jpg
#   inflating: trump_photos/868.jpg
#   inflating: trump_photos/869.jpg
#   inflating: trump_photos/872.jpg
#   inflating: trump_photos/873.jpg
#   inflating: trump_photos/877.jpg
#   inflating: trump_photos/878.jpg
#   inflating: trump_photos/88.jpg
#   inflating: trump_photos/883.jpg
#   inflating: trump_photos/884.jpg
#   inflating: trump_photos/885.jpg
#   inflating: trump_photos/89.jpg
#   inflating: trump_photos/890.jpg
#   inflating: trump_photos/891.jpg
#   inflating: trump_photos/895.jpg
#   inflating: trump_photos/897.jpg
#   inflating: trump_photos/9.jpg
#   inflating: trump_photos/902.jpg
#   inflating: trump_photos/905.jpg
#   inflating: trump_photos/91.jpg
#   inflating: trump_photos/911.jpg
#   inflating: trump_photos/912.jpg
#   inflating: trump_photos/913.jpg
#   inflating: trump_photos/918.jpg
#   inflating: trump_photos/920.jpg
#   inflating: trump_photos/924.jpg
#   inflating: trump_photos/926.jpg
#   inflating: trump_photos/929.jpg
#   inflating: trump_photos/93.jpg
#   inflating: trump_photos/931.jpg
#   inflating: trump_photos/936.jpg
#   inflating: trump_photos/937.jpg
#   inflating: trump_photos/941.jpg
#   inflating: trump_photos/942.jpg
#   inflating: trump_photos/943.jpg
#   inflating: trump_photos/948.jpg
#   inflating: trump_photos/956.jpg
#   inflating: trump_photos/957.jpg
#   inflating: trump_photos/960.jpg
#   inflating: trump_photos/962.jpg
#   inflating: trump_photos/963.jpg
#   inflating: trump_photos/964.jpg
#   inflating: trump_photos/968.jpg
#   inflating: trump_photos/973.jpg
#   inflating: trump_photos/975.jpg
#   inflating: trump_photos/976.jpg
#   inflating: trump_photos/978.jpg
#   inflating: trump_photos/979.jpg
#   inflating: trump_photos/98.jpg
#   inflating: trump_photos/980.jpg
#   inflating: trump_photos/981.jpg
#   inflating: trump_photos/984.jpg
#   inflating: trump_photos/985.jpg
#   inflating: trump_photos/987.jpg
#   inflating: trump_photos/99.jpg
#   inflating: trump_photos/990.jpg
#   inflating: trump_photos/991.jpg
#   inflating: trump_photos/993.jpg
#   inflating: trump_photos/994.jpg
#   inflating: trump_photos/995.jpg
#   inflating: trump_photos/997.jpg
#   inflating: trump_photos/10.jpg
#   inflating: trump_photos/1002.jpg
#   inflating: trump_photos/1006.jpg
#   inflating: trump_photos/1008.jpg
#   inflating: trump_photos/1009.jpg
#   inflating: trump_photos/1012.jpg
#   inflating: trump_photos/1014.jpg
#   inflating: trump_photos/1016.jpg
#   inflating: trump_photos/1017.jpg
#   inflating: trump_photos/1018.jpg
#   inflating: trump_photos/1020.jpg
#   inflating: trump_photos/1023.jpg
#   inflating: trump_photos/1024.jpg
#   inflating: trump_photos/1030.jpg
#   inflating: trump_photos/1034.jpg
#   inflating: trump_photos/1043.jpg
#   inflating: trump_photos/1049.jpg
#   inflating: trump_photos/105.jpg
#   inflating: trump_photos/1050.jpg
#   inflating: trump_photos/1052.jpg
#   inflating: trump_photos/1053.jpg
#   inflating: trump_photos/1055.jpg
#   inflating: trump_photos/1056.jpg
#   inflating: trump_photos/1057.jpg
#   inflating: trump_photos/1058.jpg
#   inflating: trump_photos/1060.jpg
#   inflating: trump_photos/1061.jpg
#   inflating: trump_photos/1062.jpg
#   inflating: trump_photos/1065.jpg
#   inflating: trump_photos/1067.jpg
#   inflating: trump_photos/107.jpg
#   inflating: trump_photos/1070.jpg
#   inflating: trump_photos/1073.jpg
#   inflating: trump_photos/1076.jpg
#   inflating: trump_photos/1078.jpg
#   inflating: trump_photos/1089.jpg
#   inflating: trump_photos/109.jpg
#   inflating: trump_photos/1091.jpg
#   inflating: trump_photos/1093.jpg
#   inflating: trump_photos/1094.jpg
#   inflating: trump_photos/1099.jpg
#   inflating: trump_photos/11.jpg
#   inflating: trump_photos/1102.jpg
#   inflating: trump_photos/1109.jpg
#   inflating: trump_photos/111.jpg
#   inflating: trump_photos/1112.jpg
#   inflating: trump_photos/1113.jpg
#   inflating: trump_photos/1115.jpg
#   inflating: trump_photos/1117.jpg
#   inflating: trump_photos/1120.jpg
#   inflating: trump_photos/1123.jpg
#   inflating: trump_photos/1125.jpg
#   inflating: trump_photos/1127.jpg
#   inflating: trump_photos/1129.jpg
#   inflating: trump_photos/113.jpg
#   inflating: trump_photos/1131.jpg
#   inflating: trump_photos/1132.jpg
#   inflating: trump_photos/1133.jpg
#   inflating: trump_photos/1135.jpg
#   inflating: trump_photos/1136.jpg
#   inflating: trump_photos/1138.jpg
#   inflating: trump_photos/1140.jpg
#   inflating: trump_photos/1142.jpg
#   inflating: trump_photos/1146.jpg
#   inflating: trump_photos/1147.jpg
#   inflating: trump_photos/1149.jpg
#   inflating: trump_photos/1153.jpg
#   inflating: trump_photos/1154.jpg
#   inflating: trump_photos/1159.jpg
#   inflating: trump_photos/1163.jpg
#   inflating: trump_photos/1165.jpg
#   inflating: trump_photos/1166.jpg
#   inflating: trump_photos/1167.jpg
#   inflating: trump_photos/1169.jpg
#   inflating: trump_photos/1171.jpg
#   inflating: trump_photos/1173.jpg
#   inflating: trump_photos/1175.jpg
#   inflating: trump_photos/1176.jpg
#   inflating: trump_photos/1179.jpg
#   inflating: trump_photos/1181.jpg
#   inflating: trump_photos/1183.jpg
#   inflating: trump_photos/1187.jpg
#   inflating: trump_photos/1189.jpg
#   inflating: trump_photos/119.jpg
#   inflating: trump_photos/1190.jpg
#   inflating: trump_photos/1191.jpg
#   inflating: trump_photos/1192.jpg
#   inflating: trump_photos/1196.jpg
#   inflating: trump_photos/1197.jpg
#   inflating: trump_photos/120.jpg
#   inflating: trump_photos/1203.jpg
#   inflating: trump_photos/1206.jpg
#   inflating: trump_photos/1207.jpg
#   inflating: trump_photos/1209.jpg
#   inflating: trump_photos/1210.jpg
#   inflating: trump_photos/1211.jpg
#   inflating: trump_photos/1219.jpg
#   inflating: trump_photos/122.jpg
#   inflating: trump_photos/1224.jpg
#   inflating: trump_photos/1225.jpg
#   inflating: trump_photos/1227.jpg
#   inflating: trump_photos/1230.jpg
#   inflating: trump_photos/1231.jpg
#   inflating: trump_photos/1233.jpg
#   inflating: trump_photos/1235.jpg
#   inflating: trump_photos/1237.jpg
#   inflating: trump_photos/1239.jpg
#   inflating: trump_photos/1243.jpg
#   inflating: trump_photos/1245.jpg
#   inflating: trump_photos/1246.jpg
#   inflating: trump_photos/1248.jpg
#   inflating: trump_photos/1253.jpg
#   inflating: trump_photos/1254.jpg
#   inflating: trump_photos/1256.jpg
#   inflating: trump_photos/1257.jpg
#   inflating: trump_photos/126.jpg
#   inflating: trump_photos/1260.jpg
#   inflating: trump_photos/1261.jpg
#   inflating: trump_photos/1263.jpg
#   inflating: trump_photos/1264.jpg
#   inflating: trump_photos/1266.jpg
#   inflating: trump_photos/1267.jpg
#   inflating: trump_photos/1268.jpg
#   inflating: trump_photos/1270.jpg
#   inflating: trump_photos/1271.jpg
#   inflating: trump_photos/1274.jpg
#   inflating: trump_photos/1278.jpg
#   inflating: trump_photos/128.jpg
#   inflating: trump_photos/1284.jpg
#   inflating: trump_photos/1285.jpg
#   inflating: trump_photos/1288.jpg
#   inflating: trump_photos/1289.jpg
#   inflating: trump_photos/129.jpg
#   inflating: trump_photos/1293.jpg
#   inflating: trump_photos/1295.jpg
#   inflating: trump_photos/1298.jpg
#   inflating: trump_photos/1299.jpg
#   inflating: trump_photos/1301.jpg
#   inflating: trump_photos/1306.jpg
#   inflating: trump_photos/1310.jpg
#   inflating: trump_photos/1314.jpg
#   inflating: trump_photos/132.jpg
#   inflating: trump_photos/133.jpg
#   inflating: trump_photos/1331.jpg
#   inflating: trump_photos/1334.jpg
#   inflating: trump_photos/1335.jpg
#   inflating: trump_photos/1343.jpg
#   inflating: trump_photos/1345.jpg
#   inflating: trump_photos/1347.jpg
#   inflating: trump_photos/1349.jpg
#   inflating: trump_photos/135.jpg
#   inflating: trump_photos/1353.jpg
#   inflating: trump_photos/1354.jpg
#   inflating: trump_photos/1358.jpg
#   inflating: trump_photos/1361.jpg
#   inflating: trump_photos/1362.jpg
#   inflating: trump_photos/1364.jpg
#   inflating: trump_photos/137.jpg
#   inflating: trump_photos/1372.jpg
#   inflating: trump_photos/1378.jpg
#   inflating: trump_photos/1380.jpg
#   inflating: trump_photos/1381.jpg
#   inflating: trump_photos/1382.jpg
#   inflating: trump_photos/1384.jpg
#   inflating: trump_photos/1386.jpg
#   inflating: trump_photos/1388.jpg
#   inflating: trump_photos/1392.jpg
#   inflating: trump_photos/1393.jpg
#   inflating: trump_photos/1396.jpg
#   inflating: trump_photos/1398.jpg
#   inflating: trump_photos/1399.jpg
#   inflating: trump_photos/1402.jpg
#   inflating: trump_photos/1405.jpg
#   inflating: trump_photos/1408.jpg
#   inflating: trump_photos/141.jpg
#   inflating: trump_photos/1411.jpg
#   inflating: trump_photos/1418.jpg
#   inflating: trump_photos/1421.jpg
#   inflating: trump_photos/1426.jpg
#   inflating: trump_photos/1427.jpg
#   inflating: trump_photos/1428.jpg
#   inflating: trump_photos/1432.jpg
#   inflating: trump_photos/1434.jpg
#   inflating: trump_photos/1435.jpg
#   inflating: trump_photos/1440.jpg
#   inflating: trump_photos/1444.jpg
#   inflating: trump_photos/1448.jpg
#   inflating: trump_photos/145.jpg
#   inflating: trump_photos/1451.jpg
#   inflating: trump_photos/1452.jpg
#   inflating: trump_photos/1455.jpg
#   inflating: trump_photos/1461.jpg
#   inflating: trump_photos/1467.jpg
#   inflating: trump_photos/1468.jpg
#   inflating: trump_photos/1470.jpg
#   inflating: trump_photos/1476.jpg
#   inflating: trump_photos/1479.jpg
#   inflating: trump_photos/1482.jpg
#   inflating: trump_photos/1487.jpg
#   inflating: trump_photos/1489.jpg
#   inflating: trump_photos/1492.jpg
#   inflating: trump_photos/1494.jpg
#   inflating: trump_photos/1496.jpg
#   inflating: trump_photos/1498.jpg
#   inflating: trump_photos/15.jpg
#   inflating: trump_photos/1501.jpg
#   inflating: trump_photos/1505.jpg
#   inflating: trump_photos/1508.jpg
#   inflating: trump_photos/1509.jpg
#   inflating: trump_photos/1512.jpg
#   inflating: trump_photos/152.jpg
#   inflating: trump_photos/1526.jpg
#   inflating: trump_photos/1529.jpg
#   inflating: trump_photos/1531.jpg
#   inflating: trump_photos/1535.jpg
#   inflating: trump_photos/1536.jpg
#   inflating: trump_photos/1537.jpg
#   inflating: trump_photos/1540.jpg
#   inflating: trump_photos/1543.jpg
#   inflating: trump_photos/1547.jpg
#   inflating: trump_photos/1549.jpg
#   inflating: trump_photos/1550.jpg
#   inflating: trump_photos/1551.jpg
#   inflating: trump_photos/1552.jpg
#   inflating: trump_photos/1554.jpg
#   inflating: trump_photos/1555.jpg
#   inflating: trump_photos/156.jpg
#   inflating: trump_photos/1563.jpg
#   inflating: trump_photos/1566.jpg
#   inflating: trump_photos/157.jpg
#   inflating: trump_photos/1571.jpg
#   inflating: trump_photos/1573.jpg
#   inflating: trump_photos/1579.jpg
#   inflating: trump_photos/158.jpg
#   inflating: trump_photos/1582.jpg
#   inflating: trump_photos/1587.jpg
#   inflating: trump_photos/1593.jpg
#   inflating: trump_photos/1596.jpg
#   inflating: trump_photos/1608.jpg
#   inflating: trump_photos/1609.jpg
#   inflating: trump_photos/1615.jpg
#   inflating: trump_photos/162.jpg
#   inflating: trump_photos/1622.jpg
#   inflating: trump_photos/1624.jpg
#   inflating: trump_photos/1625.jpg
#   inflating: trump_photos/1626.jpg
#   inflating: trump_photos/1628.jpg
#   inflating: trump_photos/163.jpg
#   inflating: trump_photos/1631.jpg
#   inflating: trump_photos/1633.jpg
#   inflating: trump_photos/1634.jpg
#   inflating: trump_photos/1635.jpg
#   inflating: trump_photos/1636.jpg
#   inflating: trump_photos/1638.jpg
#   inflating: trump_photos/1645.jpg
#   inflating: trump_photos/1648.jpg
#   inflating: trump_photos/165.jpg
#   inflating: trump_photos/1650.jpg
#   inflating: trump_photos/1654.jpg
#   inflating: trump_photos/1656.jpg
#   inflating: trump_photos/1659.jpg
# ...
#   inflating: trump_photos/2587.jpg
#   inflating: trump_photos/2591.jpg
#   inflating: trump_photos/2596.jpg
#   inflating: trump_photos/2599.jpg
#   inflating: trump_photos/2600.jpg
#   inflating: trump_photos/2603.jpg
#   inflating: trump_photos/2604.jpg
#   inflating: trump_photos/2609.jpg
#   inflating: trump_photos/2610.jpg
#   inflating: trump_photos/2616.jpg
#   inflating: trump_photos/2618.jpg
#   inflating: trump_photos/262.jpg
#   inflating: trump_photos/2624.jpg
#   inflating: trump_photos/2626.jpg
#   inflating: trump_photos/2628.jpg
#   inflating: trump_photos/263.jpg
#   inflating: trump_photos/2630.jpg
#   inflating: trump_photos/2632.jpg
#   inflating: trump_photos/2634.jpg
#   inflating: trump_photos/2636.jpg
#   inflating: trump_photos/2642.jpg
#   inflating: trump_photos/2645.jpg
#   inflating: trump_photos/2647.jpg
#   inflating: trump_photos/2649.jpg
#   inflating: trump_photos/265.jpg
#   inflating: trump_photos/2652.jpg
#   inflating: trump_photos/2656.jpg
#   inflating: trump_photos/2658.jpg
#   inflating: trump_photos/2660.jpg
#   inflating: trump_photos/2662.jpg
#   inflating: trump_photos/2663.jpg
#   inflating: trump_photos/2665.jpg
#   inflating: trump_photos/2666.jpg
#   inflating: trump_photos/2676.jpg
#   inflating: trump_photos/2681.jpg
#   inflating: trump_photos/2682.jpg
#   inflating: trump_photos/2683.jpg
#   inflating: trump_photos/2691.jpg
#   inflating: trump_photos/2692.jpg
#   inflating: trump_photos/2696.jpg
#   inflating: trump_photos/2697.jpg
#   inflating: trump_photos/27.jpg
#   inflating: trump_photos/2707.jpg
#   inflating: trump_photos/2712.jpg
#   inflating: trump_photos/2713.jpg
#   inflating: trump_photos/2715.jpg
#   inflating: trump_photos/2716.jpg
#   inflating: trump_photos/2717.jpg
#   inflating: trump_photos/2718.jpg
#   inflating: trump_photos/272.jpg
#   inflating: trump_photos/2722.jpg
#   inflating: trump_photos/2724.jpg
#   inflating: trump_photos/2725.jpg
#   inflating: trump_photos/2731.jpg
#   inflating: trump_photos/2732.jpg
#   inflating: trump_photos/2734.jpg
#   inflating: trump_photos/2736.jpg
#   inflating: trump_photos/2740.jpg
#   inflating: trump_photos/2741.jpg
#   inflating: trump_photos/2747.jpg
#   inflating: trump_photos/2749.jpg
#   inflating: trump_photos/2751.jpg
#   inflating: trump_photos/2753.jpg
#   inflating: trump_photos/2757.jpg
#   inflating: trump_photos/2758.jpg
#   inflating: trump_photos/276.jpg
#   inflating: trump_photos/2760.jpg
#   inflating: trump_photos/2763.jpg
#   inflating: trump_photos/2766.jpg
#   inflating: trump_photos/2767.jpg
#   inflating: trump_photos/2769.jpg
#   inflating: trump_photos/2770.jpg
#   inflating: trump_photos/2771.jpg
#   inflating: trump_photos/2772.jpg
#   inflating: trump_photos/2777.jpg
#   inflating: trump_photos/2779.jpg
#   inflating: trump_photos/278.jpg
#   inflating: trump_photos/2783.jpg
#   inflating: trump_photos/2784.jpg
#   inflating: trump_photos/2793.jpg
#   inflating: trump_photos/2801.jpg
#   inflating: trump_photos/2802.jpg
#   inflating: trump_photos/2808.jpg
#   inflating: trump_photos/1682.jpg
#   inflating: trump_photos/2690.jpg
#   inflating: trump_photos/2744.jpg
#   inflating: trump_photos/281.jpg
#   inflating: trump_photos/2810.jpg
#   inflating: trump_photos/2818.jpg
#   inflating: trump_photos/2819.jpg
#   inflating: trump_photos/2822.jpg
#   inflating: trump_photos/2824.jpg
#   inflating: trump_photos/2825.jpg
#   inflating: trump_photos/2826.jpg
#   inflating: trump_photos/2829.jpg
#   inflating: trump_photos/2837.jpg
#   inflating: trump_photos/2842.jpg
#   inflating: trump_photos/2844.jpg
#   inflating: trump_photos/2847.jpg
#   inflating: trump_photos/2862.jpg
#   inflating: trump_photos/2867.jpg
#   inflating: trump_photos/2868.jpg
#   inflating: trump_photos/2874.jpg
#   inflating: trump_photos/2881.jpg
#   inflating: trump_photos/2882.jpg
#   inflating: trump_photos/2883.jpg
#   inflating: trump_photos/2889.jpg
#   inflating: trump_photos/289.jpg
#   inflating: trump_photos/2891.jpg
#   inflating: trump_photos/2892.jpg
#   inflating: trump_photos/2897.jpg
#   inflating: trump_photos/2898.jpg
#   inflating: trump_photos/2908.jpg
#   inflating: trump_photos/2911.jpg
#   inflating: trump_photos/2918.jpg
#   inflating: trump_photos/2919.jpg
#   inflating: trump_photos/2923.jpg
#   inflating: trump_photos/2924.jpg
#   inflating: trump_photos/2926.jpg
#   inflating: trump_photos/2929.jpg
#   inflating: trump_photos/2932.jpg
#   inflating: trump_photos/2933.jpg
#   inflating: trump_photos/294.jpg
#   inflating: trump_photos/2940.jpg
#   inflating: trump_photos/2941.jpg
#   inflating: trump_photos/2942.jpg
#   inflating: trump_photos/2944.jpg
#   inflating: trump_photos/2948.jpg
#   inflating: trump_photos/2951.jpg
#   inflating: trump_photos/2956.jpg
#   inflating: trump_photos/2957.jpg
#   inflating: trump_photos/296.jpg
#   inflating: trump_photos/2962.jpg
#   inflating: trump_photos/2970.jpg
#   inflating: trump_photos/2971.jpg
#   inflating: trump_photos/2974.jpg
#   inflating: trump_photos/2978.jpg
#   inflating: trump_photos/2979.jpg
#   inflating: trump_photos/2980.jpg
#   inflating: trump_photos/2981.jpg
#   inflating: trump_photos/299.jpg
#   inflating: trump_photos/2999.jpg
#   inflating: trump_photos/3.jpg
#   inflating: trump_photos/300.jpg
#   inflating: trump_photos/3003.jpg
#   inflating: trump_photos/3005.jpg
#   inflating: trump_photos/3007.jpg
#   inflating: trump_photos/3011.jpg
#   inflating: trump_photos/3012.jpg
#   inflating: trump_photos/3013.jpg
#   inflating: trump_photos/3014.jpg
#   inflating: trump_photos/302.jpg
#   inflating: trump_photos/3020.jpg
#   inflating: trump_photos/303.jpg
#   inflating: trump_photos/304.jpg
#   inflating: trump_photos/306.jpg
#   inflating: trump_photos/307.jpg
#   inflating: trump_photos/308.jpg
#   inflating: trump_photos/31.jpg
#   inflating: trump_photos/312.jpg
#   inflating: trump_photos/315.jpg
#   inflating: trump_photos/318.jpg
#   inflating: trump_photos/322.jpg
#   inflating: trump_photos/323.jpg
#   inflating: trump_photos/325.jpg
#   inflating: trump_photos/329.jpg
#   inflating: trump_photos/33.jpg
#   inflating: trump_photos/332.jpg
#   inflating: trump_photos/334.jpg
#   inflating: trump_photos/335.jpg
#   inflating: trump_photos/336.jpg
#   inflating: trump_photos/339.jpg
#   inflating: trump_photos/340.jpg
#   inflating: trump_photos/342.jpg
#   inflating: trump_photos/345.jpg
#   inflating: trump_photos/346.jpg
#   inflating: trump_photos/349.jpg
#   inflating: trump_photos/354.jpg
#   inflating: trump_photos/356.jpg
#   inflating: trump_photos/359.jpg
#   inflating: trump_photos/363.jpg
#   inflating: trump_photos/365.jpg
#   inflating: trump_photos/369.jpg
#   inflating: trump_photos/37.jpg
#   inflating: trump_photos/370.jpg
#   inflating: trump_photos/376.jpg
#   inflating: trump_photos/378.jpg
#   inflating: trump_photos/386.jpg
#   inflating: trump_photos/388.jpg
#   inflating: trump_photos/391.jpg
#   inflating: trump_photos/392.jpg
#   inflating: trump_photos/396.jpg
#   inflating: trump_photos/4.jpg
#   inflating: trump_photos/405.jpg
#   inflating: trump_photos/408.jpg
#   inflating: trump_photos/415.jpg
#   inflating: trump_photos/416.jpg
#   inflating: trump_photos/418.jpg
#   inflating: trump_photos/422.jpg
#   inflating: trump_photos/424.jpg
#   inflating: trump_photos/425.jpg
#   inflating: trump_photos/427.jpg
#   inflating: trump_photos/431.jpg
#   inflating: trump_photos/434.jpg
#   inflating: trump_photos/439.jpg
#   inflating: trump_photos/440.jpg
#   inflating: trump_photos/452.jpg
#   inflating: trump_photos/454.jpg
#   inflating: trump_photos/457.jpg
#   inflating: trump_photos/458.jpg
#   inflating: trump_photos/459.jpg
#   inflating: trump_photos/46.jpg
#   inflating: trump_photos/467.jpg
#   inflating: trump_photos/469.jpg
#   inflating: trump_photos/476.jpg
#   inflating: trump_photos/481.jpg
#   inflating: trump_photos/483.jpg
#   inflating: trump_photos/485.jpg
#   inflating: trump_photos/487.jpg
#   inflating: trump_photos/49.jpg
#   inflating: trump_photos/492.jpg
#   inflating: trump_photos/498.jpg
#   inflating: trump_photos/503.jpg
#   inflating: trump_photos/504.jpg
#   inflating: trump_photos/505.jpg
#   inflating: trump_photos/507.jpg
#   inflating: trump_photos/511.jpg
#   inflating: trump_photos/513.jpg
#   inflating: trump_photos/515.jpg
#   inflating: trump_photos/517.jpg
#   inflating: trump_photos/521.jpg
#   inflating: trump_photos/525.jpg
#   inflating: trump_photos/526.jpg
#   inflating: trump_photos/527.jpg
#   inflating: trump_photos/528.jpg
#   inflating: trump_photos/531.jpg
#   inflating: trump_photos/533.jpg
#   inflating: trump_photos/534.jpg
#   inflating: trump_photos/535.jpg
#   inflating: trump_photos/536.jpg
#   inflating: trump_photos/537.jpg
#   inflating: trump_photos/541.jpg
#   inflating: trump_photos/542.jpg
#   inflating: trump_photos/547.jpg
#   inflating: trump_photos/549.jpg
#   inflating: trump_photos/550.jpg
#   inflating: trump_photos/563.jpg
#   inflating: trump_photos/564.jpg
#   inflating: trump_photos/568.jpg
#   inflating: trump_photos/569.jpg
#   inflating: trump_photos/570.jpg
#   inflating: trump_photos/571.jpg
#   inflating: trump_photos/572.jpg
#   inflating: trump_photos/580.jpg
#   inflating: trump_photos/581.jpg
#   inflating: trump_photos/583.jpg
#   inflating: trump_photos/59.jpg
#   inflating: trump_photos/590.jpg
#   inflating: trump_photos/592.jpg
#   inflating: trump_photos/594.jpg
#   inflating: trump_photos/60.jpg
#   inflating: trump_photos/606.jpg
#   inflating: trump_photos/608.jpg
#   inflating: trump_photos/61.jpg
#   inflating: trump_photos/611.jpg
#   inflating: trump_photos/620.jpg
#   inflating: trump_photos/629.jpg
#   inflating: trump_photos/631.jpg
#   inflating: trump_photos/638.jpg
#   inflating: trump_photos/642.jpg
#   inflating: trump_photos/645.jpg
#   inflating: trump_photos/647.jpg
#   inflating: trump_photos/648.jpg
#   inflating: trump_photos/649.jpg
#   inflating: trump_photos/650.jpg
#   inflating: trump_photos/651.jpg
#   inflating: trump_photos/652.jpg
#   inflating: trump_photos/653.jpg
#   inflating: trump_photos/654.jpg
#   inflating: trump_photos/656.jpg
#   inflating: trump_photos/659.jpg
#   inflating: trump_photos/665.jpg
#   inflating: trump_photos/667.jpg
#   inflating: trump_photos/67.jpg
#   inflating: trump_photos/670.jpg
#   inflating: trump_photos/672.jpg
#   inflating: trump_photos/674.jpg
#   inflating: trump_photos/675.jpg
#   inflating: trump_photos/682.jpg
#   inflating: trump_photos/687.jpg
#   inflating: trump_photos/695.jpg
#   inflating: trump_photos/697.jpg
#   inflating: trump_photos/698.jpg
#   inflating: trump_photos/701.jpg
#   inflating: trump_photos/708.jpg
#   inflating: trump_photos/711.jpg
#   inflating: trump_photos/714.jpg
#   inflating: trump_photos/717.jpg
#   inflating: trump_photos/721.jpg
#   inflating: trump_photos/723.jpg
#   inflating: trump_photos/727.jpg
#   inflating: trump_photos/729.jpg
#   inflating: trump_photos/741.jpg
#   inflating: trump_photos/742.jpg
#   inflating: trump_photos/748.jpg
#   inflating: trump_photos/749.jpg
#   inflating: trump_photos/75.jpg
#   inflating: trump_photos/751.jpg
#   inflating: trump_photos/756.jpg
#   inflating: trump_photos/761.jpg
#   inflating: trump_photos/763.jpg
#   inflating: trump_photos/765.jpg
#   inflating: trump_photos/768.jpg
#   inflating: trump_photos/77.jpg
#   inflating: trump_photos/770.jpg
#   inflating: trump_photos/773.jpg
#   inflating: trump_photos/776.jpg
#   inflating: trump_photos/780.jpg
#   inflating: trump_photos/781.jpg
#   inflating: trump_photos/783.jpg
#   inflating: trump_photos/784.jpg
#   inflating: trump_photos/786.jpg
#   inflating: trump_photos/787.jpg
#   inflating: trump_photos/789.jpg
#   inflating: trump_photos/791.jpg
#   inflating: trump_photos/792.jpg
#   inflating: trump_photos/793.jpg
#   inflating: trump_photos/80.jpg
#   inflating: trump_photos/804.jpg
#   inflating: trump_photos/806.jpg
#   inflating: trump_photos/808.jpg
#   inflating: trump_photos/809.jpg
#   inflating: trump_photos/81.jpg
#   inflating: trump_photos/811.jpg
#   inflating: trump_photos/814.jpg
#   inflating: trump_photos/815.jpg
#   inflating: trump_photos/818.jpg
#   inflating: trump_photos/820.jpg
#   inflating: trump_photos/823.jpg
#   inflating: trump_photos/826.jpg
#   inflating: trump_photos/827.jpg
#   inflating: trump_photos/83.jpg
#   inflating: trump_photos/830.jpg
#   inflating: trump_photos/836.jpg
#   inflating: trump_photos/837.jpg
#   inflating: trump_photos/842.jpg
#   inflating: trump_photos/843.jpg
#   inflating: trump_photos/844.jpg
#   inflating: trump_photos/845.jpg
#   inflating: trump_photos/848.jpg
#   inflating: trump_photos/849.jpg
#   inflating: trump_photos/85.jpg
#   inflating: trump_photos/853.jpg
#   inflating: trump_photos/854.jpg
#   inflating: trump_photos/856.jpg
#   inflating: trump_photos/858.jpg
#   inflating: trump_photos/86.jpg
#   inflating: trump_photos/861.jpg
#   inflating: trump_photos/863.jpg
#   inflating: trump_photos/864.jpg
#   inflating: trump_photos/871.jpg
#   inflating: trump_photos/876.jpg
#   inflating: trump_photos/879.jpg
#   inflating: trump_photos/886.jpg
#   inflating: trump_photos/887.jpg
#   inflating: trump_photos/888.jpg
#   inflating: trump_photos/894.jpg
#   inflating: trump_photos/898.jpg
#   inflating: trump_photos/899.jpg
#   inflating: trump_photos/90.jpg
#   inflating: trump_photos/904.jpg
#   inflating: trump_photos/906.jpg
#   inflating: trump_photos/909.jpg
#   inflating: trump_photos/910.jpg
#   inflating: trump_photos/914.jpg
#   inflating: trump_photos/916.jpg
#   inflating: trump_photos/92.jpg
#   inflating: trump_photos/922.jpg
#   inflating: trump_photos/925.jpg
#   inflating: trump_photos/933.jpg
#   inflating: trump_photos/94.jpg
#   inflating: trump_photos/940.jpg
#   inflating: trump_photos/949.jpg
#   inflating: trump_photos/951.jpg
#   inflating: trump_photos/953.jpg
#   inflating: trump_photos/954.jpg
#   inflating: trump_photos/955.jpg
#   inflating: trump_photos/959.jpg
#   inflating: trump_photos/96.jpg
#   inflating: trump_photos/961.jpg
#   inflating: trump_photos/966.jpg
#   inflating: trump_photos/967.jpg
#   inflating: trump_photos/969.jpg
#   inflating: trump_photos/970.jpg
#   inflating: trump_photos/971.jpg
#   inflating: trump_photos/974.jpg
#   inflating: trump_photos/982.jpg
#   inflating: trump_photos/983.jpg
#   inflating: trump_photos/996.jpg
#   inflating: trump_photos/998.jpg
#   inflating: trump_photos/999.jpg
#   inflating: trump_photos/1223.jpg
#   inflating: trump_photos/1371.jpg
#   inflating: trump_photos/1519.jpg
#   inflating: trump_photos/1640.jpg
#   inflating: trump_photos/1647.jpg
#   inflating: trump_photos/1730.jpg
#   inflating: trump_photos/1764.jpg
#   inflating: trump_photos/179.jpg
#   inflating: trump_photos/1924.jpg
#   inflating: trump_photos/2019.jpg
#   inflating: trump_photos/204.jpg
#   inflating: trump_photos/2182.jpg
#   inflating: trump_photos/2468.jpg
#   inflating: trump_photos/2617.jpg
#   inflating: trump_photos/270.jpg
#   inflating: trump_photos/283.jpg
#   inflating: trump_photos/3018.jpg
#   inflating: trump_photos/379.jpg
#   inflating: trump_photos/477.jpg
#   inflating: trump_photos/552.jpg

# %%
# !rm trump.zip

# %% [markdown]
# install autocrop to crop faces

# %%
# !pip install autocrop
# Out:
# Collecting autocrop
#   Downloading https://files.pythonhosted.org/packages/b0/b5/691010a64275421717d037cf3c3c22df8ec7c26e8641a5e01d9443e4e4f4/autocrop-0.3.1.tar.gz (155kB)
#     100% |████████████████████████████████| 163kB 6.8MB/s
# Requirement already satisfied: numpy>=1.10 in /usr/local/lib/python3.6/dist-packages (from autocrop) (1.14.6)
# Requirement already satisfied: opencv-python<4,>=3 in /usr/local/lib/python3.6/dist-packages (from autocrop) (3.4.5.20)
# Building wheels for collected packages: autocrop
#   Building wheel for autocrop (setup.py) ... done
#   Stored in directory: /root/.cache/pip/wheels/fe/22/7b/9b262766205bc222f437ef32a5ca48427be8e41b87254afbea
# Successfully built autocrop
# Installing collected packages: autocrop
# Successfully installed autocrop-0.3.1

# %% [markdown]
# Make directory for faces and rejected faces and then run autocrop

# %%
cd ..
# Out:
# /content/stylegan

# %%
# !mkdir Faces

# %%
# !mkdir Rejects

# %%
# !autocrop -i /content/stylegan/portraitbig/trump_photos/ -o /content/stylegan/Faces/ -w 512 -H 512 --facePercent 50 -r /content/stylegan/Rejects/
# Out:
# Processing images in folder: /content/stylegan/portraitbig/trump_photos
# Face detected:    /content/stylegan/Faces/2977.jpg
# Face detected:    /content/stylegan/Faces/578.jpg
# No face detected: /content/stylegan/Rejects/2644.jpg
# No face detected: /content/stylegan/Rejects/1918.jpg
# Face detected:    /content/stylegan/Faces/2206.jpg
# Face detected:    /content/stylegan/Faces/2512.jpg
# No face detected: /content/stylegan/Rejects/2920.jpg
# Face detected:    /content/stylegan/Faces/900.jpg
# Face detected:    /content/stylegan/Faces/2479.jpg
# No face detected: /content/stylegan/Rejects/751.jpg
# Face detected:    /content/stylegan/Faces/1836.jpg
# Face detected:    /content/stylegan/Faces/2671.jpg
# Face detected:    /content/stylegan/Faces/2254.jpg
# No face detected: /content/stylegan/Rejects/2270.jpg
# No face detected: /content/stylegan/Rejects/2986.jpg
# Face detected:    /content/stylegan/Faces/1582.jpg
# Face detected:    /content/stylegan/Faces/1644.jpg
# Face detected:    /content/stylegan/Faces/1652.jpg
# Face detected:    /content/stylegan/Faces/2820.jpg
# Face detected:    /content/stylegan/Faces/529.jpg
# No face detected: /content/stylegan/Rejects/1561.jpg
# Face detected:    /content/stylegan/Faces/383.jpg
# Face detected:    /content/stylegan/Faces/1054.jpg
# No face detected: /content/stylegan/Rejects/558.jpg
# No face detected: /content/stylegan/Rejects/2718.jpg
# Face detected:    /content/stylegan/Faces/1982.jpg
# No face detected: /content/stylegan/Rejects/213.jpg
# No face detected: /content/stylegan/Rejects/1310.jpg
# Face detected:    /content/stylegan/Faces/142.jpg
# No face detected: /content/stylegan/Rejects/2655.jpg
# No face detected: /content/stylegan/Rejects/1613.jpg
# Face detected:    /content/stylegan/Faces/1098.jpg
# Face detected:    /content/stylegan/Faces/821.jpg
# Face detected:    /content/stylegan/Faces/2454.jpg
# No face detected: /content/stylegan/Rejects/1469.jpg
# Face detected:    /content/stylegan/Faces/1215.jpg
# Face detected:    /content/stylegan/Faces/124.jpg
# Face detected:    /content/stylegan/Faces/528.jpg
# Face detected:    /content/stylegan/Faces/1725.jpg
# No face detected: /content/stylegan/Rejects/991.jpg
# No face detected: /content/stylegan/Rejects/1947.jpg
# Face detected:    /content/stylegan/Faces/691.jpg
# Face detected:    /content/stylegan/Faces/2456.jpg
# Face detected:    /content/stylegan/Faces/596.jpg
# Face detected:    /content/stylegan/Faces/2453.jpg
# Face detected:    /content/stylegan/Faces/2657.jpg
# Face detected:    /content/stylegan/Faces/2000.jpg
# Face detected:    /content/stylegan/Faces/1145.jpg
# Face detected:    /content/stylegan/Faces/128.jpg
# Face detected:    /content/stylegan/Faces/1474.jpg
# Face detected:    /content/stylegan/Faces/1659.jpg
# Face detected:    /content/stylegan/Faces/2934.jpg
# Face detected:    /content/stylegan/Faces/2077.jpg
# Face detected:    /content/stylegan/Faces/1949.jpg
# Face detected:    /content/stylegan/Faces/1559.jpg
# Face detected:    /content/stylegan/Faces/438.jpg
# No face detected: /content/stylegan/Rejects/1570.jpg
# libpng warning: iCCP: known incorrect sRGB profile
# Face detected:    /content/stylegan/Faces/2936.jpg
# No face detected: /content/stylegan/Rejects/253.jpg
# Face detected:    /content/stylegan/Faces/2250.jpg
# No face detected: /content/stylegan/Rejects/2873.jpg
# Face detected:    /content/stylegan/Faces/1870.jpg
# Face detected:    /content/stylegan/Faces/1349.jpg
# No face detected: /content/stylegan/Rejects/1452.jpg
# Face detected:    /content/stylegan/Faces/516.jpg
# No face detected: /content/stylegan/Rejects/1651.jpg
# Face detected:    /content/stylegan/Faces/1194.jpg
# No face detected: /content/stylegan/Rejects/2064.jpg
# Face detected:    /content/stylegan/Faces/1122.jpg
# Face detected:    /content/stylegan/Faces/369.jpg
# Face detected:    /content/stylegan/Faces/266.jpg
# No face detected: /content/stylegan/Rejects/2702.jpg
# Face detected:    /content/stylegan/Faces/2316.jpg
# Face detected:    /content/stylegan/Faces/2813.jpg
# Face detected:    /content/stylegan/Faces/2295.jpg
# No face detected: /content/stylegan/Rejects/2154.jpg
# No face detected: /content/stylegan/Rejects/2861.jpg
# Face detected:    /content/stylegan/Faces/1983.jpg
# libpng warning: iCCP: known incorrect sRGB profile
# Face detected:    /content/stylegan/Faces/2256.jpg
# Face detected:    /content/stylegan/Faces/2231.jpg
# Face detected:    /content/stylegan/Faces/2966.jpg
# No face detected: /content/stylegan/Rejects/885.jpg
# Face detected:    /content/stylegan/Faces/108.jpg
# Face detected:    /content/stylegan/Faces/1085.jpg
# Face detected:    /content/stylegan/Faces/2436.jpg
# No face detected: /content/stylegan/Rejects/236.jpg
# Face detected:    /content/stylegan/Faces/498.jpg
# Face detected:    /content/stylegan/Faces/2404.jpg
# Face detected:    /content/stylegan/Faces/327.jpg
# Face detected:    /content/stylegan/Faces/1233.jpg
# Face detected:    /content/stylegan/Faces/2032.jpg
# Face detected:    /content/stylegan/Faces/1354.jpg
# Face detected:    /content/stylegan/Faces/223.jpg
# No face detected: /content/stylegan/Rejects/442.jpg
# Face detected:    /content/stylegan/Faces/309.jpg
# Face detected:    /content/stylegan/Faces/2497.jpg
# Face detected:    /content/stylegan/Faces/659.jpg
# Face detected:    /content/stylegan/Faces/1295.jpg
# No face detected: /content/stylegan/Rejects/1372.jpg
# Face detected:    /content/stylegan/Faces/756.jpg
# Face detected:    /content/stylegan/Faces/1508.jpg
# Face detected:    /content/stylegan/Faces/1591.jpg
# No face detected: /content/stylegan/Rejects/1618.jpg
# Face detected:    /content/stylegan/Faces/838.jpg
# Face detected:    /content/stylegan/Faces/2423.jpg
# Face detected:    /content/stylegan/Faces/2933.jpg
# Face detected:    /content/stylegan/Faces/2460.jpg
# Face detected:    /content/stylegan/Faces/1231.jpg
# No face detected: /content/stylegan/Rejects/1028.jpg
# Face detected:    /content/stylegan/Faces/2164.jpg
# Face detected:    /content/stylegan/Faces/650.jpg
# Face detected:    /content/stylegan/Faces/118.jpg
# Face detected:    /content/stylegan/Faces/1796.jpg
# Face detected:    /content/stylegan/Faces/1472.jpg
# Face detected:    /content/stylegan/Faces/1770.jpg
# Face detected:    /content/stylegan/Faces/2754.jpg
# Face detected:    /content/stylegan/Faces/1520.jpg
# Face detected:    /content/stylegan/Faces/2127.jpg
# Face detected:    /content/stylegan/Faces/204.jpg
# Face detected:    /content/stylegan/Faces/1419.jpg
# Face detected:    /content/stylegan/Faces/157.jpg
# No face detected: /content/stylegan/Rejects/1330.jpg
# No face detected: /content/stylegan/Rejects/2183.jpg
# Face detected:    /content/stylegan/Faces/1180.jpg
# Face detected:    /content/stylegan/Faces/1974.jpg
# No face detected: /content/stylegan/Rejects/1392.jpg
# Face detected:    /content/stylegan/Faces/1418.jpg
# Face detected:    /content/stylegan/Faces/1660.jpg
# No face detected: /content/stylegan/Rejects/257.jpg
# No face detected: /content/stylegan/Rejects/2388.jpg
# No face detected: /content/stylegan/Rejects/1844.jpg
# Face detected:    /content/stylegan/Faces/1615.jpg
# Face detected:    /content/stylegan/Faces/2848.jpg
# Face detected:    /content/stylegan/Faces/2428.jpg
# No face detected: /content/stylegan/Rejects/2014.jpg
# No face detected: /content/stylegan/Rejects/2689.jpg
# Face detected:    /content/stylegan/Faces/2432.jpg
# Face detected:    /content/stylegan/Faces/2455.jpg
# Face detected:    /content/stylegan/Faces/487.jpg
# No face detected: /content/stylegan/Rejects/710.jpg
# No face detected: /content/stylegan/Rejects/551.jpg
# Face detected:    /content/stylegan/Faces/1285.jpg
# Face detected:    /content/stylegan/Faces/2812.jpg
# Face detected:    /content/stylegan/Faces/1059.jpg
# Face detected:    /content/stylegan/Faces/961.jpg
# Face detected:    /content/stylegan/Faces/263.jpg
# Face detected:    /content/stylegan/Faces/2653.jpg
# Face detected:    /content/stylegan/Faces/2187.jpg
# No face detected: /content/stylegan/Rejects/2780.jpg
# Face detected:    /content/stylegan/Faces/493.jpg
# Face detected:    /content/stylegan/Faces/647.jpg
# No face detected: /content/stylegan/Rejects/653.jpg
# No face detected: /content/stylegan/Rejects/2296.jpg
# No face detected: /content/stylegan/Rejects/997.jpg
# Face detected:    /content/stylegan/Faces/233.jpg
# No face detected: /content/stylegan/Rejects/2385.jpg
# Face detected:    /content/stylegan/Faces/1755.jpg
# Face detected:    /content/stylegan/Faces/104.jpg
# Face detected:    /content/stylegan/Faces/1351.jpg
# Face detected:    /content/stylegan/Faces/1034.jpg
# No face detected: /content/stylegan/Rejects/357.jpg
# Face detected:    /content/stylegan/Faces/2493.jpg
# Face detected:    /content/stylegan/Faces/1471.jpg
# Face detected:    /content/stylegan/Faces/1588.jpg
# Face detected:    /content/stylegan/Faces/2171.jpg
# Face detected:    /content/stylegan/Faces/2725.jpg
# Face detected:    /content/stylegan/Faces/2182.jpg
# No face detected: /content/stylegan/Rejects/2980.jpg
# Face detected:    /content/stylegan/Faces/2322.jpg
# No face detected: /content/stylegan/Rejects/347.jpg
# No face detected: /content/stylegan/Rejects/2368.jpg
# Face detected:    /content/stylegan/Faces/30.jpg
# Face detected:    /content/stylegan/Faces/1527.jpg
# Face detected:    /content/stylegan/Faces/2241.jpg
# Face detected:    /content/stylegan/Faces/2974.jpg
# Face detected:    /content/stylegan/Faces/673.jpg
# Face detected:    /content/stylegan/Faces/297.jpg
# Face detected:    /content/stylegan/Faces/1208.jpg
# Face detected:    /content/stylegan/Faces/1382.jpg
# Face detected:    /content/stylegan/Faces/365.jpg
# Face detected:    /content/stylegan/Faces/2007.jpg
# Face detected:    /content/stylegan/Faces/1032.jpg
# Face detected:    /content/stylegan/Faces/2022.jpg
# No face detected: /content/stylegan/Rejects/654.jpg
# Face detected:    /content/stylegan/Faces/66.jpg
# Face detected:    /content/stylegan/Faces/2165.jpg
# No face detected: /content/stylegan/Rejects/2106.jpg
# Face detected:    /content/stylegan/Faces/2191.jpg
# Face detected:    /content/stylegan/Faces/1000.jpg
# No face detected: /content/stylegan/Rejects/1049.jpg
# Face detected:    /content/stylegan/Faces/2945.jpg
# Face detected:    /content/stylegan/Faces/684.jpg
# Face detected:    /content/stylegan/Faces/1414.jpg
# No face detected: /content/stylegan/Rejects/1907.jpg
# Face detected:    /content/stylegan/Faces/628.jpg
# Face detected:    /content/stylegan/Faces/1880.jpg
# Face detected:    /content/stylegan/Faces/1.jpg
# Face detected:    /content/stylegan/Faces/918.jpg
# Face detected:    /content/stylegan/Faces/1692.jpg
# Face detected:    /content/stylegan/Faces/1791.jpg
# Face detected:    /content/stylegan/Faces/899.jpg
# Face detected:    /content/stylegan/Faces/1342.jpg
# Face detected:    /content/stylegan/Faces/2337.jpg
# No face detected: /content/stylegan/Rejects/2198.jpg
# Face detected:    /content/stylegan/Faces/861.jpg
# No face detected: /content/stylegan/Rejects/1258.jpg
# Face detected:    /content/stylegan/Faces/2781.jpg
# Face detected:    /content/stylegan/Faces/2021.jpg
# Face detected:    /content/stylegan/Faces/2012.jpg
# Face detected:    /content/stylegan/Faces/2380.jpg
# Face detected:    /content/stylegan/Faces/2682.jpg
# No face detected: /content/stylegan/Rejects/2537.jpg
# Face detected:    /content/stylegan/Faces/1514.jpg
# No face detected: /content/stylegan/Rejects/235.jpg
# Face detected:    /content/stylegan/Faces/2087.jpg
# No face detected: /content/stylegan/Rejects/1432.jpg
# No face detected: /content/stylegan/Rejects/80.jpg
# Face detected:    /content/stylegan/Faces/1805.jpg
# No face detected: /content/stylegan/Rejects/926.jpg
# Face detected:    /content/stylegan/Faces/2992.jpg
# Face detected:    /content/stylegan/Faces/1167.jpg
# Face detected:    /content/stylegan/Faces/773.jpg
# Face detected:    /content/stylegan/Faces/2035.jpg
# Face detected:    /content/stylegan/Faces/1959.jpg
# No face detected: /content/stylegan/Rejects/100.jpg
# No face detected: /content/stylegan/Rejects/2125.jpg
# No face detected: /content/stylegan/Rejects/537.jpg
# No face detected: /content/stylegan/Rejects/2818.jpg
# Face detected:    /content/stylegan/Faces/1731.jpg
# No face detected: /content/stylegan/Rejects/769.jpg
# Face detected:    /content/stylegan/Faces/166.jpg
# Face detected:    /content/stylegan/Faces/2882.jpg
# No face detected: /content/stylegan/Rejects/2962.jpg
# Face detected:    /content/stylegan/Faces/580.jpg
# No face detected: /content/stylegan/Rejects/1133.jpg
# Face detected:    /content/stylegan/Faces/2136.jpg
# No face detected: /content/stylegan/Rejects/62.jpg
# Face detected:    /content/stylegan/Faces/804.jpg
# No face detected: /content/stylegan/Rejects/1779.jpg
# Face detected:    /content/stylegan/Faces/811.jpg
# Face detected:    /content/stylegan/Faces/539.jpg
# Face detected:    /content/stylegan/Faces/1377.jpg
# No face detected: /content/stylegan/Rejects/2002.jpg
# Face detected:    /content/stylegan/Faces/2059.jpg
# Face detected:    /content/stylegan/Faces/2257.jpg
# No face detected: /content/stylegan/Rejects/724.jpg
# Face detected:    /content/stylegan/Faces/1416.jpg
# Face detected:    /content/stylegan/Faces/2389.jpg
# Face detected:    /content/stylegan/Faces/1333.jpg
# Face detected:    /content/stylegan/Faces/127.jpg
# Face detected:    /content/stylegan/Faces/2417.jpg
# Face detected:    /content/stylegan/Faces/1281.jpg
# Face detected:    /content/stylegan/Faces/2384.jpg
# No face detected: /content/stylegan/Rejects/206.jpg
# Face detected:    /content/stylegan/Faces/216.jpg
# Face detected:    /content/stylegan/Faces/890.jpg
# Face detected:    /content/stylegan/Faces/878.jpg
# Face detected:    /content/stylegan/Faces/1246.jpg
# Face detected:    /content/stylegan/Faces/1896.jpg
# Face detected:    /content/stylegan/Faces/1191.jpg
# No face detected: /content/stylegan/Rejects/2606.jpg
# Face detected:    /content/stylegan/Faces/1531.jpg
# No face detected: /content/stylegan/Rejects/247.jpg
# Face detected:    /content/stylegan/Faces/2370.jpg
# No face detected: /content/stylegan/Rejects/32.jpg
# Face detected:    /content/stylegan/Faces/159.jpg
# Face detected:    /content/stylegan/Faces/2173.jpg
# Face detected:    /content/stylegan/Faces/1943.jpg
# Face detected:    /content/stylegan/Faces/449.jpg
# No face detected: /content/stylegan/Rejects/271.jpg
# No face detected: /content/stylegan/Rejects/957.jpg
# No face detected: /content/stylegan/Rejects/2784.jpg
# Face detected:    /content/stylegan/Faces/1078.jpg
# Face detected:    /content/stylegan/Faces/1018.jpg
# Face detected:    /content/stylegan/Faces/3008.jpg
# No face detected: /content/stylegan/Rejects/2627.jpg
# Face detected:    /content/stylegan/Faces/924.jpg
# No face detected: /content/stylegan/Rejects/2632.jpg
# Face detected:    /content/stylegan/Faces/92.jpg
# No face detected: /content/stylegan/Rejects/2673.jpg
# Face detected:    /content/stylegan/Faces/1407.jpg
# Face detected:    /content/stylegan/Faces/1839.jpg
# Face detected:    /content/stylegan/Faces/2967.jpg
# Face detected:    /content/stylegan/Faces/1388.jpg
# No face detected: /content/stylegan/Rejects/2095.jpg
# No face detected: /content/stylegan/Rejects/2946.jpg
# Face detected:    /content/stylegan/Faces/16.jpg
# No face detected: /content/stylegan/Rejects/1704.jpg
# No face detected: /content/stylegan/Rejects/1443.jpg
# Face detected:    /content/stylegan/Faces/411.jpg
# No face detected: /content/stylegan/Rejects/1545.jpg
# Face detected:    /content/stylegan/Faces/492.jpg
# Face detected:    /content/stylegan/Faces/2072.jpg
# Face detected:    /content/stylegan/Faces/2395.jpg
# Face detected:    /content/stylegan/Faces/941.jpg
# No face detected: /content/stylegan/Rejects/1884.jpg
# No face detected: /content/stylegan/Rejects/2197.jpg
# No face detected: /content/stylegan/Rejects/31.jpg
# Face detected:    /content/stylegan/Faces/1198.jpg
# Face detected:    /content/stylegan/Faces/1780.jpg
# No face detected: /content/stylegan/Rejects/1137.jpg
# Face detected:    /content/stylegan/Faces/2275.jpg
# No face detected: /content/stylegan/Rejects/288.jpg
# Face detected:    /content/stylegan/Faces/2520.jpg
# No face detected: /content/stylegan/Rejects/490.jpg
# Face detected:    /content/stylegan/Faces/45.jpg
# Face detected:    /content/stylegan/Faces/417.jpg
# Face detected:    /content/stylegan/Faces/1721.jpg
# Face detected:    /content/stylegan/Faces/2132.jpg
# Face detected:    /content/stylegan/Faces/1199.jpg
# No face detected: /content/stylegan/Rejects/1730.jpg
# No face detected: /content/stylegan/Rejects/426.jpg
# Face detected:    /content/stylegan/Faces/1975.jpg
# No face detected: /content/stylegan/Rejects/1050.jpg
# Face detected:    /content/stylegan/Faces/477.jpg
# Face detected:    /content/stylegan/Faces/2141.jpg
# No face detected: /content/stylegan/Rejects/542.jpg
# Face detected:    /content/stylegan/Faces/988.jpg
# Face detected:    /content/stylegan/Faces/565.jpg
# No face detected: /content/stylegan/Rejects/2681.jpg
# Face detected:    /content/stylegan/Faces/17.jpg
# No face detected: /content/stylegan/Rejects/1243.jpg
# No face detected: /content/stylegan/Rejects/1916.jpg
# Face detected:    /content/stylegan/Faces/1565.jpg
# Face detected:    /content/stylegan/Faces/445.jpg
# Face detected:    /content/stylegan/Faces/238.jpg
# Face detected:    /content/stylegan/Faces/396.jpg
# Face detected:    /content/stylegan/Faces/986.jpg
# Face detected:    /content/stylegan/Faces/2342.jpg
# No face detected: /content/stylegan/Rejects/2751.jpg
# Face detected:    /content/stylegan/Faces/2576.jpg
# Face detected:    /content/stylegan/Faces/2569.jpg
# Face detected:    /content/stylegan/Faces/2079.jpg
# Face detected:    /content/stylegan/Faces/1817.jpg
# Face detected:    /content/stylegan/Faces/2712.jpg
# Face detected:    /content/stylegan/Faces/546.jpg
# No face detected: /content/stylegan/Rejects/2314.jpg
# No face detected: /content/stylegan/Rejects/175.jpg
# Face detected:    /content/stylegan/Faces/21.jpg
# Face detected:    /content/stylegan/Faces/2560.jpg
# No face detected: /content/stylegan/Rejects/1478.jpg
# Face detected:    /content/stylegan/Faces/1405.jpg
# Face detected:    /content/stylegan/Faces/1355.jpg
# Face detected:    /content/stylegan/Faces/3013.jpg
# No face detected: /content/stylegan/Rejects/1210.jpg
# Face detected:    /content/stylegan/Faces/196.jpg
# Face detected:    /content/stylegan/Faces/835.jpg
# Face detected:    /content/stylegan/Faces/2326.jpg
# Face detected:    /content/stylegan/Faces/1535.jpg
# No face detected: /content/stylegan/Rejects/1209.jpg
# Face detected:    /content/stylegan/Faces/1230.jpg
# No face detected: /content/stylegan/Rejects/1933.jpg
# Face detected:    /content/stylegan/Faces/91.jpg
# Face detected:    /content/stylegan/Faces/1493.jpg
# No face detected: /content/stylegan/Rejects/975.jpg
# Face detected:    /content/stylegan/Faces/2607.jpg
# Face detected:    /content/stylegan/Faces/928.jpg
# Face detected:    /content/stylegan/Faces/2573.jpg
# Face detected:    /content/stylegan/Faces/2883.jpg
# Face detected:    /content/stylegan/Faces/2799.jpg
# Face detected:    /content/stylegan/Faces/543.jpg
# Face detected:    /content/stylegan/Faces/1858.jpg
# No face detected: /content/stylegan/Rejects/2006.jpg
# Face detected:    /content/stylegan/Faces/2612.jpg
# No face detected: /content/stylegan/Rejects/2352.jpg
# Face detected:    /content/stylegan/Faces/1043.jpg
# No face detected: /content/stylegan/Rejects/1147.jpg
# Face detected:    /content/stylegan/Faces/896.jpg
# Face detected:    /content/stylegan/Faces/329.jpg
# No face detected: /content/stylegan/Rejects/1038.jpg
# Face detected:    /content/stylegan/Faces/1308.jpg
# No face detected: /content/stylegan/Rejects/2362.jpg
# Face detected:    /content/stylegan/Faces/1683.jpg
# Face detected:    /content/stylegan/Faces/3001.jpg
# No face detected: /content/stylegan/Rejects/779.jpg
# Face detected:    /content/stylegan/Faces/911.jpg
# Face detected:    /content/stylegan/Faces/2677.jpg
# Face detected:    /content/stylegan/Faces/1460.jpg
# Face detected:    /content/stylegan/Faces/1938.jpg
# No face detected: /content/stylegan/Rejects/1108.jpg
# Face detected:    /content/stylegan/Faces/1331.jpg
# Face detected:    /content/stylegan/Faces/1201.jpg
# No face detected: /content/stylegan/Rejects/1102.jpg
# Face detected:    /content/stylegan/Faces/1083.jpg
# Face detected:    /content/stylegan/Faces/2213.jpg
# Face detected:    /content/stylegan/Faces/2330.jpg
# No face detected: /content/stylegan/Rejects/2908.jpg
# Face detected:    /content/stylegan/Faces/2110.jpg
# Face detected:    /content/stylegan/Faces/1772.jpg
# Face detected:    /content/stylegan/Faces/2704.jpg
# Face detected:    /content/stylegan/Faces/1268.jpg
# Face detected:    /content/stylegan/Faces/1267.jpg
# No face detected: /content/stylegan/Rejects/105.jpg
# Face detected:    /content/stylegan/Faces/1095.jpg
# No face detected: /content/stylegan/Rejects/186.jpg
# Face detected:    /content/stylegan/Faces/1139.jpg
# No face detected: /content/stylegan/Rejects/1429.jpg
# Face detected:    /content/stylegan/Faces/1532.jpg
# Face detected:    /content/stylegan/Faces/2016.jpg
# Face detected:    /content/stylegan/Faces/541.jpg
# Face detected:    /content/stylegan/Faces/1902.jpg
# No face detected: /content/stylegan/Rejects/1650.jpg
# No face detected: /content/stylegan/Rejects/1160.jpg
# No face detected: /content/stylegan/Rejects/1075.jpg
# No face detected: /content/stylegan/Rejects/2358.jpg
# Face detected:    /content/stylegan/Faces/2038.jpg
# Face detected:    /content/stylegan/Faces/2600.jpg
# No face detected: /content/stylegan/Rejects/3020.jpg
# Face detected:    /content/stylegan/Faces/2348.jpg
# No face detected: /content/stylegan/Rejects/2611.jpg
# Face detected:    /content/stylegan/Faces/2170.jpg
# Face detected:    /content/stylegan/Faces/2103.jpg
# No face detected: /content/stylegan/Rejects/1610.jpg
# Face detected:    /content/stylegan/Faces/138.jpg
# Face detected:    /content/stylegan/Faces/252.jpg
# Face detected:    /content/stylegan/Faces/1026.jpg
# Face detected:    /content/stylegan/Faces/2782.jpg
# Face detected:    /content/stylegan/Faces/2119.jpg
# Face detected:    /content/stylegan/Faces/1044.jpg
# Face detected:    /content/stylegan/Faces/2700.jpg
# Face detected:    /content/stylegan/Faces/1909.jpg
# Face detected:    /content/stylegan/Faces/2108.jpg
# Face detected:    /content/stylegan/Faces/1302.jpg
# Face detected:    /content/stylegan/Faces/1859.jpg
# No face detected: /content/stylegan/Rejects/61.jpg
# Face detected:    /content/stylegan/Faces/1576.jpg
# Face detected:    /content/stylegan/Faces/513.jpg
# Face detected:    /content/stylegan/Faces/2374.jpg
# No face detected: /content/stylegan/Rejects/852.jpg
# No face detected: /content/stylegan/Rejects/434.jpg
# Face detected:    /content/stylegan/Faces/540.jpg
# No face detected: /content/stylegan/Rejects/530.jpg
# Face detected:    /content/stylegan/Faces/2054.jpg
# No face detected: /content/stylegan/Rejects/1666.jpg
# No face detected: /content/stylegan/Rejects/687.jpg
# Face detected:    /content/stylegan/Faces/2823.jpg
# No face detected: /content/stylegan/Rejects/1524.jpg
# No face detected: /content/stylegan/Rejects/1678.jpg
# Face detected:    /content/stylegan/Faces/1879.jpg
# No face detected: /content/stylegan/Rejects/666.jpg
# No face detected: /content/stylegan/Rejects/1060.jpg
# No face detected: /content/stylegan/Rejects/870.jpg
# Face detected:    /content/stylegan/Faces/2175.jpg
# Face detected:    /content/stylegan/Faces/2587.jpg
# Face detected:    /content/stylegan/Faces/728.jpg
# Face detected:    /content/stylegan/Faces/2753.jpg
# Face detected:    /content/stylegan/Faces/2926.jpg
# Face detected:    /content/stylegan/Faces/2287.jpg
# Face detected:    /content/stylegan/Faces/579.jpg
# No face detected: /content/stylegan/Rejects/2549.jpg
# Face detected:    /content/stylegan/Faces/1436.jpg
# Face detected:    /content/stylegan/Faces/1674.jpg
# No face detected: /content/stylegan/Rejects/1045.jpg
# No face detected: /content/stylegan/Rejects/1073.jpg
# Face detected:    /content/stylegan/Faces/2970.jpg
# Face detected:    /content/stylegan/Faces/2415.jpg
# Face detected:    /content/stylegan/Faces/1403.jpg
# Face detected:    /content/stylegan/Faces/2482.jpg
# Face detected:    /content/stylegan/Faces/119.jpg
# Face detected:    /content/stylegan/Faces/1170.jpg
# Face detected:    /content/stylegan/Faces/2775.jpg
# No face detected: /content/stylegan/Rejects/1695.jpg
# Face detected:    /content/stylegan/Faces/1394.jpg
# No face detected: /content/stylegan/Rejects/2160.jpg
# No face detected: /content/stylegan/Rejects/1513.jpg
# No face detected: /content/stylegan/Rejects/1069.jpg
# Face detected:    /content/stylegan/Faces/459.jpg
# Face detected:    /content/stylegan/Faces/2527.jpg
# Face detected:    /content/stylegan/Faces/1754.jpg
# Face detected:    /content/stylegan/Faces/2468.jpg
# No face detected: /content/stylegan/Rejects/18.jpg
# Face detected:    /content/stylegan/Faces/2863.jpg
# Face detected:    /content/stylegan/Faces/503.jpg
# No face detected: /content/stylegan/Rejects/218.jpg
# Face detected:    /content/stylegan/Faces/2504.jpg
# No face detected: /content/stylegan/Rejects/897.jpg
# Face detected:    /content/stylegan/Faces/2219.jpg
# No face detected: /content/stylegan/Rejects/1905.jpg
# No face detected: /content/stylegan/Rejects/916.jpg
# Face detected:    /content/stylegan/Faces/2180.jpg
# Face detected:    /content/stylegan/Faces/2717.jpg
# Face detected:    /content/stylegan/Faces/2017.jpg
# Face detected:    /content/stylegan/Faces/2240.jpg
# No face detected: /content/stylegan/Rejects/2188.jpg
# Face detected:    /content/stylegan/Faces/2859.jpg
# Face detected:    /content/stylegan/Faces/95.jpg
# Face detected:    /content/stylegan/Faces/868.jpg
# Face detected:    /content/stylegan/Faces/2433.jpg
# Face detected:    /content/stylegan/Faces/2462.jpg
# Face detected:    /content/stylegan/Faces/205.jpg
# Face detected:    /content/stylegan/Faces/1675.jpg
# No face detected: /content/stylegan/Rejects/2978.jpg
# Face detected:    /content/stylegan/Faces/1569.jpg
# Face detected:    /content/stylegan/Faces/2577.jpg
# No face detected: /content/stylegan/Rejects/171.jpg
# Face detected:    /content/stylegan/Faces/823.jpg
# Face detected:    /content/stylegan/Faces/112.jpg
# Face detected:    /content/stylegan/Faces/745.jpg
# No face detected: /content/stylegan/Rejects/2284.jpg
# Face detected:    /content/stylegan/Faces/1225.jpg
# Face detected:    /content/stylegan/Faces/461.jpg
# Face detected:    /content/stylegan/Faces/1183.jpg
# Face detected:    /content/stylegan/Faces/2048.jpg
# Face detected:    /content/stylegan/Faces/1932.jpg
# Face detected:    /content/stylegan/Faces/715.jpg
# No face detected: /content/stylegan/Rejects/2715.jpg
# Face detected:    /content/stylegan/Faces/132.jpg
# No face detected: /content/stylegan/Rejects/1897.jpg
# Face detected:    /content/stylegan/Faces/797.jpg
# Face detected:    /content/stylegan/Faces/1220.jpg
# Face detected:    /content/stylegan/Faces/1891.jpg
# No face detected: /content/stylegan/Rejects/311.jpg
# No face detected: /content/stylegan/Rejects/2089.jpg
# Face detected:    /content/stylegan/Faces/914.jpg
# Face detected:    /content/stylegan/Faces/1708.jpg
# Face detected:    /content/stylegan/Faces/2085.jpg
# No face detected: /content/stylegan/Rejects/793.jpg
# No face detected: /content/stylegan/Rejects/1702.jpg
# Face detected:    /content/stylegan/Faces/1655.jpg
# Face detected:    /content/stylegan/Faces/2723.jpg
# Face detected:    /content/stylegan/Faces/548.jpg
# Face detected:    /content/stylegan/Faces/2277.jpg
# Face detected:    /content/stylegan/Faces/333.jpg
# Face detected:    /content/stylegan/Faces/1086.jpg
# Face detected:    /content/stylegan/Faces/1092.jpg
# No face detected: /content/stylegan/Rejects/2168.jpg
# Face detected:    /content/stylegan/Faces/1288.jpg
# Face detected:    /content/stylegan/Faces/228.jpg
# No face detected: /content/stylegan/Rejects/151.jpg
# No face detected: /content/stylegan/Rejects/2932.jpg
# No face detected: /content/stylegan/Rejects/1007.jpg
# Face detected:    /content/stylegan/Faces/2315.jpg
# Face detected:    /content/stylegan/Faces/969.jpg
# Face detected:    /content/stylegan/Faces/429.jpg
# No face detected: /content/stylegan/Rejects/2363.jpg
# Face detected:    /content/stylegan/Faces/2158.jpg
# Face detected:    /content/stylegan/Faces/1670.jpg
# Face detected:    /content/stylegan/Faces/326.jpg
# Face detected:    /content/stylegan/Faces/1846.jpg
# Face detected:    /content/stylegan/Faces/2451.jpg
# No face detected: /content/stylegan/Rejects/407.jpg
# Face detected:    /content/stylegan/Faces/2940.jpg
# Face detected:    /content/stylegan/Faces/243.jpg
# No face detected: /content/stylegan/Rejects/2614.jpg
# Face detected:    /content/stylegan/Faces/526.jpg
# Face detected:    /content/stylegan/Faces/2039.jpg
# Face detected:    /content/stylegan/Faces/448.jpg
# No face detected: /content/stylegan/Rejects/582.jpg
# Face detected:    /content/stylegan/Faces/1835.jpg
# Face detected:    /content/stylegan/Faces/504.jpg
# No face detected: /content/stylegan/Rejects/575.jpg
# Face detected:    /content/stylegan/Faces/2471.jpg
# Face detected:    /content/stylegan/Faces/2851.jpg
# Face detected:    /content/stylegan/Faces/1344.jpg
# Face detected:    /content/stylegan/Faces/225.jpg
# No face detected: /content/stylegan/Rejects/2112.jpg
# No face detected: /content/stylegan/Rejects/534.jpg
# Face detected:    /content/stylegan/Faces/1188.jpg
# Face detected:    /content/stylegan/Faces/2340.jpg
# Face detected:    /content/stylegan/Faces/2343.jpg
# Face detected:    /content/stylegan/Faces/1946.jpg
# Face detected:    /content/stylegan/Faces/1500.jpg
# Face detected:    /content/stylegan/Faces/1368.jpg
# Face detected:    /content/stylegan/Faces/2156.jpg
# No face detected: /content/stylegan/Rejects/1691.jpg
# Face detected:    /content/stylegan/Faces/2369.jpg
# Face detected:    /content/stylegan/Faces/2668.jpg
# Face detected:    /content/stylegan/Faces/482.jpg
# Face detected:    /content/stylegan/Faces/1025.jpg
# Face detected:    /content/stylegan/Faces/322.jpg
# Face detected:    /content/stylegan/Faces/733.jpg
# Face detected:    /content/stylegan/Faces/1629.jpg
# No face detected: /content/stylegan/Rejects/375.jpg
# Face detected:    /content/stylegan/Faces/2253.jpg
# No face detected: /content/stylegan/Rejects/2531.jpg
# No face detected: /content/stylegan/Rejects/1343.jpg
# Face detected:    /content/stylegan/Faces/1135.jpg
# Face detected:    /content/stylegan/Faces/337.jpg
# Face detected:    /content/stylegan/Faces/149.jpg
# No face detected: /content/stylegan/Rejects/1953.jpg
# Face detected:    /content/stylegan/Faces/592.jpg
# Face detected:    /content/stylegan/Faces/279.jpg
# Face detected:    /content/stylegan/Faces/618.jpg
# Face detected:    /content/stylegan/Faces/800.jpg
# Face detected:    /content/stylegan/Faces/3011.jpg
# Face detected:    /content/stylegan/Faces/285.jpg
# Face detected:    /content/stylegan/Faces/25.jpg
# Face detected:    /content/stylegan/Faces/2529.jpg
# Face detected:    /content/stylegan/Faces/3007.jpg
# No face detected: /content/stylegan/Rejects/1410.jpg
# Face detected:    /content/stylegan/Faces/2498.jpg
# Face detected:    /content/stylegan/Faces/757.jpg
# Face detected:    /content/stylegan/Faces/1352.jpg
# No face detected: /content/stylegan/Rejects/318.jpg
# No face detected: /content/stylegan/Rejects/927.jpg
# Face detected:    /content/stylegan/Faces/2195.jpg
# No face detected: /content/stylegan/Rejects/2042.jpg
# Face detected:    /content/stylegan/Faces/2259.jpg
# Face detected:    /content/stylegan/Faces/1746.jpg
# No face detected: /content/stylegan/Rejects/1104.jpg
# Face detected:    /content/stylegan/Faces/1627.jpg
# No face detected: /content/stylegan/Rejects/2808.jpg
# Face detected:    /content/stylegan/Faces/2745.jpg
# Face detected:    /content/stylegan/Faces/2973.jpg
# Face detected:    /content/stylegan/Faces/1425.jpg
# Face detected:    /content/stylegan/Faces/3017.jpg
# Face detected:    /content/stylegan/Faces/1603.jpg
# No face detected: /content/stylegan/Rejects/2508.jpg
# Face detected:    /content/stylegan/Faces/748.jpg
# Face detected:    /content/stylegan/Faces/2288.jpg
# Face detected:    /content/stylegan/Faces/255.jpg
# Face detected:    /content/stylegan/Faces/813.jpg
# Face detected:    /content/stylegan/Faces/457.jpg
# Face detected:    /content/stylegan/Faces/1433.jpg
# No face detected: /content/stylegan/Rejects/1696.jpg
# Face detected:    /content/stylegan/Faces/494.jpg
# No face detected: /content/stylegan/Rejects/20.jpg
# No face detected: /content/stylegan/Rejects/2274.jpg
# Face detected:    /content/stylegan/Faces/790.jpg
# Face detected:    /content/stylegan/Faces/689.jpg
# Face detected:    /content/stylegan/Faces/2720.jpg
# Face detected:    /content/stylegan/Faces/2104.jpg
# Face detected:    /content/stylegan/Faces/2643.jpg
# Face detected:    /content/stylegan/Faces/1955.jpg
# Face detected:    /content/stylegan/Faces/2096.jpg
# Face detected:    /content/stylegan/Faces/2398.jpg
# Face detected:    /content/stylegan/Faces/946.jpg
# Face detected:    /content/stylegan/Faces/2406.jpg
# Face detected:    /content/stylegan/Faces/367.jpg
# Face detected:    /content/stylegan/Faces/1607.jpg
# Face detected:    /content/stylegan/Faces/2711.jpg
# Face detected:    /content/stylegan/Faces/1300.jpg
# Face detected:    /content/stylegan/Faces/2291.jpg
# No face detected: /content/stylegan/Rejects/1089.jpg
# No face detected: /content/stylegan/Rejects/1802.jpg
# No face detected: /content/stylegan/Rejects/2590.jpg
# Face detected:    /content/stylegan/Faces/1681.jpg
# No face detected: /content/stylegan/Rejects/2336.jpg
# No face detected: /content/stylegan/Rejects/1912.jpg
# No face detected: /content/stylegan/Rejects/869.jpg
# Face detected:    /content/stylegan/Faces/1024.jpg
# No face detected: /content/stylegan/Rejects/1158.jpg
# Face detected:    /content/stylegan/Faces/2561.jpg
# No face detected: /content/stylegan/Rejects/239.jpg
# Face detected:    /content/stylegan/Faces/1549.jpg
# Face detected:    /content/stylegan/Faces/1483.jpg
# Face detected:    /content/stylegan/Faces/1543.jpg
# Face detected:    /content/stylegan/Faces/1052.jpg
# No face detected: /content/stylegan/Rejects/1522.jpg
# No face detected: /content/stylegan/Rejects/983.jpg
# No face detected: /content/stylegan/Rejects/2555.jpg
# No face detected: /content/stylegan/Rejects/545.jpg
# No face detected: /content/stylegan/Rejects/1638.jpg
# No face detected: /content/stylegan/Rejects/413.jpg
# Face detected:    /content/stylegan/Faces/590.jpg
# Face detected:    /content/stylegan/Faces/2640.jpg
# No face detected: /content/stylegan/Rejects/2237.jpg
# Face detected:    /content/stylegan/Faces/1963.jpg
# No face detected: /content/stylegan/Rejects/1261.jpg
# Face detected:    /content/stylegan/Faces/2824.jpg
# Face detected:    /content/stylegan/Faces/2494.jpg
# Face detected:    /content/stylegan/Faces/400.jpg
# Face detected:    /content/stylegan/Faces/940.jpg
# No face detected: /content/stylegan/Rejects/1914.jpg
# Face detected:    /content/stylegan/Faces/2647.jpg
# Face detected:    /content/stylegan/Faces/27.jpg
# No face detected: /content/stylegan/Rejects/2838.jpg
# Face detected:    /content/stylegan/Faces/50.jpg
# Face detected:    /content/stylegan/Faces/2755.jpg
# Face detected:    /content/stylegan/Faces/2885.jpg
# No face detected: /content/stylegan/Rejects/2582.jpg
# No face detected: /content/stylegan/Rejects/362.jpg
# Face detected:    /content/stylegan/Faces/1322.jpg
# No face detected: /content/stylegan/Rejects/2220.jpg
# Face detected:    /content/stylegan/Faces/293.jpg
# Face detected:    /content/stylegan/Faces/1457.jpg
# No face detected: /content/stylegan/Rejects/777.jpg
# Face detected:    /content/stylegan/Faces/2186.jpg
# No face detected: /content/stylegan/Rejects/2583.jpg
# No face detected: /content/stylegan/Rejects/987.jpg
# Face detected:    /content/stylegan/Faces/1547.jpg
# Face detected:    /content/stylegan/Faces/2957.jpg
# Face detected:    /content/stylegan/Faces/2134.jpg
# Face detected:    /content/stylegan/Faces/1315.jpg
# Face detected:    /content/stylegan/Faces/588.jpg
# No face detected: /content/stylegan/Rejects/10.jpg
# Face detected:    /content/stylegan/Faces/1803.jpg
# Face detected:    /content/stylegan/Faces/736.jpg
# Face detected:    /content/stylegan/Faces/1881.jpg
# No face detected: /content/stylegan/Rejects/1027.jpg
# Face detected:    /content/stylegan/Faces/167.jpg
# Face detected:    /content/stylegan/Faces/703.jpg
# Face detected:    /content/stylegan/Faces/2252.jpg
# No face detected: /content/stylegan/Rejects/1304.jpg
# Face detected:    /content/stylegan/Faces/2272.jpg
# No face detected: /content/stylegan/Rejects/2317.jpg
# No face detected: /content/stylegan/Rejects/2854.jpg
# No face detected: /content/stylegan/Rejects/740.jpg
# No face detected: /content/stylegan/Rejects/550.jpg
# Face detected:    /content/stylegan/Faces/2184.jpg
# Face detected:    /content/stylegan/Faces/2268.jpg
# Face detected:    /content/stylegan/Faces/1334.jpg
# Face detected:    /content/stylegan/Faces/1193.jpg
# Face detected:    /content/stylegan/Faces/1521.jpg
# Face detected:    /content/stylegan/Faces/1245.jpg
# Face detected:    /content/stylegan/Faces/2913.jpg
# Face detected:    /content/stylegan/Faces/2773.jpg
# Face detected:    /content/stylegan/Faces/1910.jpg
# Face detected:    /content/stylegan/Faces/1270.jpg
# Face detected:    /content/stylegan/Faces/1942.jpg
# Face detected:    /content/stylegan/Faces/1097.jpg
# Face detected:    /content/stylegan/Faces/846.jpg
# Face detected:    /content/stylegan/Faces/2533.jpg
# No face detected: /content/stylegan/Rejects/276.jpg
# No face detected: /content/stylegan/Rejects/83.jpg
# Face detected:    /content/stylegan/Faces/2519.jpg
# Face detected:    /content/stylegan/Faces/1263.jpg
# Face detected:    /content/stylegan/Faces/2091.jpg
# No face detected: /content/stylegan/Rejects/2214.jpg
# No face detected: /content/stylegan/Rejects/342.jpg
# Face detected:    /content/stylegan/Faces/722.jpg
# Face detected:    /content/stylegan/Faces/1272.jpg
# Face detected:    /content/stylegan/Faces/2645.jpg
# Face detected:    /content/stylegan/Faces/660.jpg
# Face detected:    /content/stylegan/Faces/26.jpg
# Face detected:    /content/stylegan/Faces/1821.jpg
# Face detected:    /content/stylegan/Faces/2403.jpg
# Face detected:    /content/stylegan/Faces/1626.jpg
# Face detected:    /content/stylegan/Faces/207.jpg
# No face detected: /content/stylegan/Rejects/1751.jpg
# Face detected:    /content/stylegan/Faces/1497.jpg
# Face detected:    /content/stylegan/Faces/2076.jpg
# Face detected:    /content/stylegan/Faces/109.jpg
# Face detected:    /content/stylegan/Faces/1697.jpg
# No face detected: /content/stylegan/Rejects/2100.jpg
# Face detected:    /content/stylegan/Faces/1450.jpg
# Face detected:    /content/stylegan/Faces/1956.jpg
# Face detected:    /content/stylegan/Faces/2866.jpg
# Face detected:    /content/stylegan/Faces/1068.jpg
# No face detected: /content/stylegan/Rejects/1828.jpg
# No face detected: /content/stylegan/Rejects/2030.jpg
# Face detected:    /content/stylegan/Faces/1599.jpg
# Face detected:    /content/stylegan/Faces/2390.jpg
# Face detected:    /content/stylegan/Faces/44.jpg
# Face detected:    /content/stylegan/Faces/894.jpg
# Face detected:    /content/stylegan/Faces/902.jpg
# Face detected:    /content/stylegan/Faces/1801.jpg
# Face detected:    /content/stylegan/Faces/1240.jpg
# No face detected: /content/stylegan/Rejects/949.jpg
# No face detected: /content/stylegan/Rejects/1782.jpg
# No face detected: /content/stylegan/Rejects/2439.jpg
# Face detected:    /content/stylegan/Faces/2761.jpg
# Face detected:    /content/stylegan/Faces/1076.jpg
# Face detected:    /content/stylegan/Faces/583.jpg
# No face detected: /content/stylegan/Rejects/1009.jpg
# Face detected:    /content/stylegan/Faces/2721.jpg
# No face detected: /content/stylegan/Rejects/2233.jpg
# Face detected:    /content/stylegan/Faces/1040.jpg
# Face detected:    /content/stylegan/Faces/1838.jpg
# Face detected:    /content/stylegan/Faces/1222.jpg
# Face detected:    /content/stylegan/Faces/200.jpg
# No face detected: /content/stylegan/Rejects/1014.jpg
# No face detected: /content/stylegan/Rejects/2706.jpg
# Face detected:    /content/stylegan/Faces/1583.jpg
# No face detected: /content/stylegan/Rejects/169.jpg
# Face detected:    /content/stylegan/Faces/1345.jpg
# Face detected:    /content/stylegan/Faces/2236.jpg
# No face detected: /content/stylegan/Rejects/2310.jpg
# Face detected:    /content/stylegan/Faces/2844.jpg
# Face detected:    /content/stylegan/Faces/209.jpg
# Face detected:    /content/stylegan/Faces/788.jpg
# Face detected:    /content/stylegan/Faces/137.jpg
# No face detected: /content/stylegan/Rejects/1232.jpg
# Face detected:    /content/stylegan/Faces/707.jpg
# No face detected: /content/stylegan/Rejects/872.jpg
# No face detected: /content/stylegan/Rejects/996.jpg
# Face detected:    /content/stylegan/Faces/661.jpg
# Face detected:    /content/stylegan/Faces/409.jpg
# No face detected: /content/stylegan/Rejects/2686.jpg
# No face detected: /content/stylegan/Rejects/936.jpg
# No face detected: /content/stylegan/Rejects/616.jpg
# Face detected:    /content/stylegan/Faces/1203.jpg
# No face detected: /content/stylegan/Rejects/287.jpg
# Face detected:    /content/stylegan/Faces/767.jpg
# No face detected: /content/stylegan/Rejects/755.jpg
# No face detected: /content/stylegan/Rejects/282.jpg
# No face detected: /content/stylegan/Rejects/2203.jpg
# No face detected: /content/stylegan/Rejects/2312.jpg
# Face detected:    /content/stylegan/Faces/1143.jpg
# Face detected:    /content/stylegan/Faces/2305.jpg
# No face detected: /content/stylegan/Rejects/2919.jpg
# Face detected:    /content/stylegan/Faces/2994.jpg
# Face detected:    /content/stylegan/Faces/587.jpg
# Face detected:    /content/stylegan/Faces/432.jpg
# Face detected:    /content/stylegan/Faces/1739.jpg
# Face detected:    /content/stylegan/Faces/563.jpg
# Face detected:    /content/stylegan/Faces/2427.jpg
# Face detected:    /content/stylegan/Faces/1663.jpg
# Face detected:    /content/stylegan/Faces/1774.jpg
# No face detected: /content/stylegan/Rejects/2294.jpg
# Face detected:    /content/stylegan/Faces/1997.jpg
# Face detected:    /content/stylegan/Faces/602.jpg
# Face detected:    /content/stylegan/Faces/786.jpg
# Face detected:    /content/stylegan/Faces/76.jpg
# No face detected: /content/stylegan/Rejects/2128.jpg
# Face detected:    /content/stylegan/Faces/680.jpg
# Face detected:    /content/stylegan/Faces/2229.jpg
# Face detected:    /content/stylegan/Faces/1161.jpg
# Face detected:    /content/stylegan/Faces/1765.jpg
# Face detected:    /content/stylegan/Faces/1136.jpg
# Face detected:    /content/stylegan/Faces/2771.jpg
# Face detected:    /content/stylegan/Faces/1498.jpg
# Face detected:    /content/stylegan/Faces/1507.jpg
# Face detected:    /content/stylegan/Faces/1728.jpg
# No face detected: /content/stylegan/Rejects/1923.jpg
# Face detected:    /content/stylegan/Faces/591.jpg
# Face detected:    /content/stylegan/Faces/690.jpg
# No face detected: /content/stylegan/Rejects/561.jpg
# Face detected:    /content/stylegan/Faces/1686.jpg
# Face detected:    /content/stylegan/Faces/193.jpg
# No face detected: /content/stylegan/Rejects/2845.jpg
# No face detected: /content/stylegan/Rejects/161.jpg
# No face detected: /content/stylegan/Rejects/2062.jpg
# Face detected:    /content/stylegan/Faces/1566.jpg
# Face detected:    /content/stylegan/Faces/1812.jpg
# No face detected: /content/stylegan/Rejects/2065.jpg
# No face detected: /content/stylegan/Rejects/2916.jpg
# Face detected:    /content/stylegan/Faces/2960.jpg
# Face detected:    /content/stylegan/Faces/2283.jpg
# Face detected:    /content/stylegan/Faces/1328.jpg
# Face detected:    /content/stylegan/Faces/2604.jpg
# No face detected: /content/stylegan/Rejects/1893.jpg
# Face detected:    /content/stylegan/Faces/1960.jpg
# Face detected:    /content/stylegan/Faces/2777.jpg
# Face detected:    /content/stylegan/Faces/1259.jpg
# No face detected: /content/stylegan/Rejects/1055.jpg
# Face detected:    /content/stylegan/Faces/2575.jpg
# Face detected:    /content/stylegan/Faces/146.jpg
# Face detected:    /content/stylegan/Faces/1929.jpg
# No face detected: /content/stylegan/Rejects/180.jpg
# Face detected:    /content/stylegan/Faces/883.jpg
# Face detected:    /content/stylegan/Faces/1164.jpg
# Face detected:    /content/stylegan/Faces/22.jpg
# Face detected:    /content/stylegan/Faces/1921.jpg
# Face detected:    /content/stylegan/Faces/2166.jpg
# Face detected:    /content/stylegan/Faces/1424.jpg
# Face detected:    /content/stylegan/Faces/1550.jpg
# Face detected:    /content/stylegan/Faces/489.jpg
# Face detected:    /content/stylegan/Faces/1470.jpg
# Face detected:    /content/stylegan/Faces/2239.jpg
# Face detected:    /content/stylegan/Faces/1889.jpg
# Face detected:    /content/stylegan/Faces/1530.jpg
# Face detected:    /content/stylegan/Faces/2834.jpg
# Face detected:    /content/stylegan/Faces/1347.jpg
# Face detected:    /content/stylegan/Faces/698.jpg
# Face detected:    /content/stylegan/Faces/834.jpg
# Face detected:    /content/stylegan/Faces/1431.jpg
# No face detected: /content/stylegan/Rejects/1138.jpg
# Face detected:    /content/stylegan/Faces/749.jpg
# No face detected: /content/stylegan/Rejects/2139.jpg
# No face detected: /content/stylegan/Rejects/1022.jpg
# Face detected:    /content/stylegan/Faces/428.jpg
# No face detected: /content/stylegan/Rejects/2145.jpg
# No face detected: /content/stylegan/Rejects/2536.jpg
# Face detected:    /content/stylegan/Faces/2999.jpg
# Face detected:    /content/stylegan/Faces/1218.jpg
# Face detected:    /content/stylegan/Faces/939.jpg
# Face detected:    /content/stylegan/Faces/2407.jpg
# Face detected:    /content/stylegan/Faces/893.jpg
# Face detected:    /content/stylegan/Faces/2094.jpg
# Face detected:    /content/stylegan/Faces/361.jpg
# Face detected:    /content/stylegan/Faces/1819.jpg
# No face detected: /content/stylegan/Rejects/2924.jpg
# No face detected: /content/stylegan/Rejects/2836.jpg
# Face detected:    /content/stylegan/Faces/2248.jpg
# No face detected: /content/stylegan/Rejects/256.jpg
# Face detected:    /content/stylegan/Faces/837.jpg
# Face detected:    /content/stylegan/Faces/841.jpg
# No face detected: /content/stylegan/Rejects/2968.jpg
# No face detected: /content/stylegan/Rejects/2621.jpg
# Face detected:    /content/stylegan/Faces/2625.jpg
# Face detected:    /content/stylegan/Faces/464.jpg
# Face detected:    /content/stylegan/Faces/2320.jpg
# Face detected:    /content/stylegan/Faces/2847.jpg
# No face detected: /content/stylegan/Rejects/2121.jpg
# Face detected:    /content/stylegan/Faces/1834.jpg
# Face detected:    /content/stylegan/Faces/2036.jpg
# Face detected:    /content/stylegan/Faces/743.jpg
# No face detected: /content/stylegan/Rejects/1723.jpg
# Face detected:    /content/stylegan/Faces/1883.jpg
# No face detected: /content/stylegan/Rejects/2073.jpg
# Face detected:    /content/stylegan/Faces/1362.jpg
# Face detected:    /content/stylegan/Faces/2260.jpg
# No face detected: /content/stylegan/Rejects/557.jpg
# Face detected:    /content/stylegan/Faces/1212.jpg
# No face detected: /content/stylegan/Rejects/1200.jpg
# No face detected: /content/stylegan/Rejects/103.jpg
# Face detected:    /content/stylegan/Faces/73.jpg
# No face detected: /content/stylegan/Rejects/1927.jpg
# No face detected: /content/stylegan/Rejects/1179.jpg
# Face detected:    /content/stylegan/Faces/2301.jpg
# No face detected: /content/stylegan/Rejects/1256.jpg
# Face detected:    /content/stylegan/Faces/130.jpg
# Face detected:    /content/stylegan/Faces/559.jpg
# Face detected:    /content/stylegan/Faces/2897.jpg
# Face detected:    /content/stylegan/Faces/2399.jpg
# Face detected:    /content/stylegan/Faces/2448.jpg
# No face detected: /content/stylegan/Rejects/854.jpg
# Face detected:    /content/stylegan/Faces/839.jpg
# No face detected: /content/stylegan/Rejects/1456.jpg
# No face detected: /content/stylegan/Rejects/809.jpg
# Face detected:    /content/stylegan/Faces/668.jpg
# No face detected: /content/stylegan/Rejects/1517.jpg
# No face detected: /content/stylegan/Rejects/3014.jpg
# Face detected:    /content/stylegan/Faces/1654.jpg
# Face detected:    /content/stylegan/Faces/752.jpg
# No face detected: /content/stylegan/Rejects/608.jpg
# Face detected:    /content/stylegan/Faces/474.jpg
# No face detected: /content/stylegan/Rejects/2251.jpg
# No face detected: /content/stylegan/Rejects/2412.jpg
# Face detected:    /content/stylegan/Faces/2282.jpg
# Face detected:    /content/stylegan/Faces/572.jpg
# Face detected:    /content/stylegan/Faces/1951.jpg
# Face detected:    /content/stylegan/Faces/944.jpg
# Face detected:    /content/stylegan/Faces/708.jpg
# Face detected:    /content/stylegan/Faces/2258.jpg
# Face detected:    /content/stylegan/Faces/1298.jpg
# Face detected:    /content/stylegan/Faces/2688.jpg
# Face detected:    /content/stylegan/Faces/117.jpg
# Face detected:    /content/stylegan/Faces/1494.jpg
# No face detected: /content/stylegan/Rejects/2546.jpg
# Face detected:    /content/stylegan/Faces/1594.jpg
# ...
# Face detected:    /content/stylegan/Faces/2176.jpg
# Face detected:    /content/stylegan/Faces/958.jpg
# Face detected:    /content/stylegan/Faces/2480.jpg
# Face detected:    /content/stylegan/Faces/1640.jpg
# Face detected:    /content/stylegan/Faces/621.jpg
# Face detected:    /content/stylegan/Faces/978.jpg
# Face detected:    /content/stylegan/Faces/2747.jpg
# Face detected:    /content/stylegan/Faces/158.jpg
# No face detected: /content/stylegan/Rejects/272.jpg
# No face detected: /content/stylegan/Rejects/1119.jpg
# No face detected: /content/stylegan/Rejects/234.jpg
# Face detected:    /content/stylegan/Faces/1967.jpg
# Face detected:    /content/stylegan/Faces/258.jpg
# No face detected: /content/stylegan/Rejects/1128.jpg
# Face detected:    /content/stylegan/Faces/674.jpg
# Face detected:    /content/stylegan/Faces/2669.jpg
# Face detected:    /content/stylegan/Faces/1413.jpg
# Face detected:    /content/stylegan/Faces/172.jpg
# No face detected: /content/stylegan/Rejects/1150.jpg
# Face detected:    /content/stylegan/Faces/1216.jpg
# Face detected:    /content/stylegan/Faces/1096.jpg
# Face detected:    /content/stylegan/Faces/2473.jpg
# Face detected:    /content/stylegan/Faces/930.jpg
# Face detected:    /content/stylegan/Faces/1341.jpg
# Face detected:    /content/stylegan/Faces/600.jpg
# No face detected: /content/stylegan/Rejects/135.jpg
# Face detected:    /content/stylegan/Faces/2327.jpg
# Face detected:    /content/stylegan/Faces/39.jpg
# No face detected: /content/stylegan/Rejects/1006.jpg
# Face detected:    /content/stylegan/Faces/2759.jpg
# Face detected:    /content/stylegan/Faces/1578.jpg
# No face detected: /content/stylegan/Rejects/1482.jpg
# No face detected: /content/stylegan/Rejects/1266.jpg
# No face detected: /content/stylegan/Rejects/1699.jpg
# No face detected: /content/stylegan/Rejects/2292.jpg
# No face detected: /content/stylegan/Rejects/1172.jpg
# No face detected: /content/stylegan/Rejects/1324.jpg
# Face detected:    /content/stylegan/Faces/1329.jpg
# Face detected:    /content/stylegan/Faces/443.jpg
# No face detected: /content/stylegan/Rejects/2377.jpg
# Face detected:    /content/stylegan/Faces/2709.jpg
# No face detected: /content/stylegan/Rejects/2505.jpg
# Face detected:    /content/stylegan/Faces/265.jpg
# Face detected:    /content/stylegan/Faces/2174.jpg
# Face detected:    /content/stylegan/Faces/840.jpg
# No face detected: /content/stylegan/Rejects/1389.jpg
# Face detected:    /content/stylegan/Faces/1630.jpg
# Face detected:    /content/stylegan/Faces/1822.jpg
# Face detected:    /content/stylegan/Faces/935.jpg
# Face detected:    /content/stylegan/Faces/696.jpg
# No face detected: /content/stylegan/Rejects/2876.jpg
# No face detected: /content/stylegan/Rejects/2129.jpg
# Face detected:    /content/stylegan/Faces/1788.jpg
# No face detected: /content/stylegan/Rejects/633.jpg
# Face detected:    /content/stylegan/Faces/820.jpg
# Face detected:    /content/stylegan/Faces/768.jpg
# Face detected:    /content/stylegan/Faces/259.jpg
# No face detected: /content/stylegan/Rejects/1023.jpg
# No face detected: /content/stylegan/Rejects/3004.jpg
# Face detected:    /content/stylegan/Faces/688.jpg
# Face detected:    /content/stylegan/Faces/1857.jpg
# Face detected:    /content/stylegan/Faces/1070.jpg
# Face detected:    /content/stylegan/Faces/1253.jpg
# No face detected: /content/stylegan/Rejects/584.jpg
# No face detected: /content/stylegan/Rejects/807.jpg
# No face detected: /content/stylegan/Rejects/23.jpg
# No face detected: /content/stylegan/Rejects/2835.jpg
# No face detected: /content/stylegan/Rejects/2615.jpg
# Face detected:    /content/stylegan/Faces/2556.jpg
# No face detected: /content/stylegan/Rejects/1957.jpg
# Face detected:    /content/stylegan/Faces/1109.jpg
# Face detected:    /content/stylegan/Faces/421.jpg
# No face detected: /content/stylegan/Rejects/283.jpg
# No face detected: /content/stylegan/Rejects/2523.jpg
# Face detected:    /content/stylegan/Faces/1013.jpg
# No face detected: /content/stylegan/Rejects/859.jpg
# Face detected:    /content/stylegan/Faces/2997.jpg
# Face detected:    /content/stylegan/Faces/101.jpg
# Face detected:    /content/stylegan/Faces/799.jpg
# No face detected: /content/stylegan/Rejects/1537.jpg
# Face detected:    /content/stylegan/Faces/1604.jpg
# Face detected:    /content/stylegan/Faces/1892.jpg
# Face detected:    /content/stylegan/Faces/2541.jpg
# Face detected:    /content/stylegan/Faces/908.jpg
# No face detected: /content/stylegan/Rejects/1476.jpg
# No face detected: /content/stylegan/Rejects/1701.jpg
# Face detected:    /content/stylegan/Faces/35.jpg
# Face detected:    /content/stylegan/Faces/2515.jpg
# Face detected:    /content/stylegan/Faces/951.jpg
# Face detected:    /content/stylegan/Faces/615.jpg
# Face detected:    /content/stylegan/Faces/1602.jpg
# Face detected:    /content/stylegan/Faces/2458.jpg
# Face detected:    /content/stylegan/Faces/2586.jpg
# Face detected:    /content/stylegan/Faces/1761.jpg
# Face detected:    /content/stylegan/Faces/1031.jpg
# Face detected:    /content/stylegan/Faces/1771.jpg
# No face detected: /content/stylegan/Rejects/2449.jpg
# Face detected:    /content/stylegan/Faces/2594.jpg
# Face detected:    /content/stylegan/Faces/2019.jpg
# Face detected:    /content/stylegan/Faces/1877.jpg
# Face detected:    /content/stylegan/Faces/280.jpg
# Face detected:    /content/stylegan/Faces/2752.jpg
# Face detected:    /content/stylegan/Faces/1579.jpg
# Face detected:    /content/stylegan/Faces/1364.jpg
# Face detected:    /content/stylegan/Faces/1966.jpg
# Face detected:    /content/stylegan/Faces/2685.jpg
# No face detected: /content/stylegan/Rejects/2509.jpg
# Face detected:    /content/stylegan/Faces/1467.jpg
# Face detected:    /content/stylegan/Faces/2566.jpg
# Face detected:    /content/stylegan/Faces/2346.jpg
# Face detected:    /content/stylegan/Faces/2148.jpg
# Face detected:    /content/stylegan/Faces/1665.jpg
# No face detected: /content/stylegan/Rejects/150.jpg
# No face detected: /content/stylegan/Rejects/1327.jpg
# Face detected:    /content/stylegan/Faces/2654.jpg
# Face detected:    /content/stylegan/Faces/134.jpg
# Face detected:    /content/stylegan/Faces/1171.jpg
# No face detected: /content/stylegan/Rejects/3002.jpg
# Face detected:    /content/stylegan/Faces/831.jpg
# Face detected:    /content/stylegan/Faces/1244.jpg
# Face detected:    /content/stylegan/Faces/512.jpg
# Face detected:    /content/stylegan/Faces/221.jpg
# Face detected:    /content/stylegan/Faces/2383.jpg
# Face detected:    /content/stylegan/Faces/1680.jpg
# Face detected:    /content/stylegan/Faces/1207.jpg
# No face detected: /content/stylegan/Rejects/1860.jpg
# Face detected:    /content/stylegan/Faces/2043.jpg
# Face detected:    /content/stylegan/Faces/970.jpg
# No face detected: /content/stylegan/Rejects/2280.jpg
# No face detected: /content/stylegan/Rejects/785.jpg
# Face detected:    /content/stylegan/Faces/332.jpg
# Face detected:    /content/stylegan/Faces/1440.jpg
# Face detected:    /content/stylegan/Faces/418.jpg
# No face detected: /content/stylegan/Rejects/2202.jpg
# Face detected:    /content/stylegan/Faces/2951.jpg
# Face detected:    /content/stylegan/Faces/1402.jpg
# No face detected: /content/stylegan/Rejects/1072.jpg
# Face detected:    /content/stylegan/Faces/1991.jpg
# Face detected:    /content/stylegan/Faces/1067.jpg
# Face detected:    /content/stylegan/Faces/1990.jpg
# No face detected: /content/stylegan/Rejects/1427.jpg
# Face detected:    /content/stylegan/Faces/2558.jpg
# No face detected: /content/stylegan/Rejects/973.jpg
# No face detected: /content/stylegan/Rejects/2068.jpg
# Face detected:    /content/stylegan/Faces/1850.jpg
# Face detected:    /content/stylegan/Faces/1361.jpg
# Face detected:    /content/stylegan/Faces/201.jpg
# Face detected:    /content/stylegan/Faces/879.jpg
# Face detected:    /content/stylegan/Faces/1539.jpg
# No face detected: /content/stylegan/Rejects/2928.jpg
# Face detected:    /content/stylegan/Faces/1847.jpg
# Face detected:    /content/stylegan/Faces/2050.jpg
# Face detected:    /content/stylegan/Faces/1479.jpg
# No face detected: /content/stylegan/Rejects/2090.jpg
# Face detected:    /content/stylegan/Faces/2024.jpg
# Face detected:    /content/stylegan/Faces/1466.jpg
# No face detected: /content/stylegan/Rejects/1477.jpg
# Face detected:    /content/stylegan/Faces/1944.jpg
# Face detected:    /content/stylegan/Faces/202.jpg
# Face detected:    /content/stylegan/Faces/1202.jpg
# Face detected:    /content/stylegan/Faces/2281.jpg
# Face detected:    /content/stylegan/Faces/729.jpg
# Face detected:    /content/stylegan/Faces/2864.jpg
# Face detected:    /content/stylegan/Faces/324.jpg
# No face detected: /content/stylegan/Rejects/2495.jpg
# Face detected:    /content/stylegan/Faces/866.jpg
# Face detected:    /content/stylegan/Faces/1861.jpg
# No face detected: /content/stylegan/Rejects/1074.jpg
# Face detected:    /content/stylegan/Faces/594.jpg
# Face detected:    /content/stylegan/Faces/1799.jpg
# Face detected:    /content/stylegan/Faces/1996.jpg
# Face detected:    /content/stylegan/Faces/1978.jpg
# Face detected:    /content/stylegan/Faces/1715.jpg
# Face detected:    /content/stylegan/Faces/601.jpg
# No face detected: /content/stylegan/Rejects/2382.jpg
# No face detected: /content/stylegan/Rejects/419.jpg
# Face detected:    /content/stylegan/Faces/802.jpg
# No face detected: /content/stylegan/Rejects/2177.jpg
# Face detected:    /content/stylegan/Faces/1580.jpg
# No face detected: /content/stylegan/Rejects/2465.jpg
# Face detected:    /content/stylegan/Faces/500.jpg
# Face detected:    /content/stylegan/Faces/2146.jpg
# Face detected:    /content/stylegan/Faces/1003.jpg
# Face detected:    /content/stylegan/Faces/1121.jpg
# No face detected: /content/stylegan/Rejects/143.jpg
# No face detected: /content/stylegan/Rejects/576.jpg
# Face detected:    /content/stylegan/Faces/203.jpg
# No face detected: /content/stylegan/Rejects/705.jpg
# Face detected:    /content/stylegan/Faces/531.jpg
# Face detected:    /content/stylegan/Faces/466.jpg
# Face detected:    /content/stylegan/Faces/2987.jpg
# Face detected:    /content/stylegan/Faces/2637.jpg
# No face detected: /content/stylegan/Rejects/2535.jpg
# Face detected:    /content/stylegan/Faces/808.jpg
# Face detected:    /content/stylegan/Faces/210.jpg
# Face detected:    /content/stylegan/Faces/1552.jpg
# Face detected:    /content/stylegan/Faces/115.jpg
# Face detected:    /content/stylegan/Faces/2930.jpg
# Face detected:    /content/stylegan/Faces/1658.jpg
# Face detected:    /content/stylegan/Faces/291.jpg
# Face detected:    /content/stylegan/Faces/2249.jpg
# Face detected:    /content/stylegan/Faces/2638.jpg
# Face detected:    /content/stylegan/Faces/176.jpg
# Face detected:    /content/stylegan/Faces/1648.jpg
# No face detected: /content/stylegan/Rejects/960.jpg
# Face detected:    /content/stylegan/Faces/1829.jpg
# No face detected: /content/stylegan/Rejects/378.jpg
# Face detected:    /content/stylegan/Faces/2948.jpg
# Face detected:    /content/stylegan/Faces/2328.jpg
# Face detected:    /content/stylegan/Faces/2101.jpg
# Face detected:    /content/stylegan/Faces/828.jpg
# Face detected:    /content/stylegan/Faces/884.jpg
# Face detected:    /content/stylegan/Faces/2840.jpg
# Face detected:    /content/stylegan/Faces/875.jpg
# Face detected:    /content/stylegan/Faces/381.jpg
# No face detected: /content/stylegan/Rejects/355.jpg
# Face detected:    /content/stylegan/Faces/1622.jpg
# Face detected:    /content/stylegan/Faces/370.jpg
# Face detected:    /content/stylegan/Faces/2832.jpg
# Face detected:    /content/stylegan/Faces/1970.jpg
# No face detected: /content/stylegan/Rejects/455.jpg
# Face detected:    /content/stylegan/Faces/1744.jpg
# Face detected:    /content/stylegan/Faces/2849.jpg
# No face detected: /content/stylegan/Rejects/2027.jpg
# Face detected:    /content/stylegan/Faces/1406.jpg
# Face detected:    /content/stylegan/Faces/507.jpg
# No face detected: /content/stylegan/Rejects/1636.jpg
# Face detected:    /content/stylegan/Faces/2870.jpg
# Face detected:    /content/stylegan/Faces/1111.jpg
# Face detected:    /content/stylegan/Faces/679.jpg
# Face detected:    /content/stylegan/Faces/2138.jpg
# Face detected:    /content/stylegan/Faces/358.jpg
# No face detected: /content/stylegan/Rejects/1904.jpg
# Face detected:    /content/stylegan/Faces/2475.jpg
# Face detected:    /content/stylegan/Faces/2746.jpg
# No face detected: /content/stylegan/Rejects/2639.jpg
# Face detected:    /content/stylegan/Faces/1700.jpg
# Face detected:    /content/stylegan/Faces/1213.jpg
# No face detected: /content/stylegan/Rejects/2261.jpg
# No face detected: /content/stylegan/Rejects/51.jpg
# Face detected:    /content/stylegan/Faces/2693.jpg
# Face detected:    /content/stylegan/Faces/97.jpg
# Face detected:    /content/stylegan/Faces/766.jpg
# Face detected:    /content/stylegan/Faces/1390.jpg
# No face detected: /content/stylegan/Rejects/2431.jpg
# Face detected:    /content/stylegan/Faces/1661.jpg
# Face detected:    /content/stylegan/Faces/2958.jpg
# Face detected:    /content/stylegan/Faces/2084.jpg
# No face detected: /content/stylegan/Rejects/1189.jpg
# Face detected:    /content/stylegan/Faces/1981.jpg
# Face detected:    /content/stylegan/Faces/364.jpg
# Face detected:    /content/stylegan/Faces/2157.jpg
# No face detected: /content/stylegan/Rejects/2918.jpg
# Face detected:    /content/stylegan/Faces/796.jpg
# No face detected: /content/stylegan/Rejects/88.jpg
# Face detected:    /content/stylegan/Faces/2942.jpg
# No face detected: /content/stylegan/Rejects/2137.jpg
# Face detected:    /content/stylegan/Faces/298.jpg
# Face detected:    /content/stylegan/Faces/1211.jpg
# Face detected:    /content/stylegan/Faces/1587.jpg
# Face detected:    /content/stylegan/Faces/1398.jpg
# Face detected:    /content/stylegan/Faces/2299.jpg
# Face detected:    /content/stylegan/Faces/1105.jpg
# Face detected:    /content/stylegan/Faces/880.jpg
# Face detected:    /content/stylegan/Faces/2474.jpg
# No face detected: /content/stylegan/Rejects/2662.jpg
# No face detected: /content/stylegan/Rejects/1366.jpg
# Face detected:    /content/stylegan/Faces/2003.jpg
# No face detected: /content/stylegan/Rejects/2216.jpg
# Face detected:    /content/stylegan/Faces/665.jpg
# No face detected: /content/stylegan/Rejects/718.jpg
# Face detected:    /content/stylegan/Faces/1065.jpg
# Face detected:    /content/stylegan/Faces/2319.jpg
# Face detected:    /content/stylegan/Faces/1181.jpg
# No face detected: /content/stylegan/Rejects/763.jpg
# Face detected:    /content/stylegan/Faces/1814.jpg
# Face detected:    /content/stylegan/Faces/1408.jpg
# Face detected:    /content/stylegan/Faces/2375.jpg
# No face detected: /content/stylegan/Rejects/904.jpg
# Face detected:    /content/stylegan/Faces/2011.jpg
# Face detected:    /content/stylegan/Faces/1309.jpg
# Face detected:    /content/stylegan/Faces/281.jpg
# Face detected:    /content/stylegan/Faces/2245.jpg
# Face detected:    /content/stylegan/Faces/2650.jpg
# Face detected:    /content/stylegan/Faces/1621.jpg
# Face detected:    /content/stylegan/Faces/2167.jpg
# No face detected: /content/stylegan/Rejects/1605.jpg
# Face detected:    /content/stylegan/Faces/1635.jpg
# Face detected:    /content/stylegan/Faces/1029.jpg
# Face detected:    /content/stylegan/Faces/2224.jpg
# Face detected:    /content/stylegan/Faces/2728.jpg
# No face detected: /content/stylegan/Rejects/1428.jpg
# Face detected:    /content/stylegan/Faces/2939.jpg
# Face detected:    /content/stylegan/Faces/1736.jpg
# Face detected:    /content/stylegan/Faces/585.jpg
# Face detected:    /content/stylegan/Faces/1598.jpg
# No face detected: /content/stylegan/Rejects/1374.jpg
# Face detected:    /content/stylegan/Faces/197.jpg
# Face detected:    /content/stylegan/Faces/1811.jpg
# No face detected: /content/stylegan/Rejects/1760.jpg
# Face detected:    /content/stylegan/Faces/2208.jpg
# No face detected: /content/stylegan/Rejects/1924.jpg
# Face detected:    /content/stylegan/Faces/2107.jpg
# Face detected:    /content/stylegan/Faces/2204.jpg
# Face detected:    /content/stylegan/Faces/959.jpg
# No face detected: /content/stylegan/Rejects/677.jpg
# Face detected:    /content/stylegan/Faces/1768.jpg
# No face detected: /content/stylegan/Rejects/1358.jpg
# Face detected:    /content/stylegan/Faces/1752.jpg
# Face detected:    /content/stylegan/Faces/1367.jpg
# No face detected: /content/stylegan/Rejects/1260.jpg
# 3020 input files, 2119 faces cropped, 901 rejected

# %% [markdown]
# download latest model for transfer learning

# %%
# !gdown https://drive.google.com/uc?id=1eYHcNrI_kLRfWnC9Kb8xbak6548vTuyt
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1eYHcNrI_kLRfWnC9Kb8xbak6548vTuyt
# To: /content/stylegan/network-snapshot-011155.pkl
# 308MB [00:05, 58.3MB/s]

# %% [markdown]
# generate tfrecords

# %%
# !python dataset_tool.py create_from_images datasets/smalls/ /content/stylegan/Faces/
# Out:
# Loading images from "/content/stylegan/Faces/"
# Creating dataset "datasets/smalls/"
# Added 2119 images.

# %% [markdown]
# add settings and start training

# %%
cd training/
# Out:
# /content/stylegan/training

# %%
# %%writefile training_loop.py 
# Copyright (c) 2019, NVIDIA CORPORATION. All rights reserved.
#
# This work is licensed under the Creative Commons Attribution-NonCommercial
# 4.0 International License. To view a copy of this license, visit
# http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
# Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.

"""Main training script."""

import os
import numpy as np
import tensorflow as tf
import dnnlib
import dnnlib.tflib as tflib
from dnnlib.tflib.autosummary import autosummary

import config
import train
from training import dataset
from training import misc
from metrics import metric_base

#----------------------------------------------------------------------------
# Just-in-time processing of training images before feeding them to the networks.

def process_reals(x, lod, mirror_augment, drange_data, drange_net):
    with tf.name_scope('ProcessReals'):
        with tf.name_scope('DynamicRange'):
            x = tf.cast(x, tf.float32)
            x = misc.adjust_dynamic_range(x, drange_data, drange_net)
        if mirror_augment:
            with tf.name_scope('MirrorAugment'):
                s = tf.shape(x)
                mask = tf.random_uniform([s[0], 1, 1, 1], 0.0, 1.0)
                mask = tf.tile(mask, [1, s[1], s[2], s[3]])
                x = tf.where(mask < 0.5, x, tf.reverse(x, axis=[3]))
        with tf.name_scope('FadeLOD'): # Smooth crossfade between consecutive levels-of-detail.
            s = tf.shape(x)
            y = tf.reshape(x, [-1, s[1], s[2]//2, 2, s[3]//2, 2])
            y = tf.reduce_mean(y, axis=[3, 5], keepdims=True)
            y = tf.tile(y, [1, 1, 1, 2, 1, 2])
            y = tf.reshape(y, [-1, s[1], s[2], s[3]])
            x = tflib.lerp(x, y, lod - tf.floor(lod))
        with tf.name_scope('UpscaleLOD'): # Upscale to match the expected input/output size of the networks.
            s = tf.shape(x)
            factor = tf.cast(2 ** tf.floor(lod), tf.int32)
            x = tf.reshape(x, [-1, s[1], s[2], 1, s[3], 1])
            x = tf.tile(x, [1, 1, 1, factor, 1, factor])
            x = tf.reshape(x, [-1, s[1], s[2] * factor, s[3] * factor])
        return x

#----------------------------------------------------------------------------
# Evaluate time-varying training parameters.

def training_schedule(
    cur_nimg,
    training_set,
    num_gpus,
    lod_initial_resolution  = 4,        # Image resolution used at the beginning.
    lod_training_kimg       = 600,      # Thousands of real images to show before doubling the resolution.
    lod_transition_kimg     = 600,      # Thousands of real images to show when fading in new layers.
    minibatch_base          = 16,       # Maximum minibatch size, divided evenly among GPUs.
    minibatch_dict          = {},       # Resolution-specific overrides.
    max_minibatch_per_gpu   = {},       # Resolution-specific maximum minibatch size per GPU.
    G_lrate_base            = 0.001,    # Learning rate for the generator.
    G_lrate_dict            = {},       # Resolution-specific overrides.
    D_lrate_base            = 0.001,    # Learning rate for the discriminator.
    D_lrate_dict            = {},       # Resolution-specific overrides.
    lrate_rampup_kimg       = 0,        # Duration of learning rate ramp-up.
    tick_kimg_base          = 160,      # Default interval of progress snapshots.
    tick_kimg_dict          = {4: 160, 8:140, 16:120, 32:100, 64:80, 128:60, 256:40, 512:30, 1024:20}): # Resolution-specific overrides.

    # Initialize result dict.
    s = dnnlib.EasyDict()
    s.kimg = cur_nimg / 1000.0

    # Training phase.
    phase_dur = lod_training_kimg + lod_transition_kimg
    phase_idx = int(np.floor(s.kimg / phase_dur)) if phase_dur > 0 else 0
    phase_kimg = s.kimg - phase_idx * phase_dur

    # Level-of-detail and resolution.
    s.lod = training_set.resolution_log2
    s.lod -= np.floor(np.log2(lod_initial_resolution))
    s.lod -= phase_idx
    if lod_transition_kimg > 0:
        s.lod -= max(phase_kimg - lod_training_kimg, 0.0) / lod_transition_kimg
    s.lod = max(s.lod, 0.0)
    s.resolution = 2 ** (training_set.resolution_log2 - int(np.floor(s.lod)))

    # Minibatch size.
    s.minibatch = minibatch_dict.get(s.resolution, minibatch_base)
    s.minibatch -= s.minibatch % num_gpus
    if s.resolution in max_minibatch_per_gpu:
        s.minibatch = min(s.minibatch, max_minibatch_per_gpu[s.resolution] * num_gpus)

    # Learning rate.
    s.G_lrate = G_lrate_dict.get(s.resolution, G_lrate_base)
    s.D_lrate = D_lrate_dict.get(s.resolution, D_lrate_base)
    if lrate_rampup_kimg > 0:
        rampup = min(s.kimg / lrate_rampup_kimg, 1.0)
        s.G_lrate *= rampup
        s.D_lrate *= rampup

    # Other parameters.
    s.tick_kimg = tick_kimg_dict.get(s.resolution, tick_kimg_base)
    return s

#----------------------------------------------------------------------------
# Main training script.

def training_loop(
    submit_config,
    G_args                  = {},       # Options for generator network.
    D_args                  = {},       # Options for discriminator network.
    G_opt_args              = {},       # Options for generator optimizer.
    D_opt_args              = {},       # Options for discriminator optimizer.
    G_loss_args             = {},       # Options for generator loss.
    D_loss_args             = {},       # Options for discriminator loss.
    dataset_args            = {},       # Options for dataset.load_dataset().
    sched_args              = {},       # Options for train.TrainingSchedule.
    grid_args               = {},       # Options for train.setup_snapshot_image_grid().
    metric_arg_list         = [],       # Options for MetricGroup.
    tf_config               = {},       # Options for tflib.init_tf().
    G_smoothing_kimg        = 10.0,     # Half-life of the running average of generator weights.
    D_repeats               = 1,        # How many times the discriminator is trained per G iteration.
    minibatch_repeats       = 4,        # Number of minibatches to run before adjusting training parameters.
    reset_opt_for_new_lod   = True,     # Reset optimizer internal state (e.g. Adam moments) when new layers are introduced?
    total_kimg              = 15000,    # Total length of the training, measured in thousands of real images.
    mirror_augment          = False,    # Enable mirror augment?
    drange_net              = [-1,1],   # Dynamic range used when feeding image data to the networks.
    image_snapshot_ticks    = 1,        # How often to export image snapshots?
    network_snapshot_ticks  = 1,       # How often to export network snapshots?
    save_tf_graph           = False,    # Include full TensorFlow computation graph in the tfevents file?
    save_weight_histograms  = False,    # Include weight histograms in the tfevents file?
    resume_run_id           = "/content/stylegan/network-snapshot-011155.pkl",     # Run ID or network pkl to resume training from, None = start from scratch.
    resume_snapshot         = None,     # Snapshot index to resume training from, None = autodetect.
    resume_kimg             = 11155,      # Assumed training progress at the beginning. Affects reporting and training schedule.
    resume_time             = 0.0):     # Assumed wallclock time at the beginning. Affects reporting.

    # Initialize dnnlib and TensorFlow.
    ctx = dnnlib.RunContext(submit_config, train)
    tflib.init_tf(tf_config)

    # Load training set.
    training_set = dataset.load_dataset(data_dir=config.data_dir, verbose=True, **dataset_args)

    # Construct networks.
    with tf.device('/gpu:0'):
        if resume_run_id is not None:
            network_pkl = misc.locate_network_pkl(resume_run_id, resume_snapshot)
            print('Loading networks from "%s"...' % network_pkl)
            G, D, Gs = misc.load_pkl(network_pkl)
        else:
            print('Constructing networks...')
            G = tflib.Network('G', num_channels=training_set.shape[0], resolution=training_set.shape[1], label_size=training_set.label_size, **G_args)
            D = tflib.Network('D', num_channels=training_set.shape[0], resolution=training_set.shape[1], label_size=training_set.label_size, **D_args)
            Gs = G.clone('Gs')
    G.print_layers(); D.print_layers()

    print('Building TensorFlow graph...')
    with tf.name_scope('Inputs'), tf.device('/cpu:0'):
        lod_in          = tf.placeholder(tf.float32, name='lod_in', shape=[])
        lrate_in        = tf.placeholder(tf.float32, name='lrate_in', shape=[])
        minibatch_in    = tf.placeholder(tf.int32, name='minibatch_in', shape=[])
        minibatch_split = minibatch_in // submit_config.num_gpus
        Gs_beta         = 0.5 ** tf.div(tf.cast(minibatch_in, tf.float32), G_smoothing_kimg * 1000.0) if G_smoothing_kimg > 0.0 else 0.0

    G_opt = tflib.Optimizer(name='TrainG', learning_rate=lrate_in, **G_opt_args)
    D_opt = tflib.Optimizer(name='TrainD', learning_rate=lrate_in, **D_opt_args)
    for gpu in range(submit_config.num_gpus):
        with tf.name_scope('GPU%d' % gpu), tf.device('/gpu:%d' % gpu):
            G_gpu = G if gpu == 0 else G.clone(G.name + '_shadow')
            D_gpu = D if gpu == 0 else D.clone(D.name + '_shadow')
            lod_assign_ops = [tf.assign(G_gpu.find_var('lod'), lod_in), tf.assign(D_gpu.find_var('lod'), lod_in)]
            reals, labels = training_set.get_minibatch_tf()
            reals = process_reals(reals, lod_in, mirror_augment, training_set.dynamic_range, drange_net)
            with tf.name_scope('G_loss'), tf.control_dependencies(lod_assign_ops):
                G_loss = dnnlib.util.call_func_by_name(G=G_gpu, D=D_gpu, opt=G_opt, training_set=training_set, minibatch_size=minibatch_split, **G_loss_args)
            with tf.name_scope('D_loss'), tf.control_dependencies(lod_assign_ops):
                D_loss = dnnlib.util.call_func_by_name(G=G_gpu, D=D_gpu, opt=D_opt, training_set=training_set, minibatch_size=minibatch_split, reals=reals, labels=labels, **D_loss_args)
            G_opt.register_gradients(tf.reduce_mean(G_loss), G_gpu.trainables)
            D_opt.register_gradients(tf.reduce_mean(D_loss), D_gpu.trainables)
    G_train_op = G_opt.apply_updates()
    D_train_op = D_opt.apply_updates()

    Gs_update_op = Gs.setup_as_moving_average_of(G, beta=Gs_beta)
    with tf.device('/gpu:0'):
        try:
            peak_gpu_mem_op = tf.contrib.memory_stats.MaxBytesInUse()
        except tf.errors.NotFoundError:
            peak_gpu_mem_op = tf.constant(0)

    print('Setting up snapshot image grid...')
    grid_size, grid_reals, grid_labels, grid_latents = misc.setup_snapshot_image_grid(G, training_set, **grid_args)
    sched = training_schedule(cur_nimg=total_kimg*1000, training_set=training_set, num_gpus=submit_config.num_gpus, **sched_args)
    grid_fakes = Gs.run(grid_latents, grid_labels, is_validation=True, minibatch_size=sched.minibatch//submit_config.num_gpus)

    print('Setting up run dir...')
    misc.save_image_grid(grid_reals, os.path.join(submit_config.run_dir, 'reals.png'), drange=training_set.dynamic_range, grid_size=grid_size)
    misc.save_image_grid(grid_fakes, os.path.join(submit_config.run_dir, 'fakes%06d.png' % resume_kimg), drange=drange_net, grid_size=grid_size)
    summary_log = tf.summary.FileWriter(submit_config.run_dir)
    if save_tf_graph:
        summary_log.add_graph(tf.get_default_graph())
    if save_weight_histograms:
        G.setup_weight_histograms(); D.setup_weight_histograms()
    metrics = metric_base.MetricGroup(metric_arg_list)

    print('Training...\n')
    ctx.update('', cur_epoch=resume_kimg, max_epoch=total_kimg)
    maintenance_time = ctx.get_last_update_interval()
    cur_nimg = int(resume_kimg * 1000)
    cur_tick = 0
    tick_start_nimg = cur_nimg
    prev_lod = -1.0
    while cur_nimg < total_kimg * 1000:
        if ctx.should_stop(): break

        # Choose training parameters and configure training ops.
        sched = training_schedule(cur_nimg=cur_nimg, training_set=training_set, num_gpus=submit_config.num_gpus, **sched_args)
        training_set.configure(sched.minibatch // submit_config.num_gpus, sched.lod)
        if reset_opt_for_new_lod:
            if np.floor(sched.lod) != np.floor(prev_lod) or np.ceil(sched.lod) != np.ceil(prev_lod):
                G_opt.reset_optimizer_state(); D_opt.reset_optimizer_state()
        prev_lod = sched.lod

        # Run training ops.
        for _mb_repeat in range(minibatch_repeats):
            for _D_repeat in range(D_repeats):
                tflib.run([D_train_op, Gs_update_op], {lod_in: sched.lod, lrate_in: sched.D_lrate, minibatch_in: sched.minibatch})
                cur_nimg += sched.minibatch
            tflib.run([G_train_op], {lod_in: sched.lod, lrate_in: sched.G_lrate, minibatch_in: sched.minibatch})

        # Perform maintenance tasks once per tick.
        done = (cur_nimg >= total_kimg * 1000)
        if cur_nimg >= tick_start_nimg + sched.tick_kimg * 1000 or done:
            cur_tick += 1
            tick_kimg = (cur_nimg - tick_start_nimg) / 1000.0
            tick_start_nimg = cur_nimg
            tick_time = ctx.get_time_since_last_update()
            total_time = ctx.get_time_since_start() + resume_time

            # Report progress.
            print('tick %-5d kimg %-8.1f lod %-5.2f minibatch %-4d time %-12s sec/tick %-7.1f sec/kimg %-7.2f maintenance %-6.1f gpumem %-4.1f' % (
                autosummary('Progress/tick', cur_tick),
                autosummary('Progress/kimg', cur_nimg / 1000.0),
                autosummary('Progress/lod', sched.lod),
                autosummary('Progress/minibatch', sched.minibatch),
                dnnlib.util.format_time(autosummary('Timing/total_sec', total_time)),
                autosummary('Timing/sec_per_tick', tick_time),
                autosummary('Timing/sec_per_kimg', tick_time / tick_kimg),
                autosummary('Timing/maintenance_sec', maintenance_time),
                autosummary('Resources/peak_gpu_mem_gb', peak_gpu_mem_op.eval() / 2**30)))
            autosummary('Timing/total_hours', total_time / (60.0 * 60.0))
            autosummary('Timing/total_days', total_time / (24.0 * 60.0 * 60.0))

            # Save snapshots.
            if cur_tick % image_snapshot_ticks == 0 or done:
                grid_fakes = Gs.run(grid_latents, grid_labels, is_validation=True, minibatch_size=sched.minibatch//submit_config.num_gpus)
                misc.save_image_grid(grid_fakes, os.path.join(submit_config.run_dir, 'fakes%06d.png' % (cur_nimg // 1000)), drange=drange_net, grid_size=grid_size)
            if cur_tick % network_snapshot_ticks == 0 or done or cur_tick == 1:
                pkl = os.path.join(submit_config.run_dir, 'network-snapshot-%06d.pkl' % (cur_nimg // 1000))
                misc.save_pkl((G, D, Gs), pkl)
                metrics.run(pkl, run_dir=submit_config.run_dir, num_gpus=submit_config.num_gpus, tf_config=tf_config)

            # Update summaries and RunContext.
            metrics.update_autosummaries()
            tflib.autosummary.save_summaries(summary_log, cur_nimg)
            ctx.update('%.2f' % sched.lod, cur_epoch=cur_nimg // 1000, max_epoch=total_kimg)
            maintenance_time = ctx.get_last_update_interval() - tick_time

    # Write final results.
    misc.save_pkl((G, D, Gs), os.path.join(submit_config.run_dir, 'network-final.pkl'))
    summary_log.close()
    print('Final model ready ...\n')

    ctx.close()

#----------------------------------------------------------------------------
# Out:
# Overwriting training_loop.py

# %%
cd ..
# Out:
# /content/stylegan

# %%
# Copyright (c) 2019, NVIDIA CORPORATION. All rights reserved.
#
# This work is licensed under the Creative Commons Attribution-NonCommercial
# 4.0 International License. To view a copy of this license, visit
# http://creativecommons.org/licenses/by-nc/4.0/ or send a letter to
# Creative Commons, PO Box 1866, Mountain View, CA 94042, USA.

"""Main entry point for training StyleGAN and ProGAN networks."""

import copy
import dnnlib
from dnnlib import EasyDict

import config
from metrics import metric_base

#----------------------------------------------------------------------------
# Official training configs for StyleGAN, targeted mainly for FFHQ.

if 1:
    desc          = 'sgan'                                                                 # Description string included in result subdir name.
    train         = EasyDict(run_func_name='training.training_loop.training_loop')         # Options for training loop.
    G             = EasyDict(func_name='training.networks_stylegan.G_style')               # Options for generator network.
    D             = EasyDict(func_name='training.networks_stylegan.D_basic')               # Options for discriminator network.
    G_opt         = EasyDict(beta1=0.0, beta2=0.99, epsilon=1e-8)                          # Options for generator optimizer.
    D_opt         = EasyDict(beta1=0.0, beta2=0.99, epsilon=1e-8)                          # Options for discriminator optimizer.
    G_loss        = EasyDict(func_name='training.loss.G_logistic_nonsaturating')           # Options for generator loss.
    D_loss        = EasyDict(func_name='training.loss.D_logistic_simplegp', r1_gamma=10.0) # Options for discriminator loss.
    dataset       = EasyDict()                                                             # Options for load_dataset().
    sched         = EasyDict()                                                             # Options for TrainingSchedule.
    grid          = EasyDict(size='4k', layout='random')                                   # Options for setup_snapshot_image_grid().
    #metrics       = [metric_base.fid50k]                                                   # Options for MetricGroup.
    submit_config = dnnlib.SubmitConfig()                                                  # Options for dnnlib.submit_run().
    tf_config     = {'rnd.np_random_seed': 1000}                                           # Options for tflib.init_tf().

    # Dataset.
    desc += '-custom';     dataset = EasyDict(tfrecord_dir='smalls');              train.mirror_augment = True
    #desc += '-celebahq'; dataset = EasyDict(tfrecord_dir='celebahq');          train.mirror_augment = True
    #desc += '-bedroom';  dataset = EasyDict(tfrecord_dir='lsun-bedroom-full'); train.mirror_augment = False
    #desc += '-car';      dataset = EasyDict(tfrecord_dir='lsun-car-512x384');  train.mirror_augment = False
    #desc += '-cat';      dataset = EasyDict(tfrecord_dir='lsun-cat-full');     train.mirror_augment = False

    # Number of GPUs.
    desc += '-1gpu'; submit_config.num_gpus = 1; sched.minibatch_base = 4; sched.minibatch_dict = {4: 128, 8: 128, 16: 128, 32: 64, 64: 32, 128: 16, 256: 8, 512: 4}
    #desc += '-2gpu'; submit_config.num_gpus = 2; sched.minibatch_base = 8; sched.minibatch_dict = {4: 256, 8: 256, 16: 128, 32: 64, 64: 32, 128: 16, 256: 8}
    #desc += '-4gpu'; submit_config.num_gpus = 4; sched.minibatch_base = 16; sched.minibatch_dict = {4: 512, 8: 256, 16: 128, 32: 64, 64: 32, 128: 16}
    #desc += '-8gpu'; submit_config.num_gpus = 8; sched.minibatch_base = 32; sched.minibatch_dict = {4: 512, 8: 256, 16: 128, 32: 64, 64: 32}

    # Default options.
    train.total_kimg = 25000
    sched.lod_initial_resolution = 8
    sched.G_lrate_dict = {128: 0.0015, 256: 0.002, 512: 0.003, 1024: 0.003}
    sched.D_lrate_dict = EasyDict(sched.G_lrate_dict)

    # WGAN-GP loss for CelebA-HQ.
    #desc += '-wgangp'; G_loss = EasyDict(func_name='training.loss.G_wgan'); D_loss = EasyDict(func_name='training.loss.D_wgan_gp'); sched.G_lrate_dict = {k: min(v, 0.002) for k, v in sched.G_lrate_dict.items()}; sched.D_lrate_dict = EasyDict(sched.G_lrate_dict)

    # Table 1.
    #desc += '-tuned-baseline'; G.use_styles = False; G.use_pixel_norm = True; G.use_instance_norm = False; G.mapping_layers = 0; G.truncation_psi = None; G.const_input_layer = False; G.style_mixing_prob = 0.0; G.use_noise = False
    #desc += '-add-mapping-and-styles'; G.const_input_layer = False; G.style_mixing_prob = 0.0; G.use_noise = False
    #desc += '-remove-traditional-input'; G.style_mixing_prob = 0.0; G.use_noise = False
    #desc += '-add-noise-inputs'; G.style_mixing_prob = 0.0
    #desc += '-mixing-regularization' # default

    # Table 2.
    #desc += '-mix0'; G.style_mixing_prob = 0.0
    #desc += '-mix50'; G.style_mixing_prob = 0.5
    #desc += '-mix90'; G.style_mixing_prob = 0.9 # default
    #desc += '-mix100'; G.style_mixing_prob = 1.0

    # Table 4.
    #desc += '-traditional-0'; G.use_styles = False; G.use_pixel_norm = True; G.use_instance_norm = False; G.mapping_layers = 0; G.truncation_psi = None; G.const_input_layer = False; G.style_mixing_prob = 0.0; G.use_noise = False
    #desc += '-traditional-8'; G.use_styles = False; G.use_pixel_norm = True; G.use_instance_norm = False; G.mapping_layers = 8; G.truncation_psi = None; G.const_input_layer = False; G.style_mixing_prob = 0.0; G.use_noise = False
    #desc += '-stylebased-0'; G.mapping_layers = 0
    #desc += '-stylebased-1'; G.mapping_layers = 1
    #desc += '-stylebased-2'; G.mapping_layers = 2
    #desc += '-stylebased-8'; G.mapping_layers = 8 # default

#----------------------------------------------------------------------------
# Official training configs for Progressive GAN, targeted mainly for CelebA-HQ.

if 0:
    desc          = 'pgan'                                                         # Description string included in result subdir name.
    train         = EasyDict(run_func_name='training.training_loop.training_loop') # Options for training loop.
    G             = EasyDict(func_name='training.networks_progan.G_paper')         # Options for generator network.
    D             = EasyDict(func_name='training.networks_progan.D_paper')         # Options for discriminator network.
    G_opt         = EasyDict(beta1=0.0, beta2=0.99, epsilon=1e-8)                  # Options for generator optimizer.
    D_opt         = EasyDict(beta1=0.0, beta2=0.99, epsilon=1e-8)                  # Options for discriminator optimizer.
    G_loss        = EasyDict(func_name='training.loss.G_wgan')                     # Options for generator loss.
    D_loss        = EasyDict(func_name='training.loss.D_wgan_gp')                  # Options for discriminator loss.
    dataset       = EasyDict()                                                     # Options for load_dataset().
    sched         = EasyDict()                                                     # Options for TrainingSchedule.
    grid          = EasyDict(size='1080p', layout='random')                        # Options for setup_snapshot_image_grid().
    #metrics       = [metric_base.fid50k]                                           # Options for MetricGroup.
    submit_config = dnnlib.SubmitConfig()                                          # Options for dnnlib.submit_run().
    tf_config     = {'rnd.np_random_seed': 1000}                                   # Options for tflib.init_tf().

    # Dataset (choose one).
    #desc += '-celebahq';            dataset = EasyDict(tfrecord_dir='celebahq'); train.mirror_augment = True
    #desc += '-celeba';              dataset = EasyDict(tfrecord_dir='celeba'); train.mirror_augment = True
    #desc += '-cifar10';             dataset = EasyDict(tfrecord_dir='cifar10')
    #desc += '-cifar100';            dataset = EasyDict(tfrecord_dir='cifar100')
    #desc += '-svhn';                dataset = EasyDict(tfrecord_dir='svhn')
    #desc += '-mnist';               dataset = EasyDict(tfrecord_dir='mnist')
    #desc += '-mnistrgb';            dataset = EasyDict(tfrecord_dir='mnistrgb')
    #desc += '-syn1024rgb';          dataset = EasyDict(class_name='training.dataset.SyntheticDataset', resolution=1024, num_channels=3)
    #desc += '-lsun-airplane';       dataset = EasyDict(tfrecord_dir='lsun-airplane-100k');       train.mirror_augment = True
    #desc += '-lsun-bedroom';        dataset = EasyDict(tfrecord_dir='lsun-bedroom-100k');        train.mirror_augment = True
    #desc += '-lsun-bicycle';        dataset = EasyDict(tfrecord_dir='lsun-bicycle-100k');        train.mirror_augment = True
    #desc += '-lsun-bird';           dataset = EasyDict(tfrecord_dir='lsun-bird-100k');           train.mirror_augment = True
    #desc += '-lsun-boat';           dataset = EasyDict(tfrecord_dir='lsun-boat-100k');           train.mirror_augment = True
    #desc += '-lsun-bottle';         dataset = EasyDict(tfrecord_dir='lsun-bottle-100k');         train.mirror_augment = True
    #desc += '-lsun-bridge';         dataset = EasyDict(tfrecord_dir='lsun-bridge-100k');         train.mirror_augment = True
    #desc += '-lsun-bus';            dataset = EasyDict(tfrecord_dir='lsun-bus-100k');            train.mirror_augment = True
    #desc += '-lsun-car';            dataset = EasyDict(tfrecord_dir='lsun-car-100k');            train.mirror_augment = True
    #desc += '-lsun-cat';            dataset = EasyDict(tfrecord_dir='lsun-cat-100k');            train.mirror_augment = True
    #desc += '-lsun-chair';          dataset = EasyDict(tfrecord_dir='lsun-chair-100k');          train.mirror_augment = True
    #desc += '-lsun-churchoutdoor';  dataset = EasyDict(tfrecord_dir='lsun-churchoutdoor-100k');  train.mirror_augment = True
    #desc += '-lsun-classroom';      dataset = EasyDict(tfrecord_dir='lsun-classroom-100k');      train.mirror_augment = True
    #desc += '-lsun-conferenceroom'; dataset = EasyDict(tfrecord_dir='lsun-conferenceroom-100k'); train.mirror_augment = True
    #desc += '-lsun-cow';            dataset = EasyDict(tfrecord_dir='lsun-cow-100k');            train.mirror_augment = True
    #desc += '-lsun-diningroom';     dataset = EasyDict(tfrecord_dir='lsun-diningroom-100k');     train.mirror_augment = True
    #desc += '-lsun-diningtable';    dataset = EasyDict(tfrecord_dir='lsun-diningtable-100k');    train.mirror_augment = True
    #desc += '-lsun-dog';            dataset = EasyDict(tfrecord_dir='lsun-dog-100k');            train.mirror_augment = True
    #desc += '-lsun-horse';          dataset = EasyDict(tfrecord_dir='lsun-horse-100k');          train.mirror_augment = True
    #desc += '-lsun-kitchen';        dataset = EasyDict(tfrecord_dir='lsun-kitchen-100k');        train.mirror_augment = True
    #desc += '-lsun-livingroom';     dataset = EasyDict(tfrecord_dir='lsun-livingroom-100k');     train.mirror_augment = True
    #desc += '-lsun-motorbike';      dataset = EasyDict(tfrecord_dir='lsun-motorbike-100k');      train.mirror_augment = True
    #desc += '-lsun-person';         dataset = EasyDict(tfrecord_dir='lsun-person-100k');         train.mirror_augment = True
    #desc += '-lsun-pottedplant';    dataset = EasyDict(tfrecord_dir='lsun-pottedplant-100k');    train.mirror_augment = True
    #desc += '-lsun-restaurant';     dataset = EasyDict(tfrecord_dir='lsun-restaurant-100k');     train.mirror_augment = True
    #desc += '-lsun-sheep';          dataset = EasyDict(tfrecord_dir='lsun-sheep-100k');          train.mirror_augment = True
    #desc += '-lsun-sofa';           dataset = EasyDict(tfrecord_dir='lsun-sofa-100k');           train.mirror_augment = True
    #desc += '-lsun-tower';          dataset = EasyDict(tfrecord_dir='lsun-tower-100k');          train.mirror_augment = True
    #desc += '-lsun-train';          dataset = EasyDict(tfrecord_dir='lsun-train-100k');          train.mirror_augment = True
    #desc += '-lsun-tvmonitor';      dataset = EasyDict(tfrecord_dir='lsun-tvmonitor-100k');      train.mirror_augment = True

    # Conditioning & snapshot options.
    #desc += '-cond'; dataset.max_label_size = 'full' # conditioned on full label
    #desc += '-cond1'; dataset.max_label_size = 1 # conditioned on first component of the label
    #desc += '-g4k'; grid.size = '4k'
    #desc += '-grpc'; grid.layout = 'row_per_class'

    # Config presets (choose one).
    #desc += '-preset-v1-1gpu'; submit_config.num_gpus = 1; D.mbstd_group_size = 16; sched.minibatch_base = 16; sched.minibatch_dict = {256: 14, 512: 6, 1024: 3}; sched.lod_training_kimg = 800; sched.lod_transition_kimg = 800; train.total_kimg = 19000
    #desc += '-preset-v2-1gpu'; submit_config.num_gpus = 1; sched.minibatch_base = 4; sched.minibatch_dict = {4: 128, 8: 128, 16: 128, 32: 64, 64: 32, 128: 16, 256: 8, 512: 4}; sched.G_lrate_dict = {1024: 0.0015}; sched.D_lrate_dict = EasyDict(sched.G_lrate_dict); train.total_kimg = 12000
    #desc += '-preset-v2-2gpus'; submit_config.num_gpus = 2; sched.minibatch_base = 8; sched.minibatch_dict = {4: 256, 8: 256, 16: 128, 32: 64, 64: 32, 128: 16, 256: 8}; sched.G_lrate_dict = {512: 0.0015, 1024: 0.002}; sched.D_lrate_dict = EasyDict(sched.G_lrate_dict); train.total_kimg = 12000
    #desc += '-preset-v2-4gpus'; submit_config.num_gpus = 4; sched.minibatch_base = 16; sched.minibatch_dict = {4: 512, 8: 256, 16: 128, 32: 64, 64: 32, 128: 16}; sched.G_lrate_dict = {256: 0.0015, 512: 0.002, 1024: 0.003}; sched.D_lrate_dict = EasyDict(sched.G_lrate_dict); train.total_kimg = 12000
    #desc += '-preset-v2-8gpus'; submit_config.num_gpus = 8; sched.minibatch_base = 32; sched.minibatch_dict = {4: 512, 8: 256, 16: 128, 32: 64, 64: 32}; sched.G_lrate_dict = {128: 0.0015, 256: 0.002, 512: 0.003, 1024: 0.003}; sched.D_lrate_dict = EasyDict(sched.G_lrate_dict); train.total_kimg = 12000

    # Numerical precision (choose one).
    #desc += '-fp32'; sched.max_minibatch_per_gpu = {256: 16, 512: 8, 1024: 4}
    #desc += '-fp16'; G.dtype = 'float16'; D.dtype = 'float16'; G.pixelnorm_epsilon=1e-4; G_opt.use_loss_scaling = True; D_opt.use_loss_scaling = True; sched.max_minibatch_per_gpu = {512: 16, 1024: 8}

    # Disable individual features.
    #desc += '-nogrowing'; sched.lod_initial_resolution = 1024; sched.lod_training_kimg = 0; sched.lod_transition_kimg = 0; train.total_kimg = 10000
    #desc += '-nopixelnorm'; G.use_pixelnorm = False
    #desc += '-nowscale'; G.use_wscale = False; D.use_wscale = False
    #desc += '-noleakyrelu'; G.use_leakyrelu = False
    #desc += '-nosmoothing'; train.G_smoothing_kimg = 0.0
    #desc += '-norepeat'; train.minibatch_repeats = 1
    #desc += '-noreset'; train.reset_opt_for_new_lod = False

    # Special modes.
    #desc += '-BENCHMARK'; sched.lod_initial_resolution = 4; sched.lod_training_kimg = 3; sched.lod_transition_kimg = 3; train.total_kimg = (8*2+1)*3; sched.tick_kimg_base = 1; sched.tick_kimg_dict = {}; train.image_snapshot_ticks = 1000; train.network_snapshot_ticks = 1000
    #desc += '-BENCHMARK0'; sched.lod_initial_resolution = 1024; train.total_kimg = 10; sched.tick_kimg_base = 1; sched.tick_kimg_dict = {}; train.image_snapshot_ticks = 1000; train.network_snapshot_ticks = 1000
    #desc += '-VERBOSE'; sched.tick_kimg_base = 1; sched.tick_kimg_dict = {}; train.image_snapshot_ticks = 1; train.network_snapshot_ticks = 100
    #desc += '-GRAPH'; train.save_tf_graph = True
    #desc += '-HIST'; train.save_weight_histograms = True

#----------------------------------------------------------------------------
# Main entry point for training.
# Calls the function indicated by 'train' using the selected options.

def main():
    kwargs = EasyDict(train)
    kwargs.update(G_args=G, D_args=D, G_opt_args=G_opt, D_opt_args=D_opt, G_loss_args=G_loss, D_loss_args=D_loss)
    kwargs.update(dataset_args=dataset, sched_args=sched, grid_args=grid, tf_config=tf_config)
    kwargs.submit_config = copy.deepcopy(submit_config)
    kwargs.submit_config.run_dir_root = dnnlib.submission.submit.get_template_from_path(config.result_dir)
    kwargs.submit_config.run_dir_ignore += config.run_dir_ignore
    kwargs.submit_config.run_desc = desc
    dnnlib.submit_run(**kwargs)

#----------------------------------------------------------------------------

if __name__ == "__main__":
    main()

#----------------------------------------------------------------------------
# Out:
# Creating the run dir root: results
# Creating the run dir: results/00000-sgan-custom-1gpu
# Copying files to the run dir
# dnnlib: Running training.training_loop.training_loop() on localhost...
# Streaming data using training.dataset.TFRecordDataset...
# WARNING:tensorflow:From /content/stylegan/training/dataset.py:76: tf_record_iterator (from tensorflow.python.lib.io.tf_record) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use eager execution and:
# `tf.data.TFRecordDataset(path)`
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# Dataset shape = [3, 512, 512]
# Dynamic range = [0, 255]
# Label size    = 0
# Loading networks from "/content/stylegan/network-snapshot-011155.pkl"...
#
# G                             Params    OutputShape         WeightShape
# ---                           ---       ---                 ---
# latents_in                    -         (?, 512)            -
# labels_in                     -         (?, 0)              -
# lod                           -         ()                  -
# dlatent_avg                   -         (512,)              -
# G_mapping/latents_in          -         (?, 512)            -
# G_mapping/labels_in           -         (?, 0)              -
# G_mapping/PixelNorm           -         (?, 512)            -
# G_mapping/Dense0              262656    (?, 512)            (512, 512)
# G_mapping/Dense1              262656    (?, 512)            (512, 512)
# G_mapping/Dense2              262656    (?, 512)            (512, 512)
# G_mapping/Dense3              262656    (?, 512)            (512, 512)
# G_mapping/Dense4              262656    (?, 512)            (512, 512)
# G_mapping/Dense5              262656    (?, 512)            (512, 512)
# G_mapping/Dense6              262656    (?, 512)            (512, 512)
# G_mapping/Dense7              262656    (?, 512)            (512, 512)
# G_mapping/Broadcast           -         (?, 16, 512)        -
# G_mapping/dlatents_out        -         (?, 16, 512)        -
# Truncation                    -         (?, 16, 512)        -
# G_synthesis/dlatents_in       -         (?, 16, 512)        -
# G_synthesis/4x4/Const         534528    (?, 512, 4, 4)      (512,)
# G_synthesis/4x4/Conv          2885632   (?, 512, 4, 4)      (3, 3, 512, 512)
# G_synthesis/ToRGB_lod7        1539      (?, 3, 4, 4)        (1, 1, 512, 3)
# G_synthesis/8x8/Conv0_up      2885632   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/8x8/Conv1         2885632   (?, 512, 8, 8)      (3, 3, 512, 512)
# G_synthesis/ToRGB_lod6        1539      (?, 3, 8, 8)        (1, 1, 512, 3)
# G_synthesis/Upscale2D         -         (?, 3, 8, 8)        -
# G_synthesis/Grow_lod6         -         (?, 3, 8, 8)        -
# G_synthesis/16x16/Conv0_up    2885632   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/16x16/Conv1       2885632   (?, 512, 16, 16)    (3, 3, 512, 512)
# G_synthesis/ToRGB_lod5        1539      (?, 3, 16, 16)      (1, 1, 512, 3)
# G_synthesis/Upscale2D_1       -         (?, 3, 16, 16)      -
# G_synthesis/Grow_lod5         -         (?, 3, 16, 16)      -
# G_synthesis/32x32/Conv0_up    2885632   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/32x32/Conv1       2885632   (?, 512, 32, 32)    (3, 3, 512, 512)
# G_synthesis/ToRGB_lod4        1539      (?, 3, 32, 32)      (1, 1, 512, 3)
# G_synthesis/Upscale2D_2       -         (?, 3, 32, 32)      -
# G_synthesis/Grow_lod4         -         (?, 3, 32, 32)      -
# G_synthesis/64x64/Conv0_up    1442816   (?, 256, 64, 64)    (3, 3, 512, 256)
# G_synthesis/64x64/Conv1       852992    (?, 256, 64, 64)    (3, 3, 256, 256)
# G_synthesis/ToRGB_lod3        771       (?, 3, 64, 64)      (1, 1, 256, 3)
# G_synthesis/Upscale2D_3       -         (?, 3, 64, 64)      -
# G_synthesis/Grow_lod3         -         (?, 3, 64, 64)      -
# G_synthesis/128x128/Conv0_up  426496    (?, 128, 128, 128)  (3, 3, 256, 128)
# G_synthesis/128x128/Conv1     279040    (?, 128, 128, 128)  (3, 3, 128, 128)
# G_synthesis/ToRGB_lod2        387       (?, 3, 128, 128)    (1, 1, 128, 3)
# G_synthesis/Upscale2D_4       -         (?, 3, 128, 128)    -
# G_synthesis/Grow_lod2         -         (?, 3, 128, 128)    -
# G_synthesis/256x256/Conv0_up  139520    (?, 64, 256, 256)   (3, 3, 128, 64)
# G_synthesis/256x256/Conv1     102656    (?, 64, 256, 256)   (3, 3, 64, 64)
# G_synthesis/ToRGB_lod1        195       (?, 3, 256, 256)    (1, 1, 64, 3)
# G_synthesis/Upscale2D_5       -         (?, 3, 256, 256)    -
# G_synthesis/Grow_lod1         -         (?, 3, 256, 256)    -
# G_synthesis/512x512/Conv0_up  51328     (?, 32, 512, 512)   (3, 3, 64, 32)
# G_synthesis/512x512/Conv1     42112     (?, 32, 512, 512)   (3, 3, 32, 32)
# G_synthesis/ToRGB_lod0        99        (?, 3, 512, 512)    (1, 1, 32, 3)
# G_synthesis/Upscale2D_6       -         (?, 3, 512, 512)    -
# G_synthesis/Grow_lod0         -         (?, 3, 512, 512)    -
# G_synthesis/images_out        -         (?, 3, 512, 512)    -
# G_synthesis/lod               -         ()                  -
# G_synthesis/noise0            -         (1, 1, 4, 4)        -
# G_synthesis/noise1            -         (1, 1, 4, 4)        -
# G_synthesis/noise2            -         (1, 1, 8, 8)        -
# G_synthesis/noise3            -         (1, 1, 8, 8)        -
# G_synthesis/noise4            -         (1, 1, 16, 16)      -
# G_synthesis/noise5            -         (1, 1, 16, 16)      -
# G_synthesis/noise6            -         (1, 1, 32, 32)      -
# G_synthesis/noise7            -         (1, 1, 32, 32)      -
# G_synthesis/noise8            -         (1, 1, 64, 64)      -
# G_synthesis/noise9            -         (1, 1, 64, 64)      -
# G_synthesis/noise10           -         (1, 1, 128, 128)    -
# G_synthesis/noise11           -         (1, 1, 128, 128)    -
# G_synthesis/noise12           -         (1, 1, 256, 256)    -
# G_synthesis/noise13           -         (1, 1, 256, 256)    -
# G_synthesis/noise14           -         (1, 1, 512, 512)    -
# G_synthesis/noise15           -         (1, 1, 512, 512)    -
# images_out                    -         (?, 3, 512, 512)    -
# ---                           ---       ---                 ---
# Total                         26179768
#
#
# D                    Params    OutputShape         WeightShape
# ---                  ---       ---                 ---
# images_in            -         (?, 3, 512, 512)    -
# labels_in            -         (?, 0)              -
# lod                  -         ()                  -
# FromRGB_lod0         128       (?, 32, 512, 512)   (1, 1, 3, 32)
# 512x512/Conv0        9248      (?, 32, 512, 512)   (3, 3, 32, 32)
# 512x512/Conv1_down   18496     (?, 64, 256, 256)   (3, 3, 32, 64)
# Downscale2D          -         (?, 3, 256, 256)    -
# FromRGB_lod1         256       (?, 64, 256, 256)   (1, 1, 3, 64)
# Grow_lod0            -         (?, 64, 256, 256)   -
# 256x256/Conv0        36928     (?, 64, 256, 256)   (3, 3, 64, 64)
# 256x256/Conv1_down   73856     (?, 128, 128, 128)  (3, 3, 64, 128)
# Downscale2D_1        -         (?, 3, 128, 128)    -
# FromRGB_lod2         512       (?, 128, 128, 128)  (1, 1, 3, 128)
# Grow_lod1            -         (?, 128, 128, 128)  -
# 128x128/Conv0        147584    (?, 128, 128, 128)  (3, 3, 128, 128)
# 128x128/Conv1_down   295168    (?, 256, 64, 64)    (3, 3, 128, 256)
# Downscale2D_2        -         (?, 3, 64, 64)      -
# FromRGB_lod3         1024      (?, 256, 64, 64)    (1, 1, 3, 256)
# Grow_lod2            -         (?, 256, 64, 64)    -
# 64x64/Conv0          590080    (?, 256, 64, 64)    (3, 3, 256, 256)
# 64x64/Conv1_down     1180160   (?, 512, 32, 32)    (3, 3, 256, 512)
# Downscale2D_3        -         (?, 3, 32, 32)      -
# FromRGB_lod4         2048      (?, 512, 32, 32)    (1, 1, 3, 512)
# Grow_lod3            -         (?, 512, 32, 32)    -
# 32x32/Conv0          2359808   (?, 512, 32, 32)    (3, 3, 512, 512)
# 32x32/Conv1_down     2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# Downscale2D_4        -         (?, 3, 16, 16)      -
# FromRGB_lod5         2048      (?, 512, 16, 16)    (1, 1, 3, 512)
# Grow_lod4            -         (?, 512, 16, 16)    -
# 16x16/Conv0          2359808   (?, 512, 16, 16)    (3, 3, 512, 512)
# 16x16/Conv1_down     2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# Downscale2D_5        -         (?, 3, 8, 8)        -
# FromRGB_lod6         2048      (?, 512, 8, 8)      (1, 1, 3, 512)
# Grow_lod5            -         (?, 512, 8, 8)      -
# 8x8/Conv0            2359808   (?, 512, 8, 8)      (3, 3, 512, 512)
# 8x8/Conv1_down       2359808   (?, 512, 4, 4)      (3, 3, 512, 512)
# Downscale2D_6        -         (?, 3, 4, 4)        -
# FromRGB_lod7         2048      (?, 512, 4, 4)      (1, 1, 3, 512)
# Grow_lod6            -         (?, 512, 4, 4)      -
# 4x4/MinibatchStddev  -         (?, 513, 4, 4)      -
# 4x4/Conv             2364416   (?, 512, 4, 4)      (3, 3, 513, 512)
# 4x4/Dense0           4194816   (?, 512)            (8192, 512)
# 4x4/Dense1           513       (?, 1)              (512, 1)
# scores_out           -         (?, 1)              -
# ---                  ---       ---                 ---
# Total                23080225
#
# Building TensorFlow graph...
# WARNING:tensorflow:From /content/stylegan/training/training_loop.py:167: div (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Deprecated in favor of operator or tf.math.divide.
# WARNING:tensorflow:From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
#
# WARNING: The TensorFlow contrib module will not be included in TensorFlow 2.0.
# For more information, please see:
#   * https://github.com/tensorflow/community/blob/master/rfcs/20180907-contrib-sunset.md
#   * https://github.com/tensorflow/addons
# If you depend on functionality not listed there, please file an issue.
#
# Setting up snapshot image grid...
# Setting up run dir...
# Training...
#
# tick 1     kimg 11185.0  lod 0.00  minibatch 4    time 6h 03m 40s   sec/tick 21739.5 sec/kimg 724.65  maintenance 80.2   gpumem 5.6
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-19-9e62b7eb9c86> in <module>()
#     180
#     181 if __name__ == "__main__":
# --> 182     main()
#     183
#     184 #----------------------------------------------------------------------------
#
# <ipython-input-19-9e62b7eb9c86> in main()
#     175     kwargs.submit_config.run_dir_ignore += config.run_dir_ignore
#     176     kwargs.submit_config.run_desc = desc
# --> 177     dnnlib.submit_run(**kwargs)
#     178
#     179 #----------------------------------------------------------------------------
#
# /content/stylegan/dnnlib/submission/submit.py in submit_run(submit_config, run_func_name, **run_func_kwargs)
#     288             return
#     289
# --> 290     run_wrapper(submit_config)
#
# /content/stylegan/dnnlib/submission/submit.py in run_wrapper(submit_config)
#     240         print("dnnlib: Running {0}() on {1}...".format(submit_config.run_func_name, submit_config.host_name))
#     241         start_time = time.time()
# --> 242         util.call_func_by_name(func_name=submit_config.run_func_name, submit_config=submit_config, **submit_config.run_func_kwargs)
#     243         print("dnnlib: Finished {0}() in {1}.".format(submit_config.run_func_name, util.format_time(time.time() - start_time)))
#     244     except:
#
# /content/stylegan/dnnlib/util.py in call_func_by_name(func_name, *args, **kwargs)
#     255     func_obj = get_obj_by_name(func_name)
#     256     assert callable(func_obj)
# --> 257     return func_obj(*args, **kwargs)
#     258
#     259
#
# /content/stylegan/training/training_loop.py in training_loop(submit_config, G_args, D_args, G_opt_args, D_opt_args, G_loss_args, D_loss_args, dataset_args, sched_args, grid_args, metric_arg_list, tf_config, G_smoothing_kimg, D_repeats, minibatch_repeats, reset_opt_for_new_lod, total_kimg, mirror_augment, drange_net, image_snapshot_ticks, network_snapshot_ticks, save_tf_graph, save_weight_histograms, resume_run_id, resume_snapshot, resume_kimg, resume_time)
#     228         for _mb_repeat in range(minibatch_repeats):
#     229             for _D_repeat in range(D_repeats):
# --> 230                 tflib.run([D_train_op, Gs_update_op], {lod_in: sched.lod, lrate_in: sched.D_lrate, minibatch_in: sched.minibatch})
#     231                 cur_nimg += sched.minibatch
#     232             tflib.run([G_train_op], {lod_in: sched.lod, lrate_in: sched.G_lrate, minibatch_in: sched.minibatch})
#
# /content/stylegan/dnnlib/tflib/tfutil.py in run(*args, **kwargs)
#      24     """Run the specified ops in the default session."""
#      25     assert_tf_initialized()
# ---> 26     return tf.get_default_session().run(*args, **kwargs)
#      27
#      28
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in run(self, fetches, feed_dict, options, run_metadata)
#     927     try:
#     928       result = self._run(None, fetches, feed_dict, options_ptr,
# --> 929                          run_metadata_ptr)
#     930       if run_metadata:
#     931         proto_data = tf_session.TF_GetBuffer(run_metadata_ptr)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run(self, handle, fetches, feed_dict, options, run_metadata)
#    1150     if final_fetches or final_targets or (handle and feed_dict_tensor):
#    1151       results = self._do_run(handle, final_targets, final_fetches,
# -> 1152                              feed_dict_tensor, options, run_metadata)
#    1153     else:
#    1154       results = []
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_run(self, handle, target_list, fetch_list, feed_dict, options, run_metadata)
#    1326     if handle is None:
#    1327       return self._do_call(_run_fn, feeds, fetches, targets, options,
# -> 1328                            run_metadata)
#    1329     else:
#    1330       return self._do_call(_prun_fn, handle, feeds, fetches)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _do_call(self, fn, *args)
#    1332   def _do_call(self, fn, *args):
#    1333     try:
# -> 1334       return fn(*args)
#    1335     except errors.OpError as e:
#    1336       message = compat.as_text(e.message)
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _run_fn(feed_dict, fetch_list, target_list, options, run_metadata)
#    1317       self._extend_graph()
#    1318       return self._call_tf_sessionrun(
# -> 1319           options, feed_dict, fetch_list, target_list, run_metadata)
#    1320
#    1321     def _prun_fn(handle, feed_dict, fetch_list):
#
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/client/session.py in _call_tf_sessionrun(self, options, feed_dict, fetch_list, target_list, run_metadata)
#    1405     return tf_session.TF_SessionRun_wrapper(
#    1406         self._session, options, feed_dict, fetch_list, target_list,
# -> 1407         run_metadata)
#    1408
#    1409   def _call_tf_sessionprun(self, handle, feed_dict, fetch_list):
#
# KeyboardInterrupt:
